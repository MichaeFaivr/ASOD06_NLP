# %% [markdown]
# # Challenge - Preprocessing pipeline
#
# ![](https://media.ouest-france.fr/v1/pictures/fe9603bace85f5c3339acb605cb31894-17133782.jpg?width=1400&client_id=eds&sign=9fb46757bc793cfe75ca6a14462ccbf26bbff31d9a7ce55d426c03ae31da2465)
#
# ## Objectives
#
# First, the goal is to optimize the time to preprocessing text data with Spacy.
# Second, classify french tweets between negative and positive tweets.
#
# ## Guidelines
#
# 🚰 The preprocessing of texts can be time-consuming and costly for your computer, especially if your dataset is large. Spacy has developed a [feature](https://spacy.io/usage/processing-pipelines) to implement a text pre-processing pipeline to optimise the process.
#
# To measure the time of preprocessing we will use tqdm package to display a progress bar.
#
# ## Dataset
#
# 📥 In this exercise we will use a dataset of 1.5 million French tweets and their sentiment (negative and positive) from Kaggle : https://www.kaggle.com/hbaflast/french-twitter-sentiment-analysis
#
# To avoid any Github issue, don't forget to store the dataset in your local `data` folder.

# %% [markdown]
# ### GOAL.1: Optimize the time to preprocessing text data with Spacy.
# ### GOAL.2: Classify french tweets between negative and positive tweets.

# %%
# import librairies
import numpy as np
import pandas as pd
from sklearn.utils import resample
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from tqdm import tqdm
import spacy
from spacy import displacy
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

# %% [markdown]
# # 1. Load data and explore it

# %%
# load the french small model
nlp = spacy.load("fr_core_news_sm")

# %%
# import data
df = pd.read_csv('../french_tweets/french_tweets.csv',header=0)
df.head()
# Out:
#    label                                               text
# 0      0  - Awww, c'est un bummer. Tu devrais avoir davi...
# 1      0  Est contrarié qu'il ne puisse pas mettre à jou...
# 2      0  J'ai plongé plusieurs fois pour la balle. A ré...
# 3      0  Tout mon corps a des démangeaisons et comme si...
# 4      0  Non, il ne se comporte pas du tout. je suis en...

# %%
# check the labels balance
df.label.value_counts() #balanced
# Out:
# 0    771604
# 1    755120
# Name: label, dtype: int64

# %% [markdown]
# > Explore some tweets, which label corresponds to which sentiment ? Are the tweets properly labelled ?

# %%
# explore some tweets and consider the pre-processing steps that will be required
## label 0
df[df.label==0].iloc[:10]
# Out:
#    label                                               text
# 0      0  - Awww, c'est un bummer. Tu devrais avoir davi...
# 1      0  Est contrarié qu'il ne puisse pas mettre à jou...
# 2      0  J'ai plongé plusieurs fois pour la balle. A ré...
# 3      0  Tout mon corps a des démangeaisons et comme si...
# 4      0  Non, il ne se comporte pas du tout. je suis en...
# 5      0                             Pas l'équipage complet
# 6      0                                  besoin d'un câlin
# 7      0  Bonjour pas de vue! Oui ... pleut un peu, just...
# 8      0                          Non, ils ne l'avaient pas
# 9      0                                          Je meurs?

# %%
## label 1: seems more positive
df[df.label==1].iloc[:10]
# Out:
#         label                                               text
# 771604      1         Je vous aime, les gars sont les meilleurs!
# 771605      1  Je me retrouve avec un de mes besties ce soir!...
# 771606      1  Merci pour l'ajout de Twitter, sunisa! Je dois...
# 771607      1  Être malade peut être vraiment bon marché quan...
# 771608      1                   Il a cet effet sur tout le monde
# 771609      1  Vous pouvez lui dire que je viens d'éclater de...
# 771610      1  Merci pour votre réponse. J'avais déjà trouvé ...
# 771611      1  Je suis tellement jaloux, j'espère que vous av...
# 771612      1  Ah, félicite mr fletcher pour finalement rejoi...
# 771613      1  J'ai répondu que le chat stupide m'aidé à tape...

# %% [markdown]
# > 0 seems to be the negative tweets and 1 the positives **but the labels are not always very accurate...** This is not very big deal for our exercise which aims to see the possibilities of preprocessing a large dataset with Spacy.
#
#
# For the moment create a sample with just 20000 tweets and process it with Spacy.

# %% [markdown]
# # 2. Sample the dataset and preprocess it

# %%
n_samples = 20000

# %%
# sample the dataset (20000 tweets) in df_sample 
df_sample = resample(df, n_samples=n_samples, random_state=42)
df_sample.shape
# Out:
# (20000, 2)

# %% [markdown]
# Create a preprocessing function. For the moment don't bother with the preprocessing step, keep it simple:
# - remove the punctuation
# - remove stopwords
# - lemmatization

# %%
# create the preprocessing function
def preprocess_nltk(sent):
    # tokenization
    tokens = word_tokenize(sent)
    # remove stopwords
    stop_words = stopwords.words('english')
    tokens = [t for t in tokens if not t in stop_words]
    # lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(t) for t in tokens]
    return tokens

# %%
# apply onto text
df_sample['preprocessed_text_nltk'] = df_sample.text.apply(preprocess_nltk)
df_sample.head()
# Out:
#          label                                               text  \
# 121958       0  Mais je ne peux pas envoyer de courrier électr...
# 671155       0  Se sent mal après avoir mangé & quot; cinema s...
# 131932       0     awwe..hey..i doivent chat lit g2 plus tard? :]
# 1414414      1  La famille et les amis sont partis après un be...
# 259178       0  Oui, je commence définitivement à ressentir le...
#
#                                     preprocessed_text_nltk
# 121958   [Mais, je, ne, peux, pa, envoyer, de, courrier...
# 671155   [Se, sent, mal, après, avoir, mangé, &, quot, ...
# 131932   [awwe, .., hey, .., doivent, chat, lit, g2, pl...
# 1414414  [La, famille, et, le, amis, sont, partis, aprè...
# 259178   [Oui, ,, je, commence, définitivement, à, ress...

# %% [markdown]
# To measure the time to preprocessing tweets, create a new list with lists of tokens and measure time a process. To do that put the iterator in the `tqdm()` function, like this :
#
# ```python
# tokens = list()
# for tweet in tqdm(df_sample.text):
#     tokens.append(preprocessing(tweet))
# ```

# %%
# create a new list with all tweets tokens 
tokens = list()
for tweet in tqdm(df_sample.text):
    tokens.append(preprocess_nltk(tweet))
# 5.7s
tokens
# linear extrapolate for 1.5M: 6 * 75 = 7.5mins
# Out:
# 100%|██████████| 20000/20000 [00:07<00:00, 2511.61it/s]
# [['Mais',
#   'je',
#   'ne',
#   'peux',
#   'pa',
#   'envoyer',
#   'de',
#   'courrier',
#   'électronique',
#   'à',
#   'personne',
#   '!',
#   'Ce',
#   "n'est",
#   'pa',
#   'seulement',
#   'votre',
#   'adresse',
#   '...'],
#  ['Se',
#   'sent',
#   'mal',
#   'après',
#   'avoir',
#   'mangé',
#   '&',
#   'quot',
#   ';',
#   'cinema',
#   'sweet',
#   '&',
#   'quot',
#   ';',
#   'pop',
#   'corn',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'Sans',
#   'le',
#   'cinéma'],
#  ['awwe',
#   '..',
#   'hey',
#   '..',
#   'doivent',
#   'chat',
#   'lit',
#   'g2',
#   'plus',
#   'tard',
#   '?',
#   ':',
#   ']'],
#  ['La',
#   'famille',
#   'et',
#   'le',
#   'amis',
#   'sont',
#   'partis',
#   'après',
#   'un',
#   'beau',
#   'week-end',
#   'de',
#   'fin',
#   "d'études",
#   'de',
#   'deux',
#   'jours',
#   '!',
#   "J'ai",
#   'passé',
#   'un',
#   'bon',
#   'moment',
#   '!',
#   'Merci',
#   "d'être",
#   'venu',
#   '!',
#   ';',
#   ')',
#   'Le',
#   'week-end',
#   'prochain',
#   'pt',
#   '2',
#   '!'],
#  ['Oui',
#   ',',
#   'je',
#   'commence',
#   'définitivement',
#   'à',
#   'ressentir',
#   'le',
#   'décalage',
#   'maintenant',
#   '.',
#   'Environ',
#   'quatre',
#   'heures',
#   'supplémentaires',
#   ',',
#   'mais',
#   "j'ai",
#   'entendu',
#   'dire',
#   'que',
#   'nous',
#   'pouvons',
#   'avoir',
#   'de',
#   'heures',
#   'supplémentaires',
#   'obligatoires',
#   ',',
#   'donc',
#   'peut-être',
#   'cinq',
#   'ou',
#   'six'],
#  ['Je',
#   'vais',
#   'bien',
#   ',',
#   'mais',
#   'je',
#   'fais',
#   'me',
#   'devoir',
#   ',',
#   'haha',
#   ',',
#   'quoi',
#   'de',
#   'neuf',
#   '?'],
#  ["L'iPhone",
#   'n',
#   "'",
#   'pa',
#   'de',
#   'réception',
#   'dans',
#   'le',
#   'bâtiment',
#   'de',
#   'la',
#   'caisse',
#   'de',
#   'ciment',
#   'au',
#   'travail',
#   '.',
#   'Il',
#   'souffle',
#   'que',
#   'son',
#   'collègue',
#   'peut',
#   'discuter',
#   'librement',
#   'sur',
#   'sa',
#   'cellule',
#   ',',
#   'alors',
#   'que',
#   'je',
#   'doi',
#   'travailler',
#   '!'],
#  ['Mais',
#   'vous',
#   'avez',
#   "d'autres",
#   'compétences',
#   'dans',
#   'lesquelles',
#   'je',
#   'peux',
#   'croire',
#   ',',
#   'comme',
#   'manger',
#   'tard-nite',
#   'taco',
#   'bell',
#   '&',
#   'amp',
#   ';',
#   'Porter',
#   'une',
#   'ceinture',
#   'de',
#   'lutte',
#   'au',
#   'club'],
#  ['Mes',
#   'examen',
#   'se',
#   'sont',
#   'bien',
#   'passés',
#   ',',
#   'mais',
#   'il',
#   'encore',
#   'du',
#   'temp',
#   '...',
#   'merde',
#   '!'],
#  ['Mignon',
#   'cube',
#   '«',
#   'portail',
#   '»',
#   'haché',
#   '.',
#   'Mon',
#   'bébé',
#   'joue',
#   'à',
#   'de',
#   'jeux',
#   ',',
#   'je',
#   'li',
#   'de',
#   'fiction',
#   'de',
#   'fan',
#   '!'],
#  ['Je',
#   'serai',
#   'en',
#   'attente',
#   "d'entendre",
#   '...',
#   'attends',
#   'avec',
#   'impatience',
#   'ce',
#   'que',
#   'vous',
#   'venez',
#   'de',
#   'faire'],
#  ['-', "J'ai", 'cette', 'chemise', '!'],
#  ['Arriver', 'à', 'votre', 'voiture', '?'],
#  ['Mon',
#   'ami',
#   'et',
#   'mon',
#   'ami',
#   'Je',
#   'suis',
#   'en',
#   'atl',
#   '.',
#   'Nous',
#   'avon',
#   'eu',
#   'un',
#   '5',
#   '*',
#   'dans',
#   'West',
#   'Palm',
#   '&',
#   'amp',
#   ';',
#   'Manqué',
#   'de',
#   'vous',
#   'rencontrer',
#   '.',
#   "J'aimerais",
#   'te',
#   'voir',
#   "aujourd'hui",
#   '!',
#   'Pouvez-vous',
#   'nous',
#   'accrocher',
#   '?'],
#  ["J'ai", 'un', 'ca', 'de', 'lundi', '.'],
#  ['Je',
#   'ne',
#   'pense',
#   'pa',
#   'que',
#   'vous',
#   'avez',
#   'rejoint',
#   ',',
#   'pensez',
#   'que',
#   'vous',
#   'devez',
#   'publier',
#   'une',
#   'URL',
#   'complète',
#   ',',
#   'pa',
#   'la',
#   'raccourcie',
#   'pour',
#   'vous',
#   'joindre',
#   '.',
#   'Joignez-vous',
#   'si',
#   'vous',
#   'êtes',
#   'intéressé',
#   '.',
#   'devrait',
#   'être',
#   'amusant'],
#  ['Manque', 'son', 'bébé'],
#  ['Matinée', ',', 'vers', 'le', 'haut', ',', '2', "aujourd'hui", ',', 'AA'],
#  ['Et', 'toute', 'une', 'application', 'est', '.'],
#  ['Oui', ',', "j'ai", 'eu', 'tort', 'aussi', '.', 'Pardon', '.'],
#  ['Ne',
#   'veulent',
#   'pa',
#   'aller',
#   'au',
#   'collège',
#   "aujourd'hui",
#   ',',
#   'ont',
#   'toujours',
#   'du',
#   'travail',
#   'épique',
#   'pour',
#   'travailler'],
#  ['Le',
#   'voyage',
#   'était',
#   'amusant',
#   ',',
#   'surtout',
#   'en',
#   'voyant',
#   'le',
#   'chiot',
#   'de',
#   'mon',
#   'chien',
#   'et',
#   'de',
#   'sa',
#   'soeur',
#   ',',
#   'tellement',
#   'mignon',
#   '!',
#   'Comment',
#   'allez',
#   'vous',
#   '?'],
#  ['25',
#   'jours',
#   'avant',
#   "l'obtention",
#   'du',
#   'diplôme',
#   '!',
#   '...',
#   '26',
#   'jours',
#   'avant',
#   'le',
#   'mariage',
#   'de',
#   'Miguel',
#   '!',
#   '...',
#   'et',
#   'surtout',
#   '27',
#   'jours',
#   'jusqu',
#   "'",
#   'à',
#   'ce',
#   'que',
#   'je',
#   'déplace',
#   'avec',
#   'mike',
#   'je',
#   "t'aime",
#   'mike',
#   '&',
#   'lt',
#   ';',
#   '3'],
#  ["J'ai", 'du', 'travail', 'jeudi'],
#  ['fête', 'ce', 'soir', '.'],
#  ['dernier', 'jour', "d'école", '.'],
#  ['Envisageant',
#   'de',
#   'regarder',
#   'le',
#   'super',
#   '14',
#   'finale',
#   'ce',
#   'soir',
#   'à',
#   '1h30',
#   '...',
#   'bien',
#   'que',
#   'je',
#   'sen',
#   'déjà',
#   'fatigué',
#   'et',
#   'que',
#   'ce',
#   'ne',
#   'sont',
#   'que',
#   '17h00'],
#  ['est',
#   'de',
#   'retour',
#   '!',
#   '!',
#   '!',
#   '!',
#   'Mon',
#   'comp',
#   'n',
#   "'",
#   'pa',
#   'eu',
#   'Internet',
#   'pendant',
#   'plus',
#   "d'un",
#   'mois',
#   '!',
#   '!'],
#  ['Bon',
#   'anniversaire',
#   '!',
#   "J'espère",
#   'que',
#   'vous',
#   'avez',
#   'une',
#   'bonne',
#   'journée',
#   '!'],
#  ['peut', 'être', 'que', 'je', 'le', 'ferais', '.'],
#  ['Regarder', 'wall-e', '.'],
#  ['Mange',
#   'mon',
#   'yogustuff',
#   'gelé',
#   ',',
#   'il',
#   'manque',
#   'le',
#   'zachary',
#   ',',
#   'pa',
#   'même',
#   'tout',
#   'le',
#   'froenzo',
#   'dans',
#   'le',
#   'monde',
#   'pourrait',
#   'le',
#   'rattraper'],
#  ['Et',
#   "l'entrevue",
#   'est',
#   'parce',
#   'que',
#   'moi',
#   'et',
#   'Angie',
#   'avon',
#   'un',
#   'groupe',
#   'à',
#   'jouer',
#   'à',
#   "l'école",
#   '.'],
#  ['Il',
#   'est',
#   'à',
#   '3',
#   'heures',
#   'du',
#   'matin',
#   ',',
#   'je',
#   'suis',
#   'très',
#   'fatigué',
#   'mais',
#   'je',
#   'ne',
#   'peux',
#   'pa',
#   'dormir',
#   'mais',
#   'je',
#   "l'essaye"],
#  ['Juste',
#   'à',
#   'la',
#   'maison',
#   'de',
#   "l'hôpital",
#   ',',
#   'mon',
#   'nounou',
#   'eu',
#   'peur',
#   '.',
#   'Tout',
#   'est',
#   'bien',
#   ',',
#   'bien',
#   "qu'heureusement"],
#  ['Paula',
#   '&',
#   'amp',
#   ';',
#   "J'ai",
#   'eu',
#   'un',
#   'bon',
#   'convo',
#   'alors',
#   "qu'elle",
#   'donnait',
#   'ce',
#   'fab',
#   'mani',
#   '*',
#   'pedi'],
#  ['En',
#   'essayant',
#   "d'aller",
#   'dormir',
#   ',',
#   'je',
#   'manque',
#   'le',
#   'mari',
#   ',',
#   'et',
#   'je',
#   "l'avais",
#   'venu',
#   'en',
#   'Ohio'],
#  ['Est',
#   'à',
#   'la',
#   'maison',
#   'tout',
#   'seul',
#   'et',
#   'ne',
#   'sait',
#   'pa',
#   'quoi',
#   'faire',
#   '.',
#   'Choses',
#   'à',
#   'faire',
#   ':',
#   'regarder',
#   'le',
#   'amis',
#   ',',
#   'dormir',
#   ',',
#   'se',
#   'laver',
#   ',',
#   'je',
#   'ne',
#   'sais',
#   'pa',
#   '.',
#   'Meh',
#   '.'],
#  ['Veut', 'ne', 'plus', 'être', 'malade', '!'],
#  ['13',
#   'dessins',
#   'vers',
#   'le',
#   'ba',
#   ',',
#   '6',
#   'pour',
#   'aller',
#   '.',
#   'Et',
#   'je',
#   'viens',
#   'de',
#   'nettoyer',
#   'le',
#   'toilette',
#   '.'],
#  ["D'accord",
#   ',',
#   'alors',
#   'je',
#   'commence',
#   'enfin',
#   'ce',
#   'document',
#   'de',
#   '4',
#   'à',
#   '6',
#   'page',
#   '.',
#   '.',
#   '.',
#   'Si',
#   'heureuse',
#   ',',
#   "l'école",
#   'est',
#   'presque',
#   'finie',
#   '...',
#   'la',
#   'petite',
#   'fille',
#   'est',
#   'allée',
#   'dormir',
#   'et',
#   'je',
#   'suis',
#   'fatiguée'],
#  ['♫', '~', '7fj77', 'happy', 'monday', '!', '!'],
#  ["J'ai",
#   'passé',
#   'un',
#   'bon',
#   'moment',
#   'à',
#   'loris',
#   'dance',
#   '!',
#   'Notre',
#   'voyage',
#   'sur',
#   'la',
#   'route',
#   'était',
#   'amusant',
#   '.',
#   'A',
#   'dû',
#   'faire',
#   'notre',
#   'nursey',
#   'bit',
#   'et',
#   'aider',
#   'un',
#   'chien',
#   'touché',
#   'par',
#   'une',
#   'voiture',
#   '!',
#   '!',
#   'Bon',
#   'week-end',
#   '!'],
#  ['Moi',
#   'et',
#   'nikki',
#   'avon',
#   'eu',
#   'une',
#   'somme',
#   'en',
#   'religion',
#   ':',
#   'l',
#   ':',
#   'l',
#   '``',
#   'sœur',
#   "''",
#   '&',
#   'Quot',
#   ';',
#   'juste',
#   '...',
#   '&',
#   'quot',
#   ';',
#   'Sur',
#   'mon',
#   'propre',
#   ':',
#   'l',
#   ':',
#   'je',
#   'passe',
#   'go',
#   'n.b',
#   '.',
#   'Wooohooo',
#   ':',
#   'l',
#   ':',
#   'l',
#   ':',
#   'je',
#   "t'aime"],
#  ['Aww', 'poor', 'little', 'guy'],
#  ['Oh',
#   ',',
#   'pa',
#   'parler',
#   'jusqu',
#   "'",
#   'à',
#   '2',
#   'pouces',
#   'de',
#   'pluie',
#   'au',
#   'cours',
#   'de',
#   '2',
#   'prochains',
#   'jours',
#   '.',
#   'Je',
#   'pourrais',
#   'peut-être',
#   'sortir',
#   'du',
#   'sous-sol',
#   'à',
#   'nouveau',
#   '.',
#   'Et',
#   'il',
#   'se',
#   'faisait',
#   'sécher'],
#  ['Je',
#   'viens',
#   'de',
#   'lira',
#   'votre',
#   'réponse',
#   'dès',
#   'maintenant',
#   ',',
#   'je',
#   'suis',
#   'désolé',
#   ',',
#   'je',
#   "n'ai",
#   'pa',
#   'répondu',
#   'plus',
#   'tôt',
#   '.',
#   "C'était",
#   'sur',
#   'la',
#   'chaîne',
#   'de',
#   'football',
#   'du',
#   'renard',
#   '.'],
#  ['Aller', 'au', 'dentiste'],
#  ['Je',
#   'suis',
#   'un',
#   'grand',
#   'fan',
#   'de',
#   'Ryan',
#   'Sheckler',
#   ',',
#   'et',
#   "j'ai",
#   'tous',
#   's',
#   'produits',
#   '.',
#   'Je',
#   'voulais',
#   'le',
#   'rencontrer',
#   'à',
#   'Londres',
#   "j'espère",
#   'que',
#   'je',
#   'vais',
#   'vous',
#   'rencontrer',
#   'bientôt',
#   '.',
#   'paix',
#   '.'],
#  ['Soooooo',
#   'non',
#   'fou',
#   'de',
#   'personnes',
#   'que',
#   'je',
#   'suis',
#   ',',
#   'répondez-moi'],
#  ["N'ayant",
#   'pa',
#   'beaucoup',
#   'de',
#   'chance',
#   'ce',
#   'derniers',
#   'temp',
#   '?',
#   'Suce',
#   'être',
#   'vous',
#   '.'],
#  ['Omg',
#   'la',
#   'vidéo',
#   'de',
#   'ce',
#   'takkiii',
#   "'",
#   'fait',
#   'pleurer',
#   '...',
#   '?',
#   'V',
#   '=',
#   'egnpptqqhbo',
#   'takkii',
#   "l'air",
#   'tellement',
#   'triste',
#   'quand',
#   'il',
#   'pleure',
#   '!'],
#  ['Mon',
#   'équipe',
#   'perdu',
#   'de',
#   'sentiment',
#   'tristes',
#   'à',
#   "l'intérieur",
#   '...',
#   'mais',
#   'de',
#   'toute',
#   'façon',
#   ',',
#   'allez',
#   'obtenir',
#   'le',
#   'nouvel',
#   'album',
#   'de',
#   'jb',
#   'demain',
#   '!',
#   'fais',
#   'le',
#   '!'],
#  ['Attention',
#   'à',
#   'ce',
#   'choses',
#   '!',
#   'Ce',
#   "n'est",
#   'pa',
#   'bon',
#   'pour',
#   'vous',
#   'que',
#   'je',
#   'soupçonne',
#   '!',
#   'Nous',
#   'espérons',
#   'néanmoins',
#   'que',
#   'cela',
#   'vous',
#   'aidera',
#   'dans',
#   'vos',
#   'recherches',
#   '.',
#   'Dis',
#   'bonjour',
#   'à',
#   'randy',
#   '4',
#   'moi',
#   '!'],
#  ["J'aimerais",
#   'bien',
#   'être',
#   'là',
#   'pour',
#   'vous',
#   'regarder',
#   'jouer',
#   'avec',
#   'le',
#   'frères',
#   'jonas',
#   '.'],
#  ["Aujourd'hui",
#   ',',
#   'je',
#   'ne',
#   'parle',
#   'pa',
#   'avec',
#   'Manu',
#   ',',
#   'je',
#   'suis',
#   'triste'],
#  ['Mes',
#   'deux',
#   'côtes',
#   'inférieures',
#   '(',
#   'à',
#   "l'avant",
#   ')',
#   'sont',
#   'toujours',
#   'brunes',
#   'lorsque',
#   'je',
#   'réveille',
#   '.',
#   'Je',
#   'vais',
#   "d'une",
#   'certaine',
#   'façon',
#   'dormir',
#   'sur',
#   'eux',
#   '.'],
#  ['Jouer',
#   'à',
#   "l'un",
#   'avec',
#   'dulce',
#   'et',
#   'regarder',
#   'la',
#   'nouvelle',
#   'bande-annonce',
#   'de',
#   'la',
#   'lune'],
#  ['Aw',
#   'damn',
#   ',',
#   'je',
#   'ne',
#   'peux',
#   'pa',
#   'attendre',
#   'la',
#   'version',
#   'rb',
#   'beatles',
#   'hahaha'],
#  ['Est',
#   'excité',
#   'parce',
#   "qu'on",
#   'lui',
#   'dit',
#   'combien',
#   'elle',
#   'était',
#   'géniale',
#   'à',
#   'son',
#   'travail'],
#  ['Comme',
#   'le',
#   'thé',
#   'de',
#   "l'après-midi",
#   'ou',
#   'le',
#   'bday',
#   '?',
#   'Sevva',
#   'est',
#   'goooood',
#   'ou',
#   'obtenez',
#   'le',
#   'formes',
#   'que',
#   'nous',
#   'avon',
#   'vu',
#   'en',
#   'cakelicious',
#   'la',
#   'dernière',
#   'fois',
#   '...'],
#  ['huer', '!', 'No', 'rafa', 'wimbledon'],
#  ['*', 'Squee', '!', '*', 'Hey', 'beautiful', 'wifey', "'mine", '.'],
#  ['Hahahaha',
#   'je',
#   'ne',
#   'peux',
#   'pa',
#   'dormir',
#   'et',
#   'maintenant',
#   "j'ai",
#   'faim'],
#  ['Je',
#   'serai',
#   'sûr',
#   'de',
#   'vérifier',
#   'demain',
#   '!',
#   'Je',
#   'ferais',
#   'ce',
#   'soir',
#   ',',
#   'mais',
#   'je',
#   'ferai',
#   'mieux',
#   'de',
#   'coucher',
#   '.',
#   'Les',
#   'orages',
#   'tenaient',
#   'debout',
#   'toute',
#   'la',
#   'nuit'],
#  ['Vient',
#   'de',
#   'voir',
#   'avec',
#   'rachel',
#   ',',
#   'anielle',
#   'et',
#   'lynda',
#   '.',
#   'film',
#   'génial',
#   '!',
#   'Je',
#   'veux',
#   'le',
#   'revoir',
#   '!'],
#  ['Re',
#   ':',
#   'autoroute',
#   'de',
#   'anciens',
#   'combattants',
#   '-',
#   'bien',
#   'au',
#   'moins',
#   'il',
#   'beaucoup',
#   'de',
#   'pause',
#   'à',
#   'refléter',
#   '...'],
#  ['Hiiiiiiiii',
#   '!',
#   'Love',
#   'love',
#   'love',
#   'wish',
#   'wer',
#   'comin',
#   '2nyt',
#   'comin',
#   'gatecrasher',
#   'mercredi',
#   'prochain',
#   'pour',
#   'jossays',
#   'yeye',
#   'safe',
#   'sangé',
#   'x'],
#  ['Pardon',
#   '!',
#   'Si',
#   'cela',
#   'vous',
#   'rend',
#   'mieux',
#   ',',
#   'il',
#   "n'ont",
#   'pa',
#   'ajouté',
#   'le',
#   'fromage',
#   'de',
#   'chèvre',
#   'que',
#   "j'ai",
#   'demandé',
#   ',',
#   'lol',
#   '.'],
#  ["D'accord",
#   ',',
#   "j'ai",
#   'regardé',
#   'la',
#   'finale',
#   'de',
#   'saison',
#   'de',
#   'collines',
#   '.',
#   'Lauren',
#   ',',
#   'si',
#   'triste',
#   ',',
#   'est',
#   'allée',
#   'en',
#   'larmes',
#   '.',
#   'La',
#   'saison',
#   'prochaine',
#   'de',
#   'collines',
#   'serum',
#   'également',
#   'intéressante',
#   '.',
#   'Mmmm'],
#  ["c'est", 'bien', '!'],
#  ['vraiment',
#   '?',
#   '?',
#   'Parce',
#   'que',
#   'vous',
#   'voulez',
#   'dire',
#   'beaucoup',
#   'pour',
#   'moi',
#   ',',
#   'je',
#   'ferais',
#   'beaucoup',
#   'pour',
#   'vous',
#   '.'],
#  ['Je',
#   'doi',
#   'travailler',
#   'sur',
#   'le',
#   'vendredi',
#   'et',
#   'le',
#   'samedi',
#   ',',
#   "c'était",
#   '45',
#   'degrés',
#   ',',
#   'mon',
#   'seul',
#   'rafraîchissement',
#   "n'était",
#   'que',
#   'le',
#   '``',
#   'idol',
#   'marathon',
#   "''",
#   ',',
#   'non',
#   'net'],
#  ['Ack',
#   '!',
#   'Oh',
#   'mec',
#   '.',
#   "J'espérais",
#   'plus',
#   'tôt',
#   '.',
#   'Ah',
#   'bien',
#   ',',
#   'pratiquez',
#   'dans',
#   "l'exercice",
#   'de',
#   'la',
#   'patience',
#   '.',
#   ';',
#   ')'],
#  ['Travaillé',
#   'autour',
#   'de',
#   'la',
#   'maison',
#   'pendant',
#   'la',
#   'plus',
#   'grande',
#   'partie',
#   'de',
#   'la',
#   'matinée',
#   '!',
#   'Ce',
#   "n'est",
#   'que',
#   '16',
#   'heures',
#   'et',
#   'je',
#   'suis',
#   'déjà',
#   'épuisé',
#   '!',
#   '(',
#   '(',
#   'Pauvre',
#   'petit',
#   'moi',
#   '!'],
#  ['Cool', ',', "j'attends", 'de', 'nouvelles', 'mi', 'à', 'jour'],
#  ['Maintenant',
#   "c'est",
#   'un',
#   'job',
#   'sr.',
#   'Développeur',
#   'web',
#   '*',
#   'front-end',
#   '*',
#   'au',
#   'playboy'],
#  ['je', "l'ai", '!', 'Je', 'suis', 'un', 'tel', 'perdant'],
#  ['Omfg',
#   "c'est",
#   'tout',
#   '!',
#   'Je',
#   'vais',
#   'à',
#   'San',
#   'Francisco',
#   '!',
#   'Voyage',
#   'route',
#   'bébé',
#   '!',
#   '!',
#   '!'],
#  ['A',
#   'trouvé',
#   'une',
#   'nouvelle',
#   'glace',
#   'que',
#   "j'aime",
#   'manger',
#   'appelée',
#   'chocolat',
#   'au',
#   'poudrier',
#   ';',
#   'La',
#   'glycémie',
#   'se',
#   'sent',
#   'mieux',
#   'maintenant'],
#  ['Oui',
#   '...',
#   "d'une",
#   'manière',
#   'ou',
#   "d'une",
#   'autre',
#   ',',
#   'tous',
#   'me',
#   'vieux',
#   'fring',
#   'sont',
#   'dans',
#   "l'humeur",
#   'de',
#   'parler',
#   '...',
#   'je',
#   'démène',
#   'de',
#   'sujets',
#   'intimes',
#   'comme',
#   'un',
#   'fou',
#   ';',
#   ')'],
#  ['que',
#   'suis-je',
#   'en',
#   'train',
#   'de',
#   'faire',
#   '?',
#   'Essayant',
#   "d'abandonner",
#   'le',
#   'tabac',
#   "c'est",
#   'quoi',
#   '!',
#   'Grrrr',
#   '...',
#   'ce',
#   "n'est",
#   "qu'une",
#   'heure'],
#  ["aujourd'hui",
#   'est',
#   'un',
#   'bon',
#   'jour',
#   '.',
#   'Félicitations',
#   'à',
#   'tous',
#   'le',
#   'diplômés',
#   'où',
#   'sont-ils',
#   'le',
#   'party',
#   'à',
#   '!',
#   '?',
#   'Haha',
#   '.',
#   'Gnna',
#   'get',
#   'fckd',
#   'tonite',
#   '!',
#   'Lol',
#   'sike'],
#  ['Mes', 'chat', 'dort'],
#  ['Pouvez-vous',
#   "m'expliquer",
#   'ce',
#   'que',
#   'je',
#   'doi',
#   'faire',
#   'lors',
#   'de',
#   'la',
#   'modification',
#   'de',
#   'la',
#   'photo',
#   'de',
#   'compte',
#   '?',
#   "S'il",
#   'vous',
#   'plaît',
#   '........'],
#  ['Juste',
#   'une',
#   'mauvaise',
#   'expérience',
#   'avec',
#   'un',
#   'tweeter',
#   'et',
#   'devait',
#   'le',
#   'bloquer',
#   '.',
#   'Je',
#   'méfie',
#   'de',
#   'étrangers',
#   '.',
#   'Peut-être',
#   'que',
#   'je',
#   'ne',
#   'devrais',
#   'pa',
#   'être',
#   'si',
#   'amical'],
#  ['ce', "n'est", 'pa', 'drôle', '.'],
#  ['Travail', 'vectoriel', 'incroyable', 'de', 'machine56'],
#  ["D'accord",
#   ',',
#   "j'ai",
#   'passé',
#   'une',
#   'longue',
#   'journée',
#   ',',
#   'alors',
#   'je',
#   'pense',
#   "qu'il",
#   'est',
#   'temp',
#   'de',
#   'zzzzz',
#   '.',
#   'Merci',
#   'encore',
#   'pour',
#   'tout'],
#  ['Je',
#   'fausse',
#   'me',
#   'quiz',
#   'fb',
#   'pour',
#   'obtenir',
#   'de',
#   'bons',
#   'résultats',
#   '!',
#   'Apparemment',
#   ',',
#   'je',
#   'suis',
#   'chandler',
#   'sur',
#   'un',
#   'quiz',
#   ',',
#   "j'ai",
#   'un',
#   'iq',
#   "d'un",
#   'génie',
#   'sur',
#   'un',
#   'autre',
#   '.'],
#  ["Qu'est-ce", 'qui', 'ne', 'va', 'pa'],
#  ['Ce',
#   "n'est",
#   'pa',
#   'une',
#   'mauvaise',
#   'valeur',
#   'du',
#   'tout',
#   '!',
#   'Je',
#   'suis',
#   'malheureusement',
#   'totalement',
#   'coincé',
#   'pour',
#   'avoir',
#   'au',
#   'moins',
#   'le',
#   '32gb',
#   'de',
#   "l'arggghh"],
#  [':',
#   'Tsk',
#   'tsk',
#   ',',
#   'homme',
#   '.',
#   'Vous',
#   'demandez-vous',
#   'de',
#   'faire',
#   'de',
#   'choses',
#   'encore',
#   '?',
#   'Maintenant',
#   ',',
#   'vous',
#   'savez',
#   'encore',
#   'une',
#   'autre',
#   'raison',
#   'pour',
#   'laquelle',
#   'je',
#   'suis',
#   'un',
#   'idiot',
#   '.'],
#  ['Le',
#   'chat',
#   'sort',
#   'du',
#   'sac',
#   'sur',
#   'la',
#   'montagne',
#   'ce',
#   'matin',
#   '.',
#   'Pas',
#   'de',
#   'spoiler',
#   'ici',
#   '!',
#   'Détails',
#   'après',
#   'le',
#   'deuxième',
#   'service'],
#  ['Est',
#   'tombé',
#   'en',
#   'pluie',
#   'et',
#   'le',
#   'sox',
#   'ont',
#   'perdu',
#   '=',
#   '(',
#   '...',
#   'mais',
#   'nous',
#   'nous',
#   'somme',
#   'amusés',
#   'de',
#   'toute',
#   'façon'],
#  ['Ok',
#   'pour',
#   'de',
#   'boissons',
#   'avec',
#   'le',
#   'garçons',
#   '.',
#   'Bonne',
#   'nuit',
#   'twitter'],
#  [',',
#   'Tout',
#   'le',
#   'monde',
#   'obtient',
#   'un',
#   'nouvel',
#   'iphone',
#   'mais',
#   'moi',
#   ',',
#   'donnez-moi',
#   'un',
#   '!',
#   "j'en",
#   'ai',
#   'besoin',
#   '!'],
#  ['Bon', 'voyage', '-', 'et', 'bonjour'],
#  ['Mes', 'appareils', 'donnent', 'de', 'ulcères', '!'],
#  ['Haha',
#   '...',
#   'mon',
#   'chien',
#   'continue',
#   'de',
#   "m'appeler",
#   'son',
#   '«',
#   'maître',
#   '»',
#   '!',
#   'Ah',
#   '...',
#   'je',
#   'ne',
#   'suis',
#   'toujours',
#   'pa',
#   'sur',
#   'le',
#   'film',
#   '!',
#   '(',
#   ';'],
#  ['En',
#   'écoutant',
#   'le',
#   'nouvel',
#   'album',
#   'shikari',
#   ',',
#   'Common',
#   'Dreads'],
#  ['Ac', 'est', 'essentiel'],
#  ['Que', "c'est", 'il', 'passé', '?', '?', 'Tu', "m'as", 'inquiété', 'chérie'],
#  ['oui',
#   '.',
#   'Une',
#   'heure',
#   'de',
#   'plus',
#   'à',
#   'parcourir',
#   '.',
#   'Puis',
#   "l'église",
#   ',',
#   'puis',
#   'couche',
#   'moi-même',
#   '.',
#   'Je',
#   'vais',
#   'peut-être',
#   'passer',
#   'en',
#   'ligne',
#   'avant',
#   'de',
#   'travailler'],
#  ['Travaillé',
#   "aujourd'hui",
#   'dans',
#   'une',
#   'salle',
#   'de',
#   'gym',
#   'avec',
#   'flor',
#   '.'],
#  ['Je',
#   'ne',
#   'plaisante',
#   'pa',
#   "s'ils",
#   "n'ont",
#   'pa',
#   'peint',
#   'la',
#   'couleur',
#   'de',
#   'la',
#   'peau',
#   '...',
#   'pourtant',
#   '...',
#   'mais',
#   'je',
#   'veux',
#   'dire',
#   'qui',
#   'l',
#   "'",
#   'mi',
#   'en',
#   '2009',
#   '?'],
#  ['Haha',
#   "j'ai",
#   'un',
#   'ami',
#   'qui',
#   'vient',
#   'en',
#   'ville',
#   'ce',
#   'week-end',
#   'prochain',
#   ',',
#   'alors',
#   'je',
#   'par',
#   'le',
#   'prochain',
#   'samedi',
#   'matin',
#   '!'],
#  ['Oui',
#   ',',
#   'je',
#   "m'en",
#   'préoccupe',
#   'aussi',
#   '.',
#   "J'ai",
#   'eu',
#   'ce',
#   "qu'on",
#   'appelle',
#   'un',
#   '``',
#   'cirage',
#   'de',
#   'déjeuner',
#   "''",
#   '.',
#   'Pas',
#   'trop',
#   'agressif',
#   '.',
#   'Je',
#   'vais',
#   'vous',
#   'faire',
#   'savoir',
#   'comment',
#   'cela',
#   'se',
#   'passe',
#   '.'],
#  ['Triste',
#   "qu'il",
#   'n',
#   "'",
#   'aura',
#   'pa',
#   "d'interview",
#   'et',
#   'de',
#   'banque',
#   "d'état",
#   'de',
#   'kansa',
#   'en',
#   'raison',
#   'de',
#   'conflits',
#   'avec',
#   "l'école"],
#  ['Merci',
#   'pour',
#   'le',
#   'deux',
#   'suivants',
#   'vendredi',
#   '!',
#   'Gros',
#   'smootch',
#   '!',
#   'Je',
#   'vais',
#   'faire',
#   'le',
#   'mien',
#   'plus',
#   'tard'],
#  ['Je', 'veux', 'être', 'mon', 'précepteur', '?'],
#  ['Les',
#   'anges',
#   'et',
#   'le',
#   'démons',
#   'étaient',
#   'incroyables',
#   '...',
#   'un',
#   'regard',
#   'valable',
#   '!'],
#  ['Désolé', 'je', 'suis', 'endormi', 'sur', 'vous', '.'],
#  ['mauvais',
#   'jour',
#   '.',
#   'Ma',
#   'mère',
#   'déjà',
#   'confirmé',
#   "qu'elle",
#   'reviendrait',
#   'à',
#   'dubai',
#   'ce',
#   '5',
#   'juin',
#   '.',
#   "J'espère",
#   'que',
#   'le',
#   'temp',
#   "s'arrêtera",
#   '.'],
#  ['Le',
#   'premier',
#   'défi',
#   'de',
#   'compilation',
#   'de',
#   '30',
#   'jours',
#   'de',
#   'tsdc',
#   "s'est",
#   'terminé',
#   '.',
#   'À',
#   'en',
#   'juger',
#   'pour',
#   'commencer',
#   "aujourd'hui",
#   '.',
#   'Devrait',
#   'être',
#   'rapide',
#   '.',
#   'Quelques',
#   'entrées'],
#  ['Ne',
#   'peut',
#   'pa',
#   'attendre',
#   'quand',
#   'est',
#   'la',
#   'sortie',
#   'unique',
#   '&',
#   'lt',
#   ';',
#   '3',
#   '..',
#   'x'],
#  ['Vous', 'êtes', 'le', 'bienvenus', '.'],
#  ['Sunyi', 'sepi', '.', 'Pasal', ',', 'soeur', "n'est", 'pa', 'là', '.'],
#  ['Rien',
#   'de',
#   'pire',
#   'que',
#   "d'obtenir",
#   'votre',
#   'chambre',
#   'réservée',
#   '...',
#   'mais',
#   'ce',
#   "n'est",
#   'pa',
#   'ce',
#   'que',
#   'vous',
#   'avez',
#   'demandé',
#   '...',
#   'en',
#   'attendant',
#   'de',
#   'voir',
#   'comment',
#   'il',
#   'vont',
#   'le',
#   'réparer',
#   ',',
#   'ugh',
#   '!'],
#  ['Haha',
#   'ce',
#   "qu'il",
#   'fait',
#   '.',
#   'Je',
#   'sais',
#   ',',
#   'je',
#   'doi',
#   'écouter',
#   'un',
#   'essai',
#   'complet',
#   'sur',
#   "l'image",
#   'corporelle',
#   'et',
#   'la',
#   'santé',
#   ',',
#   'haha',
#   ',',
#   'que',
#   'faire',
#   'pour',
#   'le',
#   'chinois'],
#  ['Commence', 'mon', 'quart', 'de', 'clôture', '.', 'Cela', 'suce'],
#  ["C'est",
#   "l'heure",
#   'où',
#   "j'adore",
#   'prendre',
#   'de',
#   'douche',
#   ',',
#   'tourner',
#   'cette',
#   'merde',
#   '!'],
#  ["Aujourd'hui",
#   ',',
#   'je',
#   'suis',
#   'venu',
#   'voir',
#   'mon',
#   'beau-frère',
#   'et',
#   'sa',
#   'famille',
#   '.',
#   'bonne',
#   'journée',
#   'à',
#   'ce',
#   'jour',
#   '!',
#   'Le',
#   'travail',
#   'en',
#   'cour',
#   'peut',
#   'être',
#   'le',
#   'plan',
#   'pour',
#   "l'après-midi",
#   '.'],
#  ['Nous',
#   'avon',
#   'attaché',
#   'pour',
#   'le',
#   'premier',
#   '!',
#   '!',
#   '!',
#   '!',
#   'Alors',
#   'nous',
#   'avon',
#   'perdu',
#   'le',
#   'lol',
#   'tie',
#   'breaker',
#   ',',
#   'alors',
#   'nous',
#   'avon',
#   'obtenu',
#   'le',
#   'second',
#   '!'],
#  ['Nous',
#   'pension',
#   'que',
#   'vous',
#   'ne',
#   'suiviez',
#   'pa',
#   'le',
#   'maffei',
#   '.',
#   'Bon',
#   'de',
#   'savoir',
#   'que',
#   'nous',
#   'avon',
#   'eu',
#   'tort',
#   ',',
#   'car',
#   'il',
#   'se',
#   'met',
#   'rapidement',
#   'en',
#   'colère',
#   'et',
#   'est',
#   'difficile',
#   'à',
#   'apaiser'],
#  ['Regrette',
#   'instantanément',
#   'de',
#   'manger',
#   'de',
#   'la',
#   'mini',
#   'pizza',
#   '.',
#   "J'aurais",
#   'aimé',
#   'que',
#   "j'avais",
#   'le',
#   'temp',
#   'ce',
#   'matin',
#   'de',
#   'faire',
#   'le',
#   'déjeuner',
#   'à',
#   '1',
#   'milliard',
#   'de',
#   'kilomètres',
#   'plus',
#   'tard',
#   '?'],
#  ['Chillin', 'comme', 'un', 'polaire', 'dans', "l'Arctique"],
#  ['Jour', 'le', 'plus', 'stressant', 'de', 'tous', 'le', 'temp'],
#  ["J'ai", 'manqué', 'leur', 'idée', '♫', '~', '7gn8k'],
#  ['Voici',
#   'votre',
#   'page',
#   'Bebo',
#   'que',
#   "j'ai",
#   'faite',
#   'pour',
#   'vous',
#   ',',
#   "j'espère",
#   'que',
#   'vous',
#   'aimez'],
#  ['Je',
#   'viens',
#   'juste',
#   'de',
#   'réveiller',
#   '.',
#   'Je',
#   'ne',
#   'sais',
#   'pa',
#   'ce',
#   'que',
#   'je',
#   'vais',
#   'faire',
#   "aujourd'hui",
#   '.',
#   'Peut-être',
#   'laver',
#   'le',
#   'voitures',
#   'avec',
#   'de',
#   'la',
#   'paula',
#   'mais',
#   "c'est",
#   'plutôt',
#   'chaud',
#   ',',
#   'donc',
#   'je',
#   'ne',
#   'suis',
#   'pa',
#   'sûr',
#   '.',
#   'Rien',
#   'à',
#   'la',
#   'télé',
#   'maintenant',
#   '...',
#   'ugh',
#   '!'],
#  ['Vient',
#   'de',
#   'terminer',
#   'le',
#   'dîner',
#   'dans',
#   'un',
#   'joli',
#   'restaurant',
#   'le',
#   'long',
#   'de',
#   'la',
#   'route',
#   'tanjong',
#   'pagar',
#   '.',
#   'Bonne',
#   'nourriture',
#   ',',
#   'prix',
#   'raisonnable',
#   '.',
#   'ça',
#   'en',
#   'vaut',
#   'la',
#   'peine',
#   '!'],
#  ['Les',
#   'textes',
#   'de',
#   'Twitter',
#   'sont',
#   'en',
#   'cours',
#   'pour',
#   'la',
#   'journée',
#   '.',
#   'Envoyez-moi',
#   'un',
#   'message',
#   'si',
#   'vous',
#   'avez',
#   'besoin',
#   'de',
#   'moi',
#   'ou',
#   'voulez',
#   'juste',
#   'parler'],
#  ['Voulant',
#   'terminer',
#   'mon',
#   'combat',
#   ',',
#   'mais',
#   'le',
#   'client',
#   'doivent',
#   'se',
#   'rapprocher',
#   '.',
#   'Si',
#   'je',
#   'gagne',
#   ',',
#   'celebretory',
#   'taco',
#   'bell',
#   '.',
#   'Sinon',
#   ',',
#   'comfotaco',
#   'bell',
#   '.'],
#  ['Je',
#   'suis',
#   'fâché',
#   'par',
#   'son',
#   'travail',
#   '.',
#   'Merci',
#   'pour',
#   'le',
#   'conseil',
#   '(',
#   'trouvé',
#   'sur',
#   'votre',
#   'site',
#   ')',
#   '.',
#   'Elle',
#   'est',
#   'étonnante',
#   '.',
#   'Je',
#   'pense',
#   'que',
#   "c'est",
#   'pourquoi',
#   'vous',
#   'avez',
#   'gagné',
#   'un',
#   'billet',
#   ';',
#   'Pour',
#   'nous',
#   'connecter',
#   '.'],
#  ['Oui',
#   ',',
#   'nous',
#   'devon',
#   'terminer',
#   'certains',
#   'commentaires',
#   'afin',
#   'que',
#   'nous',
#   'puissions',
#   'donner',
#   'plus',
#   'de',
#   'code',
#   'promotionnels',
#   ':',
#   '...'],
#  ['Bien',
#   ',',
#   'le',
#   'nouveaux',
#   'cuirs',
#   'sont',
#   'un',
#   'régal',
#   '.',
#   'Les',
#   'bébés',
#   'peuvent',
#   'avoir',
#   'besoin',
#   'de',
#   'se',
#   'briser',
#   'en',
#   'un',
#   'peu',
#   '.',
#   'Maintenant',
#   ',',
#   'posez',
#   'le',
#   'ba',
#   'en',
#   'arrière',
#   'et',
#   'le',
#   'vélo',
#   'ne',
#   'démarre',
#   'pa',
#   '.',
#   'Travailler',
#   'en',
#   'voiture',
#   '2',
#   'mardi'],
#  ['Sur', 'le', 'chemin', 'amyrah', 'zandra', 'home'],
#  ['Aller', 'au', 'poney', 'rose'],
#  ['Merci', 'najwa', '....', 'c', 'u', 'dans', '2', 'semaines', '.'],
#  ['Chicagopersonals',
#   'si',
#   'vous',
#   'avez',
#   'plus',
#   'de',
#   '25',
#   'an',
#   ',',
#   'venez',
#   "m'aimer",
#   '(',
#   'south',
#   'chicagoland',
#   ')',
#   '27yr',
#   ':',
#   'je',
#   'suis',
#   'attentionné',
#   ',',
#   'goa',
#   '..'],
#  ['À', 'quelle', 'heure', 'finis-tu', "l'école", 'demain'],
#  ['Est', 'prêt', 'pour', 'le', 'voyage', 'de', 'me', 'fille', '!', '!'],
#  ['Sur',
#   'une',
#   'note',
#   'sérieuse',
#   ',',
#   'je',
#   'ne',
#   'sais',
#   'pa',
#   'où',
#   'est',
#   'mon',
#   'copain',
#   'ou',
#   'si',
#   'nous',
#   'somme',
#   'encore',
#   'ensemble',
#   '...',
#   'je',
#   "n'ai",
#   'pa',
#   'entendu',
#   'parler',
#   'de',
#   'lui',
#   'depuis',
#   'vendredi',
#   'dernier',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['Je',
#   'suis',
#   'en',
#   'train',
#   'de',
#   'terminer',
#   'maintenant',
#   '.',
#   ':',
#   '/',
#   'Je',
#   'doi',
#   'faire',
#   'le',
#   'contour',
#   'et',
#   'la',
#   'biographie',
#   'réelle',
#   '.'],
#  ['Je', 'veux', 'être', 'Beyoncé', 'maintenant', '.'],
#  ['Merci', 'chéri'],
#  ['sound', 'de-lish', '.'],
#  ['Ont',
#   'eu',
#   'seulement',
#   '1',
#   'heure',
#   'de',
#   'sommeil',
#   'mais',
#   'je',
#   'suis',
#   'très',
#   'nerveuse',
#   'mais',
#   'froide'],
#  ["J'ai", 'oublié', 'la', 'question'],
#  ['Elle',
#   'donne',
#   'une',
#   'pilule',
#   "d'énergie",
#   ',',
#   'puis',
#   "m'abandonne",
#   'au',
#   'pay',
#   'de',
#   'rêves',
#   '!',
#   'Hufffff'],
#  ['mauvais', 'jour'],
#  ['A', 'eu', 'un', 'excellent', 'dîner', 'et', 'est', 'allé', 'au', 'lit'],
#  ['Une',
#   'heure',
#   '35',
#   'minute',
#   'jusqu',
#   "'",
#   'à',
#   "l'iphone",
#   '3gs',
#   '.',
#   'Dois-je',
#   'acheter',
#   '?',
#   'Ou',
#   'bâton',
#   'La',
#   'principale',
#   'chose',
#   'dont',
#   "j'ai",
#   'besoin',
#   'est',
#   'le',
#   '32gb',
#   '.'],
#  ['La',
#   'fille',
#   'qui',
#   'eu',
#   'le',
#   'cri',
#   'de',
#   'ddub',
#   'est',
#   'un',
#   'coucou',
#   '.',
#   'Vous',
#   'ne',
#   'voudriez',
#   'pa',
#   "l'association",
#   '.',
#   'croyez-moi',
#   '.'],
#  ['Ne',
#   'peut',
#   'pa',
#   'arrêter',
#   'de',
#   'regarder',
#   'neorago',
#   'sur',
#   'youtube',
#   '...',
#   'une',
#   'autre',
#   'performance',
#   'chaude',
#   'de',
#   'me',
#   'garçons',
#   '!'],
#  ['Mes',
#   'oreilles',
#   'sont',
#   'démangeaisons',
#   'à',
#   "l'intérieur",
#   '.',
#   'Son',
#   'ennuyeux',
#   'meee'],
#  ['Mais',
#   "j'ai",
#   'un',
#   'peu',
#   'peur',
#   'de',
#   'marcher',
#   'dans',
#   'cette',
#   'rue',
#   'dans',
#   'ce',
#   'ski',
#   '...',
#   'il',
#   'un',
#   'homme',
#   'sur',
#   'tous',
#   'le',
#   'coin',
#   '.',
#   "Quelqu'un",
#   "m'appelle"],
#  ['Est',
#   'allé',
#   '2',
#   'fois',
#   'il',
#   'quelque',
#   'temp',
#   '...',
#   "j'étais",
#   'tellement',
#   'seul'],
#  ['Pourquoi', 'une', 'californie', 'si', 'froide', '?'],
#  ['Heureusement',
#   'après',
#   ',',
#   'un',
#   'tagine',
#   "n'est",
#   'pa',
#   'un',
#   'résultat'],
#  ['Je', 'veux', 'partir', 'aussi', 'lenny', '....', '?', '~', '7cydo'],
#  ['Est',
#   'ridiculement',
#   'chaud',
#   'dans',
#   'son',
#   'appartement',
#   '...',
#   'mais',
#   'je',
#   'ne',
#   'peux',
#   'pa',
#   'attendre',
#   'ce',
#   'week-end'],
#  ['hey', 'ce', 'qui', 'se', 'passe'],
#  ['Poulet', 'frit', 'du', 'sud', '!', 'Miam', '!'],
#  ['Si', 'heureux', "d'avoir", 'un', 'cerveau'],
#  ['Pour',
#   'le',
#   'film',
#   ',',
#   'mais',
#   'peut-être',
#   'que',
#   'je',
#   'suis',
#   'un',
#   'peu',
#   'génial',
#   '.'],
#  ['Ah',
#   'bien',
#   ',',
#   'même',
#   'si',
#   'je',
#   'ne',
#   'devais',
#   'pa',
#   'passer',
#   'devant',
#   'vous',
#   'pour',
#   'devenir',
#   'créatif',
#   'avec',
#   'le',
#   'moggy',
#   ',',
#   'la',
#   'manche',
#   ',',
#   'le',
#   'chat',
#   ',',
#   'la',
#   'manette',
#   'de',
#   'chat',
#   'mmm',
#   '....',
#   'ici',
#   'pus',
#   'pus',
#   '.'],
#  ['Prêt', 'à', 'marcher', 'et', 'son', 'seul', '1:24', '....'],
#  ['Lol',
#   'je',
#   'suis',
#   'jus',
#   'sayin',
#   'yall',
#   'toujours',
#   'gt',
#   'tha',
#   '411',
#   'lol'],
#  ['Bonjour', 'jayda', 'belle'],
#  ['Donc',
#   'je',
#   'suis',
#   'arrivé',
#   'à',
#   'la',
#   'conclusion',
#   ',',
#   'jacob',
#   'se',
#   'transforme',
#   'en',
#   'joli',
#   'loup-garou',
#   ',',
#   'sa',
#   'couleur',
#   'de',
#   'fourrure',
#   'est',
#   'si',
#   'magnifique',
#   '!',
#   '!'],
#  ['Avez-vous', 'préparé', 'la', 'bannière', '110', 'x', '80px', '?'],
#  ['Hey',
#   'lissette',
#   'comment',
#   'vas-tu',
#   '?',
#   'Tout',
#   'le',
#   'plaisir',
#   'était',
#   'pour',
#   'moi'],
#  ['Bonjour',
#   '...',
#   'je',
#   'suis',
#   'nouveau',
#   'ici',
#   '...',
#   'enseigne-moi',
#   'à',
#   'utiliser',
#   'ce',
#   'genre',
#   'de',
#   'site',
#   '...'],
#  ["c'est",
#   'une',
#   'bonne',
#   'idée',
#   '.',
#   'Le',
#   'kilo',
#   'serait',
#   'un',
#   'grand',
#   'garde',
#   'du',
#   'corp',
#   ',',
#   'personne',
#   'ne',
#   'dérangerait',
#   '.',
#   "S'il",
#   'vous',
#   'plaît',
#   ',',
#   'dites-lui',
#   'de',
#   'regarder',
#   'mon',
#   'do',
#   '...'],
#  ['Est-ce',
#   'que',
#   "l'une",
#   'de',
#   'chansons',
#   'de',
#   'votre',
#   'couverture',
#   '?',
#   "C'est",
#   'une',
#   'excellente',
#   'chanson',
#   'par'],
#  ['Non', 'disponible', 'dans', 'mon', 'pay'],
#  ['Avez-vous',
#   'déjà',
#   'pris',
#   'une',
#   'de',
#   'voile',
#   'de',
#   "l'opéra",
#   '?',
#   "J'ai",
#   'essayé',
#   'la',
#   'nuit',
#   'dernière',
#   'avec',
#   'petite',
#   'caméra',
#   ',',
#   'mais',
#   'je',
#   "n'ai",
#   'pa',
#   'trop',
#   'marché',
#   '.'],
#  ['Gardez',
#   'à',
#   "l'esprit",
#   "qu'il",
#   'été',
#   'pris',
#   'avec',
#   'mon',
#   'téléphone',
#   ',',
#   'il',
#   'ne',
#   'le',
#   'fait',
#   'pa',
#   'justice'],
#  ['Sortir',
#   'à',
#   'la',
#   'maison',
#   'un',
#   'peu',
#   'puis',
#   'aller',
#   'à',
#   'sam-hanthas',
#   'open',
#   'house',
#   '!'],
#  ['Hablame', 'oh', 'bien', ',', 'il', 'toujours', "d'autres"],
#  ['Merci',
#   'pour',
#   'le',
#   'conseil',
#   '...',
#   "j'ai",
#   'effectivement',
#   'entendu',
#   'ça',
#   '.',
#   'Mais',
#   ',',
#   'parfois',
#   ',',
#   'je',
#   'sen',
#   'que',
#   'je',
#   'parle',
#   'tant',
#   'de',
#   'gen',
#   'vont',
#   'prendre',
#   'mal',
#   'de',
#   'moi',
#   'lol'],
#  ['Oh',
#   'bien',
#   ',',
#   'il',
#   'ont',
#   'encore',
#   'une',
#   'chance',
#   'la',
#   'prochaine',
#   'fois'],
#  ['Correction', ':', 'besoin', 'de', '6000'],
#  ['Vient',
#   "d'arriver",
#   'dans',
#   'le',
#   'hampton',
#   'et',
#   'il',
#   'pleut',
#   '...',
#   '!',
#   '!'],
#  ['Moi',
#   'n',
#   'mon',
#   'bf',
#   'sure',
#   "s'est",
#   'plaindé',
#   'de',
#   "l'intrigue",
#   'que',
#   'nous',
#   'aimons',
#   'terminator',
#   '2',
#   'mieux',
#   '.',
#   'Mais',
#   "c'était",
#   'correct',
#   '.',
#   'Je',
#   'lui',
#   'ai',
#   'donné',
#   'un',
#   '8/10'],
#  ['Omfg',
#   '!',
#   'Demi',
#   'était',
#   'en',
#   'Allemagne',
#   '?',
#   'Aaaaaaah',
#   "quelqu'un",
#   'tue'],
#  ['Oh',
#   'oui',
#   ',',
#   'je',
#   'viens',
#   'de',
#   'recevoir',
#   'coke',
#   '-',
#   'zéro',
#   '400',
#   'billet',
#   'je',
#   'suis',
#   'tellement',
#   'excité'],
#  ['Sur',
#   'le',
#   'chemin',
#   'du',
#   'putain',
#   'de',
#   'zoo',
#   ',',
#   'je',
#   'souhaite',
#   'que',
#   'mon',
#   'mari',
#   'soit',
#   'avec',
#   'moi',
#   '.',
#   'Jamais',
#   'amusant',
#   'sans',
#   'lui',
#   '.'],
#  ['Hey',
#   'hey',
#   ',',
#   "j'espère",
#   'vraiment',
#   'que',
#   'tu',
#   "m'inscris",
#   '!',
#   '&',
#   'Lt',
#   ';',
#   '3',
#   'rachael'],
#  ['Eh',
#   'bien',
#   ',',
#   'ce',
#   "n'est",
#   'pa',
#   'sympa',
#   "qu'il",
#   'ait',
#   'bloqué',
#   'lol',
#   'bien',
#   'pour',
#   'que',
#   'tu',
#   'tweet',
#   'encore',
#   '!'],
#  ["C'est",
#   'un',
#   'jeu',
#   'tellement',
#   'triste',
#   'que',
#   'je',
#   'ne',
#   'pense',
#   'pa',
#   'avoir',
#   'pu',
#   'le',
#   'faire',
#   'en',
#   'classe',
#   ',',
#   "j'aurais",
#   'ressemblé',
#   'à',
#   'une',
#   'véritable',
#   'émotion',
#   'émotionnelle',
#   '...'],
#  ['A',
#   'décidé',
#   "d'obtenir",
#   'un',
#   'itouch',
#   '32gb',
#   'et',
#   'un',
#   'ihome',
#   'au',
#   'lieu',
#   "d'un",
#   'xbox',
#   '360',
#   'pour',
#   'mon',
#   'anniversaire',
#   '.',
#   'Plus',
#   'de',
#   'temp',
#   'pour',
#   'runescape',
#   'de',
#   'cette',
#   'façon',
#   '.'],
#  ["J'ai",
#   'appelé',
#   'le',
#   'magasin',
#   'de',
#   'CD',
#   '...',
#   'et',
#   'il',
#   "m'ont",
#   'dit',
#   'que',
#   'lvatt',
#   'venait',
#   'peut-être',
#   'la',
#   'semaine',
#   'prochaine',
#   ',',
#   'je',
#   'veux',
#   'pleurer',
#   'maintenant',
#   '...',
#   'fml',
#   '.',
#   'Fml',
#   '.',
#   'Fml',
#   '.',
#   'Fml',
#   '.',
#   'Fml',
#   '.',
#   'Fml',
#   '.'],
#  ["J'ai",
#   "l'impression",
#   'de',
#   'boucler',
#   'me',
#   'cheveux',
#   "aujourd'hui",
#   '...',
#   'mais',
#   'alors',
#   'je',
#   'suis',
#   'paresseux'],
#  ['Fait', 'son', 'foodtecc'],
#  ["J'ai",
#   'entendu',
#   'dire',
#   'que',
#   'le',
#   'temp',
#   'est',
#   'en',
#   'vrac',
#   'dans',
#   'le',
#   'bouffées',
#   'torrentielles',
#   '.',
#   'Il',
#   'est',
#   'parfait',
#   'dans',
#   'le',
#   'palmes',
#   '.',
#   'Été',
#   '&',
#   'lt',
#   ';',
#   '3'],
#  ['Était',
#   'tellement',
#   'content',
#   'de',
#   'partager',
#   "l'accomplissement",
#   'de',
#   'soeur',
#   ',',
#   'même',
#   'si',
#   'elle',
#   'nous',
#   'nourrissait',
#   'trop',
#   'de',
#   'nourriture',
#   '.',
#   "C'était",
#   'délicieux',
#   'cependant',
#   '.'],
#  ['La',
#   'douche',
#   "'",
#   'fait',
#   'sentir',
#   'mieux',
#   'de',
#   'préparer',
#   'à',
#   'la',
#   'vie',
#   'sociale'],
#  ['A',
#   'réussi',
#   'à',
#   'bourrer',
#   'son',
#   'ventre',
#   '.',
#   ':',
#   '&',
#   'Amp',
#   ';',
#   '*',
#   'Veut',
#   'manger',
#   'plus',
#   '*'],
#  ['Vient',
#   'de',
#   'rentrer',
#   'à',
#   'la',
#   'maison',
#   '.',
#   'Le',
#   'gin',
#   'et',
#   'le',
#   'tonique',
#   'ont',
#   'tellement',
#   'baissé',
#   '...',
#   'ont',
#   'dansé',
#   'avec',
#   'me',
#   'chiennes',
#   ',',
#   'mais',
#   'ont',
#   'dû',
#   'sauter',
#   'le',
#   'dernier',
#   'après-midi',
#   'de',
#   'sortie'],
#  ['Dimanche',
#   'du',
#   'golf',
#   '...',
#   'vérifier',
#   '.',
#   'Tuyau',
#   'de',
#   'drainage',
#   'soutenu',
#   'dans',
#   'le',
#   'sous-sol',
#   '...',
#   'vérifier',
#   '.',
#   'Quelle',
#   'façon',
#   'de',
#   'finir',
#   'un',
#   'week-end'],
#  ['Je',
#   "n'ai",
#   'jamais',
#   'eu',
#   'de',
#   'chance',
#   "d'obtenir",
#   'le',
#   'jb',
#   'pour',
#   'tweet',
#   '/',
#   'myspace',
#   'ou',
#   'livechat',
#   'moi'],
#  ["j'imagine", '.', 'Il', "'", 'volé', 'une', 'voiture', '.'],
#  ['Cape',
#   'de',
#   'pluie',
#   'type',
#   'de',
#   'journée',
#   'autour',
#   'de',
#   "l'usine",
#   'ewa-marine',
#   'en',
#   'Allemagne',
#   'du',
#   'Sud',
#   '...',
#   'mais',
#   '...',
#   'pour',
#   'tous',
#   'le',
#   'dslrs'],
#  ['Au',
#   'lit',
#   'se',
#   'sentant',
#   'comme',
#   'une',
#   'merde',
#   'après',
#   'avoir',
#   'séjourné',
#   'pour',
#   'regarder',
#   "l'ufc",
#   '!',
#   '!',
#   'besoin',
#   'de',
#   'plus',
#   'de',
#   'sommeil',
#   '!',
#   '!',
#   'mal',
#   '!'],
#  ['Examens', 'ewww'],
#  ['Ce',
#   'dont',
#   "j'ai",
#   'vraiment',
#   'besoin',
#   ',',
#   "c'est",
#   'une',
#   'plage',
#   '!'],
#  ['Tellement',
#   'excité',
#   '.',
#   'Planifier',
#   'une',
#   'aventure',
#   'européenne',
#   'con',
#   'mi',
#   'amiga',
#   'becca'],
#  ['Pluie',
#   'arrive',
#   'enfin',
#   ',',
#   'drat',
#   '.',
#   'Devinez',
#   'que',
#   'cela',
#   'signifie',
#   'que',
#   'nous',
#   'devrons',
#   'faire',
#   'du',
#   'pique-nique',
#   'dans',
#   'le',
#   'salon',
#   'au',
#   'lieu',
#   'de',
#   'passer',
#   'au',
#   'wolftrap',
#   'tonite',
#   '.'],
#  ['Prier',
#   'pour',
#   'le',
#   'soleil',
#   '-',
#   'ne',
#   'pa',
#   'jouer',
#   'à',
#   'la',
#   'mode',
#   ',',
#   'peinture',
#   'et',
#   'pompier',
#   'sam',
#   'en',
#   'boucle',
#   '-',
#   'le',
#   'châteaux',
#   'de',
#   'sable',
#   'et',
#   'le',
#   'glaces',
#   'sont',
#   'beaucoup',
#   'plus',
#   'amusants'],
#  ['Jeté',
#   'et',
#   'tourné',
#   'toute',
#   'la',
#   'sooooooooo',
#   'fatigué',
#   '.',
#   'Ne',
#   'voulant',
#   'pa',
#   'être',
#   'au',
#   'travail',
#   '.'],
#  ["J'ai",
#   'donc',
#   'voulu',
#   'que',
#   'mon',
#   'restaurant',
#   'chinois',
#   'local',
#   'porte',
#   'tout',
#   'le',
#   'tofu'],
#  ['veut', 'sleeeeep', '!', '!', 'si', 'fatigué'],
#  ['Park',
#   '+',
#   'amis',
#   '+',
#   'fam',
#   '+',
#   'mall',
#   '(',
#   'tanforan',
#   ')',
#   '+',
#   'jollibee',
#   '+',
#   'pierre',
#   'froide',
#   '=',
#   'satisfaction',
#   'complète'],
#  ['La',
#   'mauvaise',
#   'chance',
#   'nous',
#   'désavoue',
#   "d'avoir",
#   'de',
#   'belle',
#   'choses',
#   '.'],
#  ['Ow',
#   ',',
#   'le',
#   'casquettes',
#   'de',
#   'la',
#   'faute',
#   'ont',
#   'mangé',
#   'mon',
#   'âme',
#   ',',
#   'et',
#   'paof',
#   'mon',
#   'visage'],
#  ['...',
#   'mais',
#   'alors',
#   ',',
#   'qui',
#   'suis-je',
#   'pour',
#   'parler',
#   'avec',
#   'cette',
#   'écharpe',
#   'à',
#   'la',
#   'remorque'],
#  ['Hihihihihi',
#   ')',
#   ')',
#   ')',
#   'vous',
#   "n'êtes",
#   'jamais',
#   'perdu',
#   'pour',
#   'une',
#   'réponse',
#   'mon',
#   'cowboy',
#   'somnambule'],
#  ['Bien',
#   'voir',
#   'ce',
#   'personnes',
#   'au',
#   'moins',
#   'savaient',
#   'que',
#   "c'était",
#   'un',
#   'véritable',
#   'espace',
#   'de',
#   'stationnement',
#   'contrairement',
#   'à',
#   'certaines',
#   'personnes',
#   'que',
#   'je',
#   'connais',
#   '...',
#   'calculatrices',
#   'annd',
#   ',',
#   'imprimantes',
#   ',',
#   'etc',
#   '.'],
#  ['Non', ',', 'je', 'ne', 'le', 'crois', 'pa'],
#  ['à',
#   'M',
#   '!',
#   '!',
#   'Je',
#   'suis',
#   'allé',
#   'sur',
#   'le',
#   'trébuchement',
#   ',',
#   'et',
#   'je',
#   'ne',
#   'pouvais',
#   'pa',
#   'trouver',
#   'comment',
#   'supprimer',
#   'le',
#   'animaux',
#   ',',
#   'alors',
#   'je',
#   'pensais',
#   'être',
#   'courageux',
#   ',',
#   'et',
#   'le',
#   'premier',
#   'trébucher',
#   'était',
#   'un',
#   'requin'],
#  ['Malheureusement',
#   'sur',
#   'mon',
#   'chemin',
#   'de',
#   'retour',
#   'à',
#   'la',
#   'maison',
#   '4rm',
#   'tampa',
#   '.',
#   'Je',
#   'ne',
#   'veux',
#   'pa',
#   'aller',
#   'au',
#   'Bacc',
#   '!',
#   '!',
#   '!'],
#  ['Un',
#   'peu',
#   'ivre',
#   'après',
#   'avoir',
#   'bu',
#   'à',
#   "l'école",
#   '...',
#   'dernier',
#   'jour',
#   '!'],
#  ['En',
#   'regardant',
#   'le',
#   'mec',
#   'avec',
#   'le',
#   'poteau',
#   'dans',
#   'son',
#   'œil',
#   '.'],
#  ['Le',
#   'constructeur',
#   'est',
#   'tellement',
#   'mignon',
#   'avec',
#   'le',
#   'chat',
#   'aw',
#   '!'],
#  ['Est',
#   'triste',
#   '&',
#   'amp',
#   ';',
#   'amp',
#   ';',
#   'Je',
#   'vais',
#   'regarder',
#   'tbbt',
#   '(',
#   "j'espère",
#   ')',
#   'animer',
#   '♥'],
#  ["C'est",
#   'tellement',
#   'bouleversant',
#   '.',
#   'Elle',
#   'et',
#   'Ryan',
#   "n'ont",
#   'jamais',
#   'eu',
#   'la',
#   'chance',
#   'de',
#   'se',
#   'marier'],
#  ['3', 'jours', ',', 'je', 'vais', 'au', 'festival', 'du', 'film', 'Tribeca'],
#  ['Essayez', "d'trouver", 'une', 'application', 'mobile', 'qui', 'fonctionne'],
#  ['Woooo',
#   'fait',
#   'le',
#   'travail',
#   'pour',
#   'le',
#   'week-end',
#   ',',
#   "j'aime",
#   'avoir',
#   'weekend',
#   'hors'],
#  ['Et',
#   'maintenant',
#   ',',
#   'je',
#   'vais',
#   'au',
#   'lit',
#   'dire',
#   '...',
#   'une',
#   'copie',
#   'pour',
#   'une',
#   'autre',
#   'nouvelle',
#   'niche',
#   'est',
#   'dans',
#   'la',
#   'boîte',
#   '...',
#   'je',
#   'retrouve',
#   'dans',
#   "l'écriture",
#   '&',
#   'groot',
#   '&',
#   'quot',
#   ';',
#   'dernièrement'],
#  ['Tout',
#   'ce',
#   'que',
#   'je',
#   'peux',
#   'dire',
#   "c'est",
#   'deux',
#   'mot',
#   '...',
#   'ce',
#   'soir',
#   'était',
#   'délicieux'],
#  ['Oh',
#   'oui',
#   ',',
#   'le',
#   'croisement',
#   ',',
#   'puis',
#   'le',
#   'gamin',
#   'de',
#   'moe',
#   "'s",
#   'bc',
#   'mangent',
#   'gratuitement',
#   '...',
#   'ça',
#   'semble',
#   'avoir',
#   'décidé'],
#  ['Ça', "l'air", 'très', 'bien'],
#  ['moi',
#   'aussi',
#   '.',
#   "J'aimerais",
#   "n'avoir",
#   'pa',
#   'lu',
#   'le',
#   'règlement',
#   'londonien'],
#  ['Lol',
#   'je',
#   'suppose',
#   'que',
#   'mon',
#   'bufffff',
#   'vous',
#   'donne',
#   'de',
#   'accessoires',
#   'pour',
#   'avoir',
#   '90',
#   '%',
#   'de',
#   'son',
#   'test'],
#  ['Yall',
#   'continuez',
#   ',',
#   'je',
#   'pense',
#   'que',
#   "l'imma",
#   'le',
#   'lance',
#   'avec',
#   'mon',
#   'mec',
#   '2',
#   'nuits'],
#  ['Est',
#   'seul',
#   'ici',
#   'au',
#   'café',
#   'de',
#   'kublai',
#   '.',
#   'Je',
#   'demande',
#   'où',
#   'sont',
#   'le',
#   'autres',
#   'organisateurs'],
#  ['En',
#   'élevant',
#   'et',
#   'en',
#   "l'aimant",
#   '...',
#   "n'ont",
#   'pa',
#   'fumé',
#   'depuis',
#   'si',
#   'longtemps'],
#  ['L4d',
#   'est',
#   'un',
#   'jeu',
#   'formidable',
#   ',',
#   'plus',
#   'tard',
#   ',',
#   'je',
#   'serais',
#   'ravi',
#   'de',
#   'rejoindre',
#   'si',
#   'vous',
#   'avez',
#   'besoin',
#   "d'un",
#   'autre',
#   'joueur'],
#  ['Claqué',
#   'la',
#   'porte',
#   'de',
#   "l'avant",
#   'alors',
#   'que',
#   "j'étais",
#   'entré',
#   'dans',
#   'la',
#   'voiture',
#   ',',
#   "j'étais",
#   'super',
#   'pissé',
#   'et',
#   'brisé',
#   'le',
#   'pare-brise',
#   '.',
#   'Incroyable',
#   ',',
#   'sinon',
#   ',',
#   "j'ai",
#   '2',
#   'salaire',
#   '4'],
#  ['Je',
#   'ne',
#   'veux',
#   'pa',
#   'voir',
#   'ton',
#   'visage',
#   'moche',
#   'internet',
#   'est',
#   'juste'],
#  ['Peut-être',
#   'est-ce',
#   'un',
#   'signe',
#   'pour',
#   'moi',
#   'de',
#   'ne',
#   'pa',
#   'faire',
#   'de',
#   'magasin',
#   'puisque',
#   'la',
#   'comp',
#   'de',
#   'mère',
#   'agit',
#   'de',
#   'manière',
#   'extrêmement',
#   'spéciale'],
#  ['Abonnez-vous', 'à', 'page', 'youtube', "s'il", 'vous', 'plaît'],
#  ['Chantait',
#   'pendant',
#   'toute',
#   'la',
#   'leçon',
#   "d'anglais",
#   ',',
#   "c'était",
#   'drôle',
#   '.',
#   'Et',
#   'également',
#   'joué',
#   'au',
#   'football',
#   "aujourd'hui"],
#  ['Mon', 'chat', 'gratté', 'mon', 'visage', '.'],
#  ['Aller',
#   'magique',
#   '...',
#   'nous',
#   'allons',
#   'battre',
#   'le',
#   'twit',
#   'de',
#   'lakers',
#   'lolz'],
#  ['Hou',
#   'la',
#   'la',
#   '!',
#   'Beaucoup',
#   'de',
#   'nouveaux',
#   'testeurs',
#   'bêta',
#   'ce',
#   'week-end',
#   '.',
#   "J'espère",
#   'que',
#   'le',
#   'gen',
#   "s'amusent",
#   '...',
#   '(',
#   'et',
#   'signalent',
#   'de',
#   'bug',
#   ')'],
#  ['Chatta',
#   'avec',
#   'ta',
#   'tante',
#   'où',
#   'est-elle',
#   '?',
#   'Oo',
#   'ic',
#   ',',
#   'ont-ils',
#   'utilisé',
#   'cosu',
#   '?',
#   'Hm',
#   ',',
#   'lyl',
#   'idk',
#   'wht',
#   '2',
#   '...',
#   'ennuyé'],
#  ['Nikka',
#   '.',
#   'Haha',
#   '.',
#   'Je',
#   'pensais',
#   'que',
#   'magkita',
#   'ta',
#   '?',
#   'Awww',
#   '.',
#   'Ma',
#   'miss',
#   'namo',
#   'imo',
#   'kabuang',
#   '!',
#   'Hapit',
#   'na',
#   'skool',
#   '.',
#   'Ana',
#   'ka',
#   '.',
#   'Briser',
#   'no',
#   'cœurs',
#   '.',
#   'hahaha',
#   '.'],
#  ['Noirs', 'au', 'Space', 'Party', 'lol'],
#  ['Passe', 'une', 'bonne', 'journée', '!', 'Anniversaire', 'girrrl'],
#  ['Quoi',
#   "qu'il",
#   'en',
#   'soit',
#   'Mieux',
#   'que',
#   'le',
#   'mien',
#   '...',
#   'un',
#   'peu',
#   '?',
#   'Roarrr',
#   ',',
#   'fmlllllllll',
#   '!',
#   'Karman',
#   '=',
#   'bio',
#   'fail',
#   '.',
#   'Non',
#   ',',
#   'faites',
#   'échouer',
#   "l'épopée",
#   'scientifique',
#   '.'],
#  ['Cousin',
#   'disparu',
#   'ont',
#   'eu',
#   'un',
#   'beau',
#   'week-end',
#   ',',
#   'retour',
#   'à',
#   'la',
#   'révision',
#   'maintenant',
#   'ah',
#   'bien',
#   'doit',
#   'être',
#   'fait',
#   '!'],
#  ["Aujourd'hui", ',', 'ce', "n'est", 'pa', 'un', 'bon', 'début', '.'],
#  ['Peut',
#   'entendre',
#   'le',
#   'tonnerre',
#   '!',
#   '!',
#   '!',
#   '&',
#   'Lt',
#   ';',
#   '3',
#   'plus',
#   "s'il",
#   'vous',
#   'plait',
#   '!'],
#  ["Aujourd'hui",
#   ',',
#   'ce',
#   'serum',
#   'un',
#   'pur',
#   'travail',
#   'à',
#   '100',
#   '%',
#   '!',
#   'Non',
#   'msn',
#   ',',
#   'fb',
#   'et',
#   'twitter',
#   '!',
#   'après',
#   'ça'],
#  ['Nouveau',
#   'chanteur',
#   '?',
#   "J'aurais",
#   'aimé',
#   'savoir',
#   'à',
#   'ce',
#   'sujet'],
#  ['2525', ':', 'dank', 'je', 'wel', ',', 'en', 'besoin'],
#  ['Je', 'veux', 'aller', 'à', 'la', 'piscine'],
#  ['Je',
#   'doi',
#   'seulement',
#   'regarder',
#   'm',
#   'elseas',
#   'face',
#   'pendant',
#   'cinq',
#   'jours',
#   'de',
#   'plus',
#   'deux',
#   'an',
#   'avec',
#   'cette',
#   'femme',
#   'était',
#   'trop',
#   '!'],
#  ['À',
#   'moins',
#   'que',
#   'vous',
#   'ne',
#   'vouliez',
#   'le',
#   'faire',
#   'deux',
#   'jours',
#   'de',
#   'suite',
#   ',',
#   'nous',
#   'devrons',
#   'continuer',
#   'un',
#   'autre',
#   'jour',
#   '.'],
#  ['Je',
#   'suis',
#   'tellement',
#   'fatigué',
#   "d'un",
#   'mauvais',
#   'jour',
#   'après',
#   "l'autre",
#   '...',
#   "j'abandonne",
#   '...'],
#  ['Oh',
#   'wow',
#   '!',
#   'Ceux-ci',
#   'sont',
#   'bons',
#   '!',
#   '!',
#   '&',
#   'Amp',
#   ';',
#   '&',
#   'amp',
#   ';',
#   "c'est",
#   'une',
#   'chanson',
#   '!',
#   'Vous',
#   'devriez',
#   'jouer',
#   'un',
#   'jour',
#   'et',
#   'le',
#   'mettre',
#   'sur',
#   'youtube',
#   'ou',
#   'quelque',
#   'chose',
#   'comme',
#   'ça',
#   '?',
#   'Haha',
#   '.'],
#  ['Personne', "d'autre", "n'est", 'éveillé'],
#  ['Vraiment',
#   'douloureux',
#   '.',
#   "j'ai",
#   'besoin',
#   "d'un",
#   'massage',
#   '.',
#   'Comme',
#   '4real'],
#  ['Je',
#   'ne',
#   'sais',
#   'pa',
#   'pourquoi',
#   ',',
#   'mais',
#   'il',
#   'n',
#   "'",
#   'pa',
#   'envoyé',
#   'mon',
#   'dernier',
#   'tweet',
#   'à',
#   'zomg',
#   'moto',
#   'driveby'],
#  ['Tu', 'nous', 'manques', '!', '!', '!'],
#  ['Ma',
#   'mère',
#   'dit',
#   'que',
#   'je',
#   'ressemblais',
#   'à',
#   'un',
#   'nerd',
#   '.',
#   'Cela',
#   'fait',
#   'mal',
#   'à',
#   'me',
#   'sentiment',
#   'et',
#   'ensuite',
#   'je',
#   'lui',
#   'ai',
#   'dit',
#   '``',
#   'ne',
#   'pa',
#   'taurez',
#   '.',
#   '&',
#   'Quot',
#   ';'],
#  ['Je',
#   'travaille',
#   "jusqu'au",
#   'moins',
#   'minuit',
#   ',',
#   'alors',
#   'je',
#   'suppose',
#   'que',
#   'je',
#   "n'ai",
#   'pa',
#   'une',
#   'chance',
#   '.'],
#  ['Non',
#   ',',
#   'il',
#   'n',
#   "'",
#   'pa',
#   'compris',
#   '.',
#   'Le',
#   'mobile',
#   "s'est",
#   'égaré',
#   'tard',
#   '.',
#   'Ne',
#   'pa',
#   'laisser',
#   'passer',
#   'le',
#   'appels',
#   ',',
#   'le',
#   'sm',
#   'arrivent',
#   '2',
#   'jours',
#   'de',
#   'retard',
#   'etc'],
#  ["J'adore",
#   'le',
#   'temple',
#   'de',
#   'Shirley',
#   'aussi',
#   '!',
#   'Maintenant',
#   'je',
#   'veux',
#   'un'],
#  ['Et',
#   "l'Internet",
#   'fonctionne',
#   'encore',
#   'votre',
#   'bra',
#   'aussi',
#   ',',
#   'la',
#   'vie',
#   'est',
#   'bonne'],
#  ['Demain', 'dianna', 'vous', 'appellera'],
#  ['Los', 'Lupes', 'à', 'irving', 'avec', 'la', 'familia'],
#  ["J'ai",
#   'juste',
#   'expérimenté',
#   'que',
#   "c'est",
#   'agréable',
#   'de',
#   'faire',
#   'du',
#   'chien',
#   'me',
#   'propres',
#   'outils',
#   '.',
#   'Me',
#   'donner',
#   'de',
#   'commentaires',
#   'tout',
#   'le',
#   'temp',
#   '.',
#   'très',
#   'puissant',
#   '!'],
#  ['Considérant',
#   'la',
#   'crème',
#   'glacée',
#   'pour',
#   'le',
#   'petit-déjeuner',
#   '...',
#   'à',
#   'la',
#   'routine',
#   'du',
#   'matin',
#   '!',
#   'Avoir',
#   'un',
#   'grand',
#   'twitter'],
#  ['Regarde',
#   'actuellement',
#   'le',
#   'crépuscule',
#   'sur',
#   'dvd',
#   'et',
#   'souhaite',
#   'que',
#   'Edward',
#   'Cullen',
#   'soit',
#   'à',
#   'moi',
#   'tout',
#   'le',
#   'mien',
#   ',',
#   'haha'],
#  ['Aaa', '....', 'ne', 'sais', 'pa', 'quoi', 'faire'],
#  ['Oui',
#   ',',
#   'il',
#   'faut',
#   'avoir',
#   'commencé',
#   'à',
#   'télécharger',
#   'en',
#   'même',
#   'temp',
#   'que',
#   'le',
#   'reste',
#   'du',
#   'Royaume-Uni'],
#  ["Qu'est-ce",
#   'que',
#   'tu',
#   'une',
#   'jpeg',
#   'de',
#   'la',
#   'conception',
#   "n'importe",
#   'où',
#   '?',
#   "J'aimerais",
#   'bien',
#   'voir',
#   'ce',
#   'que',
#   'vous',
#   'faites',
#   'de',
#   'rock'],
#  ['-',
#   'audrey',
#   'hepburn',
#   '♥',
#   '...',
#   'gerard',
#   'way',
#   'ne',
#   'pardonnerait',
#   'jamais',
#   'pour',
#   'cela'],
#  ['Powere', 'Keps', "s'incline", 'et', 'sort', 'en', 'bode'],
#  ['Mélangeant', 'ipod', ',', 'facebook-ing'],
#  ['Je',
#   'vais',
#   'aller',
#   'chez',
#   'le',
#   'médecin',
#   "aujourd'hui",
#   'pour',
#   'voir',
#   "s'il",
#   'peut',
#   'comprendre',
#   'pourquoi',
#   "j'ai",
#   'de',
#   'maux',
#   'de',
#   'tête',
#   'stupides',
#   '!'],
#  ['Je',
#   'demande',
#   'aussi',
#   'pourquoi',
#   'je',
#   'ne',
#   'reçois',
#   'plus',
#   'de',
#   'tweet',
#   'sur',
#   'mon',
#   'téléphone',
#   '?',
#   '!',
#   '?',
#   '!',
#   '?',
#   '!',
#   '?'],
#  ['Twitter',
#   'dépose-t-il',
#   'de',
#   'plaque',
#   "d'or",
#   'et',
#   'de',
#   'platine',
#   '?',
#   'Twee.e.t',
#   'ou',
#   'm.tweet.v',
#   'award',
#   'peut-être',
#   '?',
#   'Mon',
#   'facebook',
#   'fam',
#   "'",
#   'sur',
#   'un',
#   'carton',
#   'au',
#   'lait',
#   '.'],
#  ['La',
#   'cravate',
#   'semble',
#   'beaucoup',
#   'plus',
#   'dynamique',
#   'dans',
#   'la',
#   'vidéo',
#   'que',
#   'dans',
#   'la',
#   'photo',
#   '...',
#   "j'aime",
#   'ça',
#   '!'],
#  ['Je',
#   'sen',
#   'seul',
#   'maintenant',
#   '!',
#   'reviens',
#   '!',
#   'Mais',
#   'amusez-vous'],
#  ['vraiment',
#   '?',
#   'Je',
# ...
#   'sorciers',
#   '...'],
#  ['Je', 'sen', 'coupable'],
#  ['À',
#   'la',
#   'recherche',
#   'de',
#   "quelqu'un",
#   'pour',
#   "m'envoyer",
#   'une',
#   'clé',
#   'bêta',
#   'beta',
#   'de',
#   "l'aion",
#   'fermée',
#   '.',
#   'Aidez-moi'],
#  ['chéri',
#   'tu',
#   'manques',
#   '!',
#   'Nd',
#   'ive',
#   'eu',
#   'de',
#   'mauvaises',
#   'nouvelles',
#   ',',
#   'il',
#   'ne',
#   'semble',
#   'pa',
#   'lke',
#   'im',
#   'goin2',
#   'être',
#   'capable',
#   'de',
#   'vous',
#   'voir',
#   'cet',
#   'été',
#   '...',
#   'alors',
#   ',',
#   'vous',
#   'pouvez',
#   'appeler',
#   'maintenant',
#   'lol'],
#  ['Au',
#   'magasin',
#   'de',
#   'sprint',
#   'pour',
#   'voir',
#   "s'ils",
#   'peuvent',
#   'comprendre',
#   'que',
#   'caméra',
#   'ne',
#   'fonctionne',
#   'pa'],
#  ['Oui',
#   ',',
#   "j'avais",
#   'beaucoup',
#   'de',
#   'problèmes',
#   'avec',
#   'tj',
#   'aussi',
#   ',',
#   "j'avais",
#   'de',
#   'la',
#   'chance',
#   'la',
#   'première',
#   'fois',
#   'que',
#   'la',
#   'première',
#   'nuit',
#   'était',
#   'inaudible',
#   '.',
#   'Mais',
#   'une',
#   'deuxième',
#   'chance',
#   'est',
#   'venue'],
#  ['Les',
#   'lapin',
#   'sont',
#   'de',
#   'animaux',
#   'vicieux',
#   '.',
#   'Avez-vous',
#   'vu',
#   'le',
#   'film',
#   'monty',
#   'python',
#   'saint',
#   'grail',
#   '?',
#   'Ce',
#   'lapin',
#   'était',
#   'un',
#   'monstre',
#   '.'],
#  ["c'est",
#   'chaud',
#   '.',
#   "J'ai",
#   'adoré',
#   'le',
#   '&',
#   'quot',
#   ';',
#   'chaque',
#   'fille',
#   '&',
#   'quot',
#   ';',
#   'Freestyle',
#   '.',
#   'La',
#   '``',
#   'anticipation',
#   "''",
#   'Pour',
#   '``',
#   'ready',
#   "''",
#   'quot',
#   ';',
#   'Commence',
#   'ici',
#   '&',
#   'quot',
#   ';',
#   'Yuuup'],
#  ['Pour',
#   'une',
#   'raison',
#   'quelconque',
#   ',',
#   'Corona',
#   'Light',
#   'goûte',
#   'tellement',
#   'mieux',
#   'quand',
#   'je',
#   'suis',
#   'avec',
#   'vous',
#   'que',
#   'quand',
#   'je',
#   'suis',
#   'seul',
#   '.'],
#  ['Merci', 'andy', 'crevette', 'barbe', 'louisiana'],
#  ['Ahh',
#   "'longview",
#   "'",
#   'au',
#   'cours',
#   'de',
#   'la',
#   'journée',
#   'verte',
#   '-',
#   'rappelle',
#   "d'essayer",
#   'de',
#   'jurer',
#   'aussi',
#   'fort',
#   'que',
#   'je',
#   'pourrais',
#   "m'exprimer",
#   'dessus',
#   'lol'],
#  ['En',
#   'écoutant',
#   'quelque',
#   'chose',
#   'à',
#   'bo',
#   'Burnham',
#   '.',
#   'mec',
#   'marrant'],
#  ['sensationnel', '.', "J'ai", 'encore', 'un', 'mal', 'de', 'tête'],
#  ['Sophs',
#   'endormis',
#   'sur',
#   'moi',
#   'aussi',
#   ',',
#   'mon',
#   'téléphone',
#   'continue',
#   'de',
#   'fonctionner',
#   'et',
#   'je',
#   'ne',
#   'peux',
#   'pa',
#   "l'obtenir",
#   '!',
#   'Elle',
#   'v.',
#   'Somnolent',
#   "aujourd'hui",
#   '?',
#   '!',
#   '?'],
#  ['Hahhaa',
#   'qui',
#   'eu',
#   'de',
#   'la',
#   'chance',
#   'de',
#   'ne',
#   'pa',
#   'faire',
#   'de',
#   'très',
#   'bons',
#   'copains',
#   'de',
#   'voyage',
#   'serait-on',
#   '?',
#   'Ba',
#   'sont',
#   'de',
#   'ordure',
#   ',',
#   'il',
#   'ne',
#   'semblent',
#   'pa',
#   'trop',
#   'aimer'],
#  ['Prouve',
#   'simplement',
#   'que',
#   'personne',
#   'ne',
#   'lit',
#   'plus',
#   'le',
#   'site',
#   'Web',
#   'si',
#   'ce',
#   "n'est",
#   'pa',
#   'Twitter',
#   ',',
#   'il',
#   "n'existe",
#   'pa',
#   '.'],
#  ['Se',
#   'demande',
#   'comment',
#   'il',
#   'peut',
#   'être',
#   'très',
#   'nuageux',
#   'quand',
#   'il',
#   'été',
#   'charmant',
#   'ce',
#   'derniers',
#   'jours'],
#  ['se', 'déconnecter', '!', 'Passer', 'au', 'mode', 'PC', '.'],
#  ['Cerise',
#   'après',
#   'une',
#   'journée',
#   'magnifique',
#   ',',
#   'un',
#   'barbecue',
#   'fabuleux',
#   'et',
#   'une',
#   'belle',
#   'nuit'],
#  ['Hahahah',
#   'owh',
#   'lool',
#   'ça',
#   'fonctionnera',
#   "j'espère",
#   "qu'il",
#   'vaut',
#   'mieux',
#   'que',
#   "l'homme",
#   'je',
#   'déteste',
#   'hollande'],
#  ['Vraiment',
#   'mauvais',
#   'temp',
#   '.',
#   'Parfait',
#   'pour',
#   "s'asseoir",
#   'dans',
#   'le',
#   'lit',
#   'en',
#   'regardant',
#   'seinfeld'],
#  ['Le',
#   'nouveau',
#   't-shirt',
#   '5preview',
#   '....',
#   'Je',
#   'ne',
#   'vous',
#   'aime',
#   'arriver',
#   'je',
#   'besoin',
#   'de',
#   'mettre',
#   'à',
#   'jour',
#   'sur',
#   'le',
#   'dernières',
#   'choses',
#   '!'],
#  ['Je', 'suis', 'officiellement', '26'],
#  ["S'il",
#   'vous',
#   'plaît',
#   ',',
#   'veuillez',
#   'le',
#   'réserver',
#   '!',
#   'il',
#   'sont',
#   'étonnants',
#   '!'],
#  ['Fait-il', '?', '?', '?', 'je', 'suis', 'offensé'],
#  ['@',
#   'Luke8bt',
#   'luke',
#   '....',
#   'vient',
#   'de',
#   'trouver',
#   'votre',
#   'réponse',
#   '.',
#   'Je',
#   'vous',
#   'remercie',
#   '.',
#   'vraiment',
#   'apprécié',
#   '.',
#   'Nous',
#   'somme',
#   'de',
#   'nouveau',
#   'amis',
#   '.'],
#  ['Ne', 'pa', 'se', 'sentir', 'bien', '..'],
#  ['Plus', 'bbm'],
#  ['Deux',
#   'en',
#   'ba',
#   'pour',
#   'aller',
#   'au',
#   'saint',
#   'jeudi',
#   'fille',
#   '!',
#   '!',
#   '!'],
#  ['N',
#   "'",
#   'pa',
#   "d'accès",
#   'à',
#   'YouTube',
#   'mais',
#   'doit',
#   'rechercher',
#   'pour',
#   'youtube'],
#  ['Assurez-vous',
#   'de',
#   'publier',
#   'vos',
#   'prédictions',
#   'sur',
#   'le',
#   'forum',
#   'à',
#   'www.socceram.net'],
#  ['Merci', ',', 'je', 'suis', 'surpris', 'un', 'peu'],
#  ["C'est",
#   'si',
#   'gentil',
#   'à',
#   "l'extérieur",
#   "aujourd'hui",
#   ',',
#   'mais',
#   'ressemble',
#   'à',
#   'eryn',
#   'et',
#   'je',
#   'passerai',
#   'le',
#   'jour',
#   'à',
#   "l'intérieur",
#   ',',
#   'elle',
#   "s'est",
#   'réveillée',
#   'malade',
#   '...'],
#  ['Bien',
#   '...',
#   'Tu',
#   'veux',
#   'dire',
#   'que',
#   'tu',
#   'ne',
#   'feras',
#   'pa',
#   "l'énergie",
#   'pour',
#   'trouver',
#   '?'],
#  ['Yay',
#   '!',
#   'voir',
#   '?',
#   '!',
#   'Restez',
#   'avec',
#   'moi',
#   '...',
#   'je',
#   'suis',
#   'plein',
#   'de',
#   'bonnes',
#   'idées',
#   'comme',
#   'ça',
#   '.',
#   '*',
#   'gros',
#   'câlins',
#   '*'],
#  ['Même',
#   'ici',
#   '...',
#   '*',
#   'mode',
#   'envy',
#   '*',
#   '...',
#   'elle',
#   'n',
#   "'",
#   'pa',
#   'besoin',
#   'de',
#   '2',
#   'crunch',
#   'comme',
#   'je',
#   'shud',
#   '...',
#   'comme',
#   'wat',
#   "j'ai",
#   'besoin',
#   'de',
#   '2',
#   'faire',
#   'plus',
#   'tard',
#   '...',
#   'wahaha'],
#  ['Et', 'merci', 'beaucoup'],
#  ['Est-ce',
#   'que',
#   'je',
#   'peux',
#   'écouter',
#   'de',
#   'la',
#   'radio',
#   '(',
#   ')',
#   'sur',
#   "l'iPhone",
#   '?',
#   "J'ai",
#   'juste',
#   'brûlé',
#   'le',
#   'seul',
#   'petit',
#   'déjeuner',
#   'viable',
#   'que',
#   "j'avais",
#   'dans',
#   'la',
#   'maison'],
#  ["d'accord",
#   '.',
#   'Je',
#   'suppose',
#   'que',
#   'je',
#   'vais',
#   'tweeter',
#   'quelques',
#   'choses',
#   'aléatoires',
#   'et',
#   'ensuite',
#   'avoir',
#   'mon',
#   '2700e',
#   'tweet',
#   ',',
#   'puis',
#   'je',
#   'couche',
#   '.',
#   "d'accord",
#   '?'],
#  ['Mon',
#   'obsédé',
#   'de',
#   '7',
#   'an',
#   ',',
#   'tout',
#   'comme',
#   'il',
#   'ré-créé',
#   'la',
#   'bataille',
#   'de',
#   'Geonosis',
#   'à',
#   'partir',
#   'de',
#   "l'épisode",
#   '2.',
#   'vraiment',
#   'incroyable',
#   '.'],
#  ["C'est",
#   'un',
#   'samedi',
#   'matin',
#   'parfait',
#   '.',
#   'Le',
#   'soleil',
#   'brille',
#   ',',
#   'le',
#   'oiseaux',
#   'chantent',
#   '...',
#   'et',
#   'je',
#   'rattrape',
#   'sur',
#   'admin'],
#  ['Nous',
#   'avon',
#   'eu',
#   'tout',
#   'notre',
#   'bacon',
#   'pour',
#   'dîner',
#   'hier',
#   'soir'],
#  ['Je',
#   'ne',
#   'peux',
#   'pa',
#   'dormir',
#   '!',
#   'Je',
#   'doi',
#   'lever',
#   'dans',
#   '3',
#   'heures',
#   '.'],
#  ["J'espère",
#   'que',
#   'je',
#   'pourrai',
#   '/',
#   'ou',
#   "j'espère",
#   'que',
#   'le',
#   'conférencier',
#   'nous',
#   'donne',
#   'un',
#   'feu',
#   'vert',
#   'sur',
#   'le',
#   'projet',
#   ',',
#   'sinon',
#   ',',
#   'doit',
#   'travailler',
#   'pendant',
#   'la',
#   'nuit',
#   '...'],
#  ['Est', 'au', 'bureau'],
#  ['Stationné',
#   'sur',
#   'la',
#   'm1',
#   'le',
#   'jour',
#   'le',
#   'plus',
#   'chaud',
#   'de',
#   "l'année"],
#  ['Je',
#   'pourrais',
#   'avoir',
#   'pris',
#   'une',
#   'décision',
#   'stupide',
#   'à',
#   'certains',
#   ',',
#   'mais',
#   'dans',
#   "l'ensemble",
#   ',',
#   'je',
#   'suis',
#   'bien',
#   'amusé'],
#  ['Mon',
#   'ordinateur',
#   'portable',
#   'est',
#   'en',
#   'panne',
#   'alors',
#   'je',
#   "n'ai",
#   'pa',
#   "d'ordinateur",
#   'en',
#   'ce',
#   'moment'],
#  ['Hey',
#   '.',
#   'Passez',
#   'le',
#   'message',
#   'sur',
#   'Rory',
#   'que',
#   'je',
#   "l'aime",
#   'absolument',
#   '!',
#   'Et',
#   "j'adore",
#   'le',
#   'reste',
#   "d'entre",
#   'vous',
#   ',',
#   'vous',
#   'avez',
#   'donné',
#   'un',
#   'coup',
#   'de',
#   'pied',
#   'au',
#   'dernier',
#   'mois',
#   '!'],
#  ['Lol',
#   '!',
#   'Ils',
#   'gardent',
#   'la',
#   'garde',
#   '!',
#   'Fille',
#   'amusante',
#   'en',
#   'liberté',
#   '!',
#   'Lol',
#   'j',
#   '/',
#   'k',
#   '!'],
#  ['-',
#   'disappeares',
#   'de',
#   'divertissement',
#   "d'été",
#   ';',
#   'Avec',
#   "l'été",
#   'en',
#   'Autriche',
#   '!',
#   '!'],
#  ['Jon',
#   '!',
#   'Bon',
#   'de',
#   'vous',
#   'voir',
#   'ici',
#   '!',
#   'Je',
#   'doi',
#   'venir',
#   'prendre',
#   'un',
#   'déjeuner',
#   'là-bas',
#   'bientôt',
#   '!'],
#  ['Vous',
#   'ne',
#   "m'avez",
#   'pa',
#   'répondu',
#   ',',
#   'je',
#   'doi',
#   'donner',
#   '10',
#   '$',
#   'pour',
#   'mon',
#   'ami'],
#  ['-', 'tellement', 'mieux', '.', 'nouveau', 'et', 'amélioré'],
#  ['Oui', 'il', 'avait', '70', 'an', 'il', '2', 'semaines'],
#  ["J'ai", 'parfois', 'le', 'deux', 'confus', '.'],
#  ['Est',
#   'en',
#   'train',
#   'de',
#   'manger',
#   'un',
#   'bon',
#   'bol',
#   'chaud',
#   'de',
#   'ramen',
#   'et',
#   'de',
#   'deuil',
#   'le',
#   'fait',
#   "qu'elle",
#   'pris',
#   'son',
#   'téléphone',
#   'et',
#   'iPod',
#   'pris',
#   'ce',
#   'soir',
#   '...',
#   'Je',
#   'déteste',
#   'mon',
#   'vie',
#   '!'],
#  ['Salut', 'merci', 'de', "m'avoir", 'suivi', 'xx'],
#  ['-', 'je', "t'aime"],
#  ['Cela', 'suce', "l'espoir", 'de', 'ne', 'pa', 'tomber', 'malade', '!'],
#  ['Vient',
#   'de',
#   'télécharger',
#   'la',
#   'photo',
#   'de',
#   'mon',
#   'espace',
#   'de',
#   'ciel',
#   'bleu'],
#  ['Mes', 'parent', 'aiment', 'le', 'format', '!'],
#  ["J'aimerais",
#   'être',
#   'sorti',
#   'mais',
#   'aimer',
#   'bébé',
#   'kyssja',
#   '&',
#   'lt',
#   ';',
#   '3'],
#  ['Mon', 'bébé', 'est', 'vivant'],
#  ['En',
#   'attendant',
#   'que',
#   'Android',
#   '1.5',
#   'soit',
#   'poussé',
#   'à',
#   'la',
#   'g1',
#   'alors',
#   '?'],
#  ['Baise', "j'ai", 'perdu', 'mon', 'capuchon', "d'objectif"],
#  ['maintenant', "c'est", '?', 'cool'],
#  ['Oh',
#   ',',
#   'je',
#   'sais',
#   '!',
#   'Je',
#   'regardais',
#   'avec',
#   'le',
#   'plus',
#   'petit',
#   'visage'],
#  ['Je',
#   'suis',
#   'tellement',
#   'fou',
#   'que',
#   "j'ai",
#   'raté',
#   'le',
#   'tremblement',
#   'de',
#   'terre',
#   '!',
#   'Je',
#   'conduis',
#   'toujours',
#   'quand',
#   'ce',
#   'choses',
#   'se',
#   'passent',
#   '!'],
#  ["j'ai", 'mal', 'au', 'doigt', '....'],
#  ['pssh', 'je', "n'ai", 'rien', '.'],
#  ['17',
#   'jours',
#   'jusqu',
#   "'",
#   'à',
#   'ce',
#   'que',
#   'Star',
#   'Trek',
#   'arrive',
#   '!'],
#  ['bonne', 'nuit', '!'],
#  [':',
#   'Essayez',
#   'twitter',
#   'de',
#   'la',
#   'nouvelle',
#   'Blackberry',
#   'bold',
#   'de',
#   'votre',
#   'femme',
#   'en',
#   'utilisant',
#   'ubertwitter',
#   'ou',
#   'application',
#   'twitterberry'],
#  ['Je',
#   'voudrais',
#   'vraiment',
#   'que',
#   "j'aurais",
#   'pris',
#   'cette',
#   'biscuit',
#   'n',
#   'crème',
#   '...',
#   'tu',
#   'pen',
#   'que',
#   'ça',
#   'va',
#   'faire',
#   'passer',
#   '?'],
#  ['Les',
#   'mauvaises',
#   'choses',
#   'viennent-elles',
#   'en',
#   'trois',
#   '?',
#   'Vous',
#   'êtes',
#   'sur',
#   'un',
#   'rouleau',
#   '...'],
#  ['Eh', '.', 'Tout', 'le', 'monde', 'est', 'allé', 'au', 'lit'],
#  ['Nuit', 'au', 'musée', 'aspirée', '!', "J'aimerais", 'avoir', 'vu'],
#  ['Est', 'prêt', 'à', 'se', 'coucher', '...', 'long', 'demain'],
#  ['Eh',
#   'bien',
#   ',',
#   'au',
#   'moins',
#   'prendre',
#   'une',
#   'photo',
#   'ou',
#   'deux',
#   "s'il",
#   'vous',
#   'plaît',
#   '!'],
#  ['Mauvaise',
#   'expérience',
#   'dans',
#   'er',
#   '...',
#   'la',
#   'vie',
#   'est',
#   'vraiment',
#   'courte',
#   '.'],
#  ['Est',
#   'malade',
#   'de',
#   'faire',
#   'du',
#   'bruit',
#   '.',
#   'Aller',
#   'voir',
#   'de',
#   'amis',
#   'pour',
#   'discuter',
#   'et',
#   'un',
#   'café'],
#  ['Merci',
#   'pour',
#   'la',
#   'tête',
#   ',',
#   'tu',
#   'absolument',
#   'raison',
#   '...',
#   'ferai'],
#  ['Il',
#   'suffit',
#   'de',
#   'lira',
#   'que',
#   'Farrah',
#   'fawcett',
#   'est',
#   'mort',
#   '.',
#   'Rip',
#   ',',
#   'ange',
#   '.'],
#  ['Je', 'pense', 'que', 'mon', 'oreille', 'pourrait', 'être', 'infectée'],
#  ['Nb', 'prenez', 'deux'],
#  ['N',
#   "'",
#   'pa',
#   'eu',
#   'le',
#   'shoplifter',
#   '.',
#   'A',
#   'vu',
#   'la',
#   'personne',
#   ',',
#   'mais',
#   'pa',
#   'autorisé',
#   'à',
#   'toucher',
#   'la',
#   'personne',
#   'pour',
#   'le',
#   'arrêter',
#   '.',
#   'Très',
#   'irritant',
#   '.'],
#  ['Rochelle',
#   'prend',
#   's',
#   'photo',
#   '?',
#   'Yay',
#   '!',
#   'Haha',
#   '.',
#   'Elle',
#   'est',
#   'géniale',
#   ',',
#   'elle',
#   'doit',
#   "l'aimer",
#   '.',
#   "s'amuser",
#   '!',
#   "J'espère",
#   'que',
#   'je',
#   'vais',
#   'voir',
#   'ce',
#   'coup',
#   ',',
#   'ouais',
#   '?'],
#  ['Je', 'suis', 'battu', '...', 'Goodnight', 'twitter', '!'],
#  ['Ne', 'gaspille', 'pa', 'te', 'larmes', 'de', 'fiction'],
#  ['Avec',
#   'mac',
#   ',',
#   'Apple',
#   'fournit',
#   'un',
#   'bon',
#   'moyen',
#   'de',
#   'migrer',
#   'de',
#   "l'ancien",
#   'vers',
#   'le',
#   'nouveau',
#   '.',
#   'Je',
#   "n'ai",
#   'pa',
#   'encore',
#   'vu',
#   'de',
#   'article',
#   'similaires',
#   'pour',
#   'iphones',
#   '.',
#   "n'importe",
#   'qui',
#   '?',
#   'Manuellement',
#   'alors'],
#  ['Se',
#   'sent',
#   'vraiment',
#   'froid',
#   'à',
#   'la',
#   'maison',
#   '-',
#   'très',
#   'différent',
#   'par',
#   'rapport',
#   'à',
#   'cette',
#   'semaine',
#   'la',
#   'semaine',
#   'dernière',
#   '!',
#   'Va',
#   'monter',
#   'le',
#   'chauffage',
#   'car',
#   'me',
#   'orteils',
#   'sont',
#   'gelés'],
#  ['Essayant', 'de', 'passer', 'cette', 'classe', "d'espagnol"],
#  ['Amour', 'de', 'la', 'nuit', 'de', 'ronde', '4', 'démo'],
#  ['Omg',
#   ',',
#   'je',
#   "n'ai",
#   'vraiment',
#   'envie',
#   "d'étudier",
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['Jade',
#   'suce',
#   '......',
#   'Elle',
#   'est',
#   'méchante',
#   ',',
#   'elle',
#   'veut',
#   'que',
#   'je',
#   'le',
#   'regarde',
#   'parce',
#   "qu'elle",
#   "l'air",
#   'de',
#   'regarder',
#   'maintenant',
#   '!',
#   'Oldies',
#   'sanglantes'],
#  ['Bien',
#   ',',
#   'il',
#   'vont',
#   'grandir',
#   'avant',
#   'de',
#   'le',
#   'connaître',
#   ',',
#   'alors',
#   'prenez',
#   'le',
#   'temp',
#   'maintenant'],
#  ['Ne', 'pa', 'trop', 'chaud'],
#  ['B', '?', 'Ng', 'b', '?', 'T'],
#  ['Je',
#   'fais',
#   'fumer',
#   'afin',
#   'que',
#   'je',
#   'puisse',
#   'sembler',
#   'mauvais',
#   'comme',
#   'Lawrence',
#   'tierney',
#   ',',
#   'mais',
#   'je',
#   'finirais',
#   'probablement',
#   'par',
#   'ressembler',
#   'à',
#   'un',
#   'jable',
#   'de',
#   'juin'],
#  ['Vraiment', ',', 'je', "n'ai", 'plus', 'le', 'temp', 'pour', 'ça', '...'],
#  ['Whoops', ',', 'ce', 'dernier', 'tweet', 'était', 'pour', 'vous', '.'],
#  ['Je',
#   'suis',
#   'désolé',
#   'que',
#   'vous',
#   'soyez',
#   'perplexe',
#   '!',
#   'triste',
#   '!',
#   'Nous',
#   'allons',
#   'vous',
#   'faire',
#   'un',
#   'spectacle',
#   'bientôt',
#   '!',
#   '!'],
#  ['Oh',
#   'oui',
#   ',',
#   'mais',
#   'je',
#   'suis',
#   'aussi',
#   'très',
#   'triste',
#   'à',
#   'la',
#   'rapidité',
#   'avec',
#   'laquelle',
#   'il',
#   'est',
#   'parti',
#   '!',
#   'comment',
#   'va',
#   'tout',
#   'le',
#   'monde',
#   '?',
#   '?'],
#  ['-',
#   'bisou',
#   ',',
#   'aerosmith',
#   ',',
#   'tdf',
#   ',',
#   'atl',
#   ',',
#   'bowling',
#   'pour',
#   'soupe',
#   ',',
#   'weezer',
#   '.',
#   'Je',
#   'suis',
#   'vraiment',
#   'en',
#   'train',
#   'de',
#   'nommer',
#   'me',
#   'groupes',
#   'préférés',
#   ',',
#   'mais',
#   'leurs',
#   'noms',
#   'sont',
#   'vraiment',
#   'cool',
#   '!'],
#  ['Très',
#   'gentil',
#   'ami',
#   ',',
#   'qui',
#   'peut',
#   'rendre',
#   'au',
#   'monde',
#   'normal'],
#  ['Ce', "n'est", 'pa', 'le', 'soleil', "aujourd'hui"],
#  ['Lorsque',
#   'vous',
#   'savez',
#   'que',
#   'vous',
#   "n'avez",
#   'presque',
#   'rien',
#   'en',
#   'commun',
#   'avec',
#   "quelqu'un",
#   ',',
#   'mais',
#   'que',
#   'vous',
#   'vous',
#   'sentez',
#   'en',
#   'sécurité',
#   ',',
#   "qu'est-ce",
#   'que',
#   'cela',
#   'signifie',
#   '?',
#   'Ressemble-t-il',
#   'à',
#   'une',
#   'âme',
#   'soeur',
#   '?'],
#  ['Sur',
#   'le',
#   'chemin',
#   'de',
#   "l'accueil",
#   'de',
#   'Audrey',
#   '.',
#   'Elle',
#   'ne',
#   'le',
#   'sait',
#   'pa',
#   'encore',
#   ',',
#   'elle',
#   'achète',
#   'son',
#   'premier',
#   'set',
#   'de',
#   'coup'],
#  ["N'ont",
#   'pa',
#   'regardé',
#   'la',
#   'télévision',
#   'dans',
#   'quelques',
#   'semaines',
#   '.',
#   'L',
#   "'",
#   'allumé',
#   'la',
#   'dernière',
#   'nuit',
#   ',',
#   'décidé',
#   "qu'il",
#   'était',
#   'stupide',
#   'et',
#   'l',
#   "'",
#   'éteint',
#   '.'],
#  ['Ooooo', "j'aimerais", 'venir', 'et', 'déchiqueter', 'de', 'choses', 'lol'],
#  ['Uhe',
#   '-',
#   "j'étais",
#   'inquiet',
#   'pour',
#   'toi',
#   ';',
#   "C'était",
#   'toucher',
#   'et',
#   'aller',
#   ',',
#   'mais',
#   'vous',
#   'avez',
#   'traversé'],
#  ...]

# %% [markdown]
# How long did it take ?
#
# It takes several minutes for just 20000 tweets, imagine that for 1.5 million 🤯!
#
# Now we try to optimize the process with a Spacy pipeline.
#
# A Spacy pipeline take in pute texts and have some interesting arguments to optimize the time of preprocessing (see the documentation: https://spacy.io/usage/processing-pipelines)
#
# We will look at two in particular:
# - **disable**: when we pass a text into a spacy model, by default it will do a lot of processing (named entity recognition, retrieving embedding vectors, etc.). With this parameter we can remove these unnecessary steps here.
#
# - **batch_size**: the number of texts pre-processed at a time

# %%
## disable and batch_size params
docs = nlp.pipe(df_sample.text, disable=["tok2vec", "tagger", "parser", "attribute_ruler", "ner"], batch_size=20)
docs ## attention se vide après boucle car générateur
# Out:
# <generator object Language.pipe at 0x7f543b4f1a10>

# %% [markdown]
# `pipe` return a iterator of spacy docs. Write once again a preprocessing function that takes as input a spacy doc object and not a tweet directly !

# %%
# create a preprocessing_2 function
def preprocessing_2(my_doc):
    # Document created by preprocessing the text with the nlp object
    tokens = [t.text for t in my_doc]
    # stop_words removal
    stop_words = stopwords.words('english')
    tokens = [t for t in tokens if not t in stop_words]
    # lemmatize
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(t) for t in tokens]
    return tokens

# %%
# create a new list with all tweets tokens from pipeline
## !!! il faut faire retourner la cellule avec le générateur de docs !!!!
new_tweets = []
for doc in docs:
    tokens = preprocessing_2(doc)
    new_tweets.append(tokens)
new_tweets
# Out:
# [['Mais',
#   'je',
#   'ne',
#   'peux',
#   'pa',
#   'envoyer',
#   'de',
#   'courrier',
#   'électronique',
#   'à',
#   'personne',
#   '!',
#   'Ce',
#   "n'",
#   'est',
#   'pa',
#   'seulement',
#   'votre',
#   'adresse',
#   '...'],
#  ['Se',
#   'sent',
#   'mal',
#   'après',
#   'avoir',
#   'mangé',
#   '&',
#   'quot',
#   ';',
#   'cinema',
#   'sweet',
#   '&',
#   'quot',
#   ';',
#   'pop',
#   'corn',
#   '.',
#   '.',
#   '.',
#   '.',
#   '.',
#   'Sans',
#   'le',
#   'cinéma'],
#  ['awwe',
#   '..',
#   'hey',
#   '..',
#   'doivent',
#   'chat',
#   'lit',
#   'g2',
#   'plus',
#   'tard',
#   '?',
#   ':]'],
#  ['La',
#   'famille',
#   'et',
#   'le',
#   'amis',
#   'sont',
#   'partis',
#   'après',
#   'un',
#   'beau',
#   'week',
#   '-',
#   'end',
#   'de',
#   'fin',
#   "d'",
#   'études',
#   'de',
#   'deux',
#   'jours',
#   '!',
#   "J'",
#   'ai',
#   'passé',
#   'un',
#   'bon',
#   'moment',
#   '!',
#   'Merci',
#   "d'",
#   'être',
#   'venu',
#   '!',
#   ';)',
#   'Le',
#   'week',
#   '-',
#   'end',
#   'prochain',
#   'pt',
#   '2',
#   '!'],
#  ['Oui',
#   ',',
#   'je',
#   'commence',
#   'définitivement',
#   'à',
#   'ressentir',
#   'le',
#   'décalage',
#   'maintenant',
#   '.',
#   'Environ',
#   'quatre',
#   'heures',
#   'supplémentaires',
#   ',',
#   'mais',
#   "j'",
#   'ai',
#   'entendu',
#   'dire',
#   'que',
#   'nous',
#   'pouvons',
#   'avoir',
#   'de',
#   'heures',
#   'supplémentaires',
#   'obligatoires',
#   ',',
#   'donc',
#   'peut-être',
#   'cinq',
#   'ou',
#   'six'],
#  ['Je',
#   'vais',
#   'bien',
#   ',',
#   'mais',
#   'je',
#   'fais',
#   'me',
#   'devoir',
#   ',',
#   'haha',
#   ',',
#   'quoi',
#   'de',
#   'neuf',
#   '?'],
#  ["L'",
#   'iPhone',
#   "n'",
#   'pa',
#   'de',
#   'réception',
#   'dans',
#   'le',
#   'bâtiment',
#   'de',
#   'la',
#   'caisse',
#   'de',
#   'ciment',
#   'au',
#   'travail',
#   '.',
#   'Il',
#   'souffle',
#   'que',
#   'son',
#   'collègue',
#   'peut',
#   'discuter',
#   'librement',
#   'sur',
#   'sa',
#   'cellule',
#   ',',
#   'alors',
#   'que',
#   'je',
#   'doi',
#   'travailler',
#   '!'],
#  ['Mais',
#   'vous',
#   'avez',
#   "d'",
#   'autres',
#   'compétences',
#   'dans',
#   'lesquelles',
#   'je',
#   'peux',
#   'croire',
#   ',',
#   'comme',
#   'manger',
#   'tard',
#   '-',
#   'nite',
#   'taco',
#   'bell',
#   '&',
#   'amp',
#   ';',
#   'Porter',
#   'une',
#   'ceinture',
#   'de',
#   'lutte',
#   'au',
#   'club'],
#  ['Mes',
#   'examen',
#   'se',
#   'sont',
#   'bien',
#   'passés',
#   ',',
#   'mais',
#   'il',
#   'encore',
#   'du',
#   'temp',
#   '...',
#   'merde',
#   '!'],
#  ['Mignon',
#   'cube',
#   '«',
#   'portail',
#   '»',
#   'haché',
#   '.',
#   'Mon',
#   'bébé',
#   'joue',
#   'à',
#   'de',
#   'jeux',
#   ',',
#   'je',
#   'li',
#   'de',
#   'fiction',
#   'de',
#   'fan',
#   '!'],
#  ['Je',
#   'serai',
#   'en',
#   'attente',
#   "d'",
#   'entendre',
#   '...',
#   'attends',
#   'avec',
#   'impatience',
#   'ce',
#   'que',
#   'vous',
#   'venez',
#   'de',
#   'faire'],
#  ['-', "J'", 'ai', 'cette', 'chemise', '!'],
#  ['Arriver', 'à', 'votre', 'voiture', '?'],
#  ['Mon',
#   'ami',
#   'et',
#   'mon',
#   'ami',
#   'Je',
#   'suis',
#   'en',
#   'atl',
#   '.',
#   'Nous',
#   'avon',
#   'eu',
#   'un',
#   '5',
#   '*',
#   'dans',
#   'West',
#   'Palm',
#   '&',
#   'amp',
#   ';',
#   'Manqué',
#   'de',
#   'vous',
#   'rencontrer',
#   '.',
#   "J'",
#   'aimerais',
#   'te',
#   'voir',
#   "aujourd'hui",
#   '!',
#   'Pouvez',
#   '-vous',
#   'nous',
#   'accrocher',
#   '?'],
#  ["J'", 'ai', 'un', 'ca', 'de', 'lundi', '.'],
#  ['Je',
#   'ne',
#   'pense',
#   'pa',
#   'que',
#   'vous',
#   'avez',
#   'rejoint',
#   ',',
#   'pensez',
#   'que',
#   'vous',
#   'devez',
#   'publier',
#   'une',
#   'URL',
#   'complète',
#   ',',
#   'pa',
#   'la',
#   'raccourcie',
#   'pour',
#   'vous',
#   'joindre',
#   '.',
#   'Joignez',
#   '-vous',
#   'si',
#   'vous',
#   'êtes',
#   'intéressé',
#   '.',
#   'devrait',
#   'être',
#   'amusant'],
#  ['Manque', 'son', 'bébé'],
#  ['Matinée', ',', 'vers', 'le', 'haut', ',', '2', "aujourd'hui", ',', 'AA'],
#  ['Et', 'toute', 'une', 'application', 'est', '.'],
#  ['Oui', ',', "j'", 'ai', 'eu', 'tort', 'aussi', '.', 'Pardon', '.'],
#  ['Ne',
#   'veulent',
#   'pa',
#   'aller',
#   'au',
#   'collège',
#   "aujourd'hui",
#   ',',
#   'ont',
#   'toujours',
#   'du',
#   'travail',
#   'épique',
#   'pour',
#   'travailler'],
#  ['Le',
#   'voyage',
#   'était',
#   'amusant',
#   ',',
#   'surtout',
#   'en',
#   'voyant',
#   'le',
#   'chiot',
#   'de',
#   'mon',
#   'chien',
#   'et',
#   'de',
#   'sa',
#   'soeur',
#   ',',
#   'tellement',
#   'mignon',
#   '!',
#   'Comment',
#   'allez',
#   'vous',
#   '?'],
#  ['25',
#   'jours',
#   'avant',
#   "l'",
#   'obtention',
#   'du',
#   'diplôme',
#   '!',
#   '...',
#   '26',
#   'jours',
#   'avant',
#   'le',
#   'mariage',
#   'de',
#   'Miguel',
#   '!',
#   '...',
#   'et',
#   'surtout',
#   '27',
#   'jours',
#   "jusqu'",
#   'à',
#   'ce',
#   'que',
#   'je',
#   'déplace',
#   'avec',
#   'mike',
#   'je',
#   "t'",
#   'aime',
#   'mike',
#   '&',
#   'lt',
#   ';',
#   '3'],
#  ["J'", 'ai', 'du', 'travail', 'jeudi'],
#  ['fête', 'ce', 'soir', '.'],
#  ['dernier', 'jour', "d'", 'école', '.'],
#  ['Envisageant',
#   'de',
#   'regarder',
#   'le',
#   'super',
#   '14',
#   'finale',
#   'ce',
#   'soir',
#   'à',
#   '1h30',
#   '...',
#   'bien',
#   'que',
#   'je',
#   'sen',
#   'déjà',
#   'fatigué',
#   'et',
#   'que',
#   'ce',
#   'ne',
#   'sont',
#   'que',
#   '17h00'],
#  ['est',
#   'de',
#   'retour',
#   '!',
#   '!',
#   '!',
#   '!',
#   'Mon',
#   'comp',
#   "n'",
#   'pa',
#   'eu',
#   'Internet',
#   'pendant',
#   'plus',
#   "d'",
#   'un',
#   'mois',
#   '!',
#   '!'],
#  ['Bon',
#   'anniversaire',
#   '!',
#   "J'",
#   'espère',
#   'que',
#   'vous',
#   'avez',
#   'une',
#   'bonne',
#   'journée',
#   '!'],
#  ['peut', 'être', 'que', 'je', 'le', 'ferais', '.'],
#  ['Regarder', 'wall', '-', 'e.'],
#  ['Mange',
#   'mon',
#   'yogustuff',
#   'gelé',
#   ',',
#   'il',
#   'manque',
#   'le',
#   'zachary',
#   ',',
#   'pa',
#   'même',
#   'tout',
#   'le',
#   'froenzo',
#   'dans',
#   'le',
#   'monde',
#   'pourrait',
#   'le',
#   'rattraper'],
#  ['Et',
#   "l'",
#   'entrevue',
#   'est',
#   'parce',
#   'que',
#   'moi',
#   'et',
#   'Angie',
#   'avon',
#   'un',
#   'groupe',
#   'à',
#   'jouer',
#   'à',
#   "l'",
#   'école',
#   '.'],
#  ['Il',
#   'est',
#   'à',
#   '3',
#   'heures',
#   'du',
#   'matin',
#   ',',
#   'je',
#   'suis',
#   'très',
#   'fatigué',
#   'mais',
#   'je',
#   'ne',
#   'peux',
#   'pa',
#   'dormir',
#   'mais',
#   'je',
#   "l'",
#   'essaye'],
#  ['Juste',
#   'à',
#   'la',
#   'maison',
#   'de',
#   "l'",
#   'hôpital',
#   ',',
#   'mon',
#   'nounou',
#   'eu',
#   'peur',
#   '.',
#   'Tout',
#   'est',
#   'bien',
#   ',',
#   'bien',
#   "qu'",
#   'heureusement'],
#  ['Paula',
#   '&',
#   'amp',
#   ';',
#   "J'",
#   'ai',
#   'eu',
#   'un',
#   'bon',
#   'convo',
#   'alors',
#   "qu'",
#   'elle',
#   'donnait',
#   'ce',
#   'fab',
#   'mani',
#   '*',
#   'pedi'],
#  ['En',
#   'essayant',
#   "d'",
#   'aller',
#   'dormir',
#   ',',
#   'je',
#   'manque',
#   'le',
#   'mari',
#   ',',
#   'et',
#   'je',
#   "l'",
#   'avais',
#   'venu',
#   'en',
#   'Ohio'],
#  ['Est',
#   'à',
#   'la',
#   'maison',
#   'tout',
#   'seul',
#   'et',
#   'ne',
#   'sait',
#   'pa',
#   'quoi',
#   'faire',
#   '.',
#   'Choses',
#   'à',
#   'faire',
#   ':',
#   'regarder',
#   'le',
#   'amis',
#   ',',
#   'dormir',
#   ',',
#   'se',
#   'laver',
#   ',',
#   'je',
#   'ne',
#   'sais',
#   'pa',
#   '.',
#   'Meh',
#   '.'],
#  ['Veut', 'ne', 'plus', 'être', 'malade', '!'],
#  ['13',
#   'dessins',
#   'vers',
#   'le',
#   'ba',
#   ',',
#   '6',
#   'pour',
#   'aller',
#   '.',
#   'Et',
#   'je',
#   'viens',
#   'de',
#   'nettoyer',
#   'le',
#   'toilette',
#   '.'],
#  ["D'",
#   'accord',
#   ',',
#   'alors',
#   'je',
#   'commence',
#   'enfin',
#   'ce',
#   'document',
#   'de',
#   '4',
#   'à',
#   '6',
#   'page',
#   '.',
#   '.',
#   '.',
#   'Si',
#   'heureuse',
#   ',',
#   "l'",
#   'école',
#   'est',
#   'presque',
#   'finie',
#   '...',
#   'la',
#   'petite',
#   'fille',
#   'est',
#   'allée',
#   'dormir',
#   'et',
#   'je',
#   'suis',
#   'fatiguée'],
#  ['♫', '~', '7fj77', 'happy', 'monday', '!', '!'],
#  ["J'",
#   'ai',
#   'passé',
#   'un',
#   'bon',
#   'moment',
#   'à',
#   'loris',
#   'dance',
#   '!',
#   'Notre',
#   'voyage',
#   'sur',
#   'la',
#   'route',
#   'était',
#   'amusant',
#   '.',
#   'A',
#   'dû',
#   'faire',
#   'notre',
#   'nursey',
#   'bit',
#   'et',
#   'aider',
#   'un',
#   'chien',
#   'touché',
#   'par',
#   'une',
#   'voiture',
#   '!',
#   '!',
#   'Bon',
#   'week',
#   '-',
#   'end',
#   '!'],
#  ['Moi',
#   'et',
#   'nikki',
#   'avon',
#   'eu',
#   'une',
#   'somme',
#   'en',
#   'religion',
#   ':',
#   'l',
#   ':',
#   'l',
#   '"',
#   'sœur',
#   '"',
#   '&',
#   'Quot',
#   ';',
#   'juste',
#   '...',
#   '&',
#   'quot',
#   ';',
#   'Sur',
#   'mon',
#   'propre',
#   ':',
#   'l',
#   ':',
#   'je',
#   'passe',
#   'go',
#   'n.b',
#   '.',
#   'Wooohooo',
#   ':',
#   'l',
#   ':',
#   'l',
#   ':',
#   'je',
#   "t'",
#   'aime'],
#  ['Aww', 'poor', 'little', 'guy'],
#  ['Oh',
#   ',',
#   'pa',
#   'parler',
#   "jusqu'",
#   'à',
#   '2',
#   'pouces',
#   'de',
#   'pluie',
#   'au',
#   'cours',
#   'de',
#   '2',
#   'prochains',
#   'jours',
#   '.',
#   'Je',
#   'pourrais',
#   'peut-être',
#   'sortir',
#   'du',
#   'sous-sol',
#   'à',
#   'nouveau',
#   '.',
#   'Et',
#   'il',
#   'se',
#   'faisait',
#   'sécher'],
#  ['Je',
#   'viens',
#   'de',
#   'lira',
#   'votre',
#   'réponse',
#   'dès',
#   'maintenant',
#   ',',
#   'je',
#   'suis',
#   'désolé',
#   ',',
#   'je',
#   "n'",
#   'ai',
#   'pa',
#   'répondu',
#   'plus',
#   'tôt',
#   '.',
#   "C'",
#   'était',
#   'sur',
#   'la',
#   'chaîne',
#   'de',
#   'football',
#   'du',
#   'renard',
#   '.'],
#  ['Aller', 'au', 'dentiste'],
#  ['Je',
#   'suis',
#   'un',
#   'grand',
#   'fan',
#   'de',
#   'Ryan',
#   'Sheckler',
#   ',',
#   'et',
#   "j'",
#   'ai',
#   'tous',
#   's',
#   'produits',
#   '.',
#   'Je',
#   'voulais',
#   'le',
#   'rencontrer',
#   'à',
#   'Londres',
#   "j'",
#   'espère',
#   'que',
#   'je',
#   'vais',
#   'vous',
#   'rencontrer',
#   'bientôt',
#   '.',
#   'paix',
#   '.'],
#  ['Soooooo',
#   'non',
#   'fou',
#   'de',
#   'personnes',
#   'que',
#   'je',
#   'suis',
#   ',',
#   'répondez',
#   '-moi'],
#  ["N'",
#   'ayant',
#   'pa',
#   'beaucoup',
#   'de',
#   'chance',
#   'ce',
#   'derniers',
#   'temp',
#   '?',
#   'Suce',
#   'être',
#   'vous',
#   '.'],
#  ['Omg',
#   'la',
#   'vidéo',
#   'de',
#   'ce',
#   'takkiii',
#   "m'",
#   'fait',
#   'pleurer',
#   '...',
#   '?',
#   'V',
#   '=',
#   'egnpptqqhbo',
#   'takkii',
#   "l'",
#   'air',
#   'tellement',
#   'triste',
#   'quand',
#   'il',
#   'pleure',
#   '!'],
#  ['Mon',
#   'équipe',
#   'perdu',
#   'de',
#   'sentiment',
#   'tristes',
#   'à',
#   "l'",
#   'intérieur',
#   '...',
#   'mais',
#   'de',
#   'toute',
#   'façon',
#   ',',
#   'allez',
#   'obtenir',
#   'le',
#   'nouvel',
#   'album',
#   'de',
#   'jb',
#   'demain',
#   '!',
#   'fais',
#   'le',
#   '!'],
#  ['Attention',
#   'à',
#   'ce',
#   'choses',
#   '!',
#   'Ce',
#   "n'",
#   'est',
#   'pa',
#   'bon',
#   'pour',
#   'vous',
#   'que',
#   'je',
#   'soupçonne',
#   '!',
#   'Nous',
#   'espérons',
#   'néanmoins',
#   'que',
#   'cela',
#   'vous',
#   'aidera',
#   'dans',
#   'vos',
#   'recherches',
#   '.',
#   'Dis',
#   'bonjour',
#   'à',
#   'randy',
#   '4',
#   'moi',
#   '!'],
#  ["J'",
#   'aimerais',
#   'bien',
#   'être',
#   'là',
#   'pour',
#   'vous',
#   'regarder',
#   'jouer',
#   'avec',
#   'le',
#   'frères',
#   'jonas',
#   '.'],
#  ["Aujourd'hui",
#   ',',
#   'je',
#   'ne',
#   'parle',
#   'pa',
#   'avec',
#   'Manu',
#   ',',
#   'je',
#   'suis',
#   'triste'],
#  ['Mes',
#   'deux',
#   'côtes',
#   'inférieures',
#   '(',
#   'à',
#   "l'",
#   'avant',
#   ')',
#   'sont',
#   'toujours',
#   'brunes',
#   'lorsque',
#   'je',
#   'réveille',
#   '.',
#   'Je',
#   'vais',
#   "d'",
#   'une',
#   'certaine',
#   'façon',
#   'dormir',
#   'sur',
#   'eux',
#   '.'],
#  ['Jouer',
#   'à',
#   "l'",
#   'un',
#   'avec',
#   'dulce',
#   'et',
#   'regarder',
#   'la',
#   'nouvelle',
#   'bande',
#   '-',
#   'annonce',
#   'de',
#   'la',
#   'lune'],
#  ['Aw',
#   'damn',
#   ',',
#   'je',
#   'ne',
#   'peux',
#   'pa',
#   'attendre',
#   'la',
#   'version',
#   'rb',
#   'beatles',
#   'hahaha'],
#  ['Est',
#   'excité',
#   'parce',
#   "qu'",
#   'lui',
#   'dit',
#   'combien',
#   'elle',
#   'était',
#   'géniale',
#   'à',
#   'son',
#   'travail'],
#  ['Comme',
#   'le',
#   'thé',
#   'de',
#   "l'",
#   'après-midi',
#   'ou',
#   'le',
#   'bday',
#   '?',
#   'Sevva',
#   'est',
#   'goooood',
#   'ou',
#   'obtenez',
#   'le',
#   'formes',
#   'que',
#   'nous',
#   'avon',
#   'vu',
#   'en',
#   'cakelicious',
#   'la',
#   'dernière',
#   'fois',
#   '...'],
#  ['huer', '!', 'No', 'rafa', 'wimbledon'],
#  ['*', 'Squee', '!', '*', 'Hey', 'beautiful', 'wifey', "'", 'mine', '.'],
#  ['Hahahaha',
#   'je',
#   'ne',
#   'peux',
#   'pa',
#   'dormir',
#   'et',
#   'maintenant',
#   "j'",
#   'ai',
#   'faim'],
#  ['Je',
#   'serai',
#   'sûr',
#   'de',
#   'vérifier',
#   'demain',
#   '!',
#   'Je',
#   'ferais',
#   'ce',
#   'soir',
#   ',',
#   'mais',
#   'je',
#   'ferai',
#   'mieux',
#   'de',
#   'coucher',
#   '.',
#   'Les',
#   'orages',
#   'tenaient',
#   'debout',
#   'toute',
#   'la',
#   'nuit'],
#  ['Vient',
#   'de',
#   'voir',
#   'avec',
#   'rachel',
#   ',',
#   'anielle',
#   'et',
#   'lynda',
#   '.',
#   'film',
#   'génial',
#   '!',
#   'Je',
#   'veux',
#   'le',
#   'revoir',
#   '!'],
#  ['Re',
#   ':',
#   'autoroute',
#   'de',
#   'anciens',
#   'combattants',
#   '-',
#   'bien',
#   'au',
#   'moins',
#   'il',
#   'beaucoup',
#   'de',
#   'pause',
#   'à',
#   'refléter',
#   '...'],
#  ['Hiiiiiiiii',
#   '!',
#   'Love',
#   'love',
#   'love',
#   'wish',
#   'wer',
#   'comin',
#   '2nyt',
#   'comin',
#   'gatecrasher',
#   'mercredi',
#   'prochain',
#   'pour',
#   'jossays',
#   'yeye',
#   'safe',
#   'sangé',
#   'x'],
#  ['Pardon',
#   '!',
#   'Si',
#   'cela',
#   'vous',
#   'rend',
#   'mieux',
#   ',',
#   'il',
#   "n'",
#   'ont',
#   'pa',
#   'ajouté',
#   'le',
#   'fromage',
#   'de',
#   'chèvre',
#   'que',
#   "j'",
#   'ai',
#   'demandé',
#   ',',
#   'lol',
#   '.'],
#  ["D'",
#   'accord',
#   ',',
#   "j'",
#   'ai',
#   'regardé',
#   'la',
#   'finale',
#   'de',
#   'saison',
#   'de',
#   'collines',
#   '.',
#   'Lauren',
#   ',',
#   'si',
#   'triste',
#   ',',
#   'est',
#   'allée',
#   'en',
#   'larmes',
#   '.',
#   'La',
#   'saison',
#   'prochaine',
#   'de',
#   'collines',
#   'serum',
#   'également',
#   'intéressante',
#   '.',
#   'Mmmm'],
#  ["c'", 'est', 'bien', '!'],
#  ['vraiment',
#   '?',
#   '?',
#   'Parce',
#   'que',
#   'vous',
#   'voulez',
#   'dire',
#   'beaucoup',
#   'pour',
#   'moi',
#   ',',
#   'je',
#   'ferais',
#   'beaucoup',
#   'pour',
#   'vous',
#   '.'],
#  ['Je',
#   'doi',
#   'travailler',
#   'sur',
#   'le',
#   'vendredi',
#   'et',
#   'le',
#   'samedi',
#   ',',
#   "c'",
#   'était',
#   '45',
#   'degrés',
#   ',',
#   'mon',
#   'seul',
#   'rafraîchissement',
#   "n'",
#   'était',
#   'que',
#   'le',
#   '"',
#   'idol',
#   'marathon',
#   '"',
#   ',',
#   'non',
#   'net'],
#  ['Ack',
#   '!',
#   'Oh',
#   'mec',
#   '.',
#   "J'",
#   'espérais',
#   'plus',
#   'tôt',
#   '.',
#   'Ah',
#   'bien',
#   ',',
#   'pratiquez',
#   'dans',
#   "l'",
#   'exercice',
#   'de',
#   'la',
#   'patience',
#   '.',
#   ';)'],
#  ['Travaillé',
#   'autour',
#   'de',
#   'la',
#   'maison',
#   'pendant',
#   'la',
#   'plus',
#   'grande',
#   'partie',
#   'de',
#   'la',
#   'matinée',
#   '!',
#   'Ce',
#   "n'",
#   'est',
#   'que',
#   '16',
#   'heures',
#   'et',
#   'je',
#   'suis',
#   'déjà',
#   'épuisé',
#   '!',
#   '(',
#   '(',
#   'Pauvre',
#   'petit',
#   'moi',
#   '!'],
#  ['Cool', ',', "j'", 'attends', 'de', 'nouvelles', 'mi', 'à', 'jour'],
#  ['Maintenant',
#   "c'",
#   'est',
#   'un',
#   'job',
#   'sr',
#   '.',
#   'Développeur',
#   'web',
#   '*',
#   'front',
#   '-',
#   'end',
#   '*',
#   'au',
#   'playboy'],
#  ['je', "l'", 'ai', '!', 'Je', 'suis', 'un', 'tel', 'perdant'],
#  ['Omfg',
#   "c'",
#   'est',
#   'tout',
#   '!',
#   'Je',
#   'vais',
#   'à',
#   'San',
#   'Francisco',
#   '!',
#   'Voyage',
#   'route',
#   'bébé',
#   '!',
#   '!',
#   '!'],
#  ['A',
#   'trouvé',
#   'une',
#   'nouvelle',
#   'glace',
#   'que',
#   "j'",
#   'aime',
#   'manger',
#   'appelée',
#   'chocolat',
#   'au',
#   'poudrier',
#   ';',
#   'La',
#   'glycémie',
#   'se',
#   'sent',
#   'mieux',
#   'maintenant'],
#  ['Oui',
#   '...',
#   "d'",
#   'une',
#   'manière',
#   'ou',
#   "d'",
#   'une',
#   'autre',
#   ',',
#   'tous',
#   'me',
#   'vieux',
#   'fring',
#   'sont',
#   'dans',
#   "l'",
#   'humeur',
#   'de',
#   'parler',
#   '...',
#   'je',
#   'démène',
#   'de',
#   'sujets',
#   'intimes',
#   'comme',
#   'un',
#   'fou',
#   ';)'],
#  ['que',
#   'suis',
#   '-je',
#   'en',
#   'train',
#   'de',
#   'faire',
#   '?',
#   'Essayant',
#   "d'",
#   'abandonner',
#   'le',
#   'tabac',
#   "c'",
#   'est',
#   'quoi',
#   '!',
#   'Grrrr',
#   '...',
#   'ce',
#   "n'",
#   'est',
#   "qu'",
#   'une',
#   'heure'],
#  ["aujourd'hui",
#   'est',
#   'un',
#   'bon',
#   'jour',
#   '.',
#   'Félicitations',
#   'à',
#   'tous',
#   'le',
#   'diplômés',
#   'où',
#   'sont',
#   '-ils',
#   'le',
#   'party',
#   'à',
#   '!',
#   '?',
#   'Haha',
#   '.',
#   'Gnna',
#   'get',
#   'fckd',
#   'tonite',
#   '!',
#   'Lol',
#   'sike'],
#  ['Mes', 'chat', 'dort'],
#  ['Pouvez',
#   '-vous',
#   "m'",
#   'expliquer',
#   'ce',
#   'que',
#   'je',
#   'doi',
#   'faire',
#   'lors',
#   'de',
#   'la',
#   'modification',
#   'de',
#   'la',
#   'photo',
#   'de',
#   'compte',
#   '?',
#   "S'",
#   'il',
#   'vous',
#   'plaît',
#   '........'],
#  ['Juste',
#   'une',
#   'mauvaise',
#   'expérience',
#   'avec',
#   'un',
#   'tweeter',
#   'et',
#   'devait',
#   'le',
#   'bloquer',
#   '.',
#   'Je',
#   'méfie',
#   'de',
#   'étrangers',
#   '.',
#   'Peut',
#   '-',
#   'être',
#   'que',
#   'je',
#   'ne',
#   'devrais',
#   'pa',
#   'être',
#   'si',
#   'amical'],
#  ['ce', "n'", 'est', 'pa', 'drôle', '.'],
#  ['Travail', 'vectoriel', 'incroyable', 'de', 'machine56'],
#  ["D'",
#   'accord',
#   ',',
#   "j'",
#   'ai',
#   'passé',
#   'une',
#   'longue',
#   'journée',
#   ',',
#   'alors',
#   'je',
#   'pense',
#   "qu'",
#   'il',
#   'est',
#   'temp',
#   'de',
#   'zzzzz',
#   '.',
#   'Merci',
#   'encore',
#   'pour',
#   'tout'],
#  ['Je',
#   'fausse',
#   'me',
#   'quiz',
#   'fb',
#   'pour',
#   'obtenir',
#   'de',
#   'bons',
#   'résultats',
#   '!',
#   'Apparemment',
#   ',',
#   'je',
#   'suis',
#   'chandler',
#   'sur',
#   'un',
#   'quiz',
#   ',',
#   "j'",
#   'ai',
#   'un',
#   'iq',
#   "d'",
#   'un',
#   'génie',
#   'sur',
#   'un',
#   'autre',
#   '.'],
#  ["Qu'", 'est', '-ce', 'qui', 'ne', 'va', 'pa'],
#  ['Ce',
#   "n'",
#   'est',
#   'pa',
#   'une',
#   'mauvaise',
#   'valeur',
#   'du',
#   'tout',
#   '!',
#   'Je',
#   'suis',
#   'malheureusement',
#   'totalement',
#   'coincé',
#   'pour',
#   'avoir',
#   'au',
#   'moins',
#   'le',
#   '32',
#   'gb',
#   'de',
#   "l'",
#   'arggghh'],
#  [':',
#   'Tsk',
#   'tsk',
#   ',',
#   'homme',
#   '.',
#   'Vous',
#   'demandez',
#   '-vous',
#   'de',
#   'faire',
#   'de',
#   'choses',
#   'encore',
#   '?',
#   'Maintenant',
#   ',',
#   'vous',
#   'savez',
#   'encore',
#   'une',
#   'autre',
#   'raison',
#   'pour',
#   'laquelle',
#   'je',
#   'suis',
#   'un',
#   'idiot',
#   '.'],
#  ['Le',
#   'chat',
#   'sort',
#   'du',
#   'sac',
#   'sur',
#   'la',
#   'montagne',
#   'ce',
#   'matin',
#   '.',
#   'Pas',
#   'de',
#   'spoiler',
#   'ici',
#   '!',
#   'Détails',
#   'après',
#   'le',
#   'deuxième',
#   'service'],
#  ['Est',
#   'tombé',
#   'en',
#   'pluie',
#   'et',
#   'le',
#   'sox',
#   'ont',
#   'perdu',
#   '=',
#   '(',
#   '...',
#   'mais',
#   'nous',
#   'nous',
#   'somme',
#   'amusés',
#   'de',
#   'toute',
#   'façon'],
#  ['Ok',
#   'pour',
#   'de',
#   'boissons',
#   'avec',
#   'le',
#   'garçons',
#   '.',
#   'Bonne',
#   'nuit',
#   'twitter'],
#  [',',
#   'Tout',
#   'le',
#   'monde',
#   'obtient',
#   'un',
#   'nouvel',
#   'iphone',
#   'mais',
#   'moi',
#   ',',
#   'donnez',
#   '-moi',
#   'un',
#   '!',
#   "j'",
#   'en',
#   'ai',
#   'besoin',
#   '!'],
#  ['Bon', 'voyage', '-', 'et', 'bonjour'],
#  ['Mes', 'appareils', 'donnent', 'de', 'ulcères', '!'],
#  ['Haha',
#   '...',
#   'mon',
#   'chien',
#   'continue',
#   'de',
#   "m'",
#   'appeler',
#   'son',
#   '«',
#   'maître',
#   '»',
#   '!',
#   'Ah',
#   '...',
#   'je',
#   'ne',
#   'suis',
#   'toujours',
#   'pa',
#   'sur',
#   'le',
#   'film',
#   '!',
#   '(;'],
#  ['En',
#   'écoutant',
#   'le',
#   'nouvel',
#   'album',
#   'shikari',
#   ',',
#   'Common',
#   'Dreads'],
#  ['Ac', 'est', 'essentiel'],
#  ['Que',
#   "c'",
#   'est',
#   'il',
#   'passé',
#   '?',
#   '?',
#   'Tu',
#   "m'",
#   'inquiété',
#   'chérie'],
#  ['oui',
#   '.',
#   'Une',
#   'heure',
#   'de',
#   'plus',
#   'à',
#   'parcourir',
#   '.',
#   'Puis',
#   "l'",
#   'église',
#   ',',
#   'puis',
#   'couche',
#   'moi',
#   '-',
#   'même',
#   '.',
#   'Je',
#   'vais',
#   'peut-être',
#   'passer',
#   'en',
#   'ligne',
#   'avant',
#   'de',
#   'travailler'],
#  ['Travaillé',
#   "aujourd'hui",
#   'dans',
#   'une',
#   'salle',
#   'de',
#   'gym',
#   'avec',
#   'flor',
#   '.'],
#  ['Je',
#   'ne',
#   'plaisante',
#   'pa',
#   "s'",
#   'il',
#   "n'",
#   'ont',
#   'pa',
#   'peint',
#   'la',
#   'couleur',
#   'de',
#   'la',
#   'peau',
#   '...',
#   'pourtant',
#   '...',
#   'mais',
#   'je',
#   'veux',
#   'dire',
#   'qui',
#   "l'",
#   'mi',
#   'en',
#   '2009',
#   '?'],
#  ['Haha',
#   "j'",
#   'ai',
#   'un',
#   'ami',
#   'qui',
#   'vient',
#   'en',
#   'ville',
#   'ce',
#   'week',
#   '-',
#   'end',
#   'prochain',
#   ',',
#   'alors',
#   'je',
#   'par',
#   'le',
#   'prochain',
#   'samedi',
#   'matin',
#   '!'],
#  ['Oui',
#   ',',
#   'je',
#   "m'",
#   'en',
#   'préoccupe',
#   'aussi',
#   '.',
#   "J'",
#   'ai',
#   'eu',
#   'ce',
#   "qu'",
#   'appelle',
#   'un',
#   '"',
#   'cirage',
#   'de',
#   'déjeuner',
#   '"',
#   '.',
#   'Pas',
#   'trop',
#   'agressif',
#   '.',
#   'Je',
#   'vais',
#   'vous',
#   'faire',
#   'savoir',
#   'comment',
#   'cela',
#   'se',
#   'passe',
#   '.'],
#  ['Triste',
#   "qu'",
#   'il',
#   "n'",
#   'aura',
#   'pa',
#   "d'",
#   'interview',
#   'et',
#   'de',
#   'banque',
#   "d'",
#   'état',
#   'de',
#   'kansa',
#   'en',
#   'raison',
#   'de',
#   'conflits',
#   'avec',
#   "l'",
#   'école'],
#  ['Merci',
#   'pour',
#   'le',
#   'deux',
#   'suivants',
#   'vendredi',
#   '!',
#   'Gros',
#   'smootch',
#   '!',
#   'Je',
#   'vais',
#   'faire',
#   'le',
#   'mien',
#   'plus',
#   'tard'],
#  ['Je', 'veux', 'être', 'mon', 'précepteur', '?'],
#  ['Les',
#   'anges',
#   'et',
#   'le',
#   'démons',
#   'étaient',
#   'incroyables',
#   '...',
#   'un',
#   'regard',
#   'valable',
#   '!'],
#  ['Désolé', 'je', 'suis', 'endormi', 'sur', 'vous', '.'],
#  ['mauvais',
#   'jour',
#   '.',
#   'Ma',
#   'mère',
#   'déjà',
#   'confirmé',
#   "qu'",
#   'elle',
#   'reviendrait',
#   'à',
#   'dubai',
#   'ce',
#   '5',
#   'juin',
#   '.',
#   "J'",
#   'espère',
#   'que',
#   'le',
#   'temp',
#   "s'",
#   'arrêtera',
#   '.'],
#  ['Le',
#   'premier',
#   'défi',
#   'de',
#   'compilation',
#   'de',
#   '30',
#   'jours',
#   'de',
#   'tsdc',
#   "s'",
#   'est',
#   'terminé',
#   '.',
#   'À',
#   'en',
#   'juger',
#   'pour',
#   'commencer',
#   "aujourd'hui",
#   '.',
#   'Devrait',
#   'être',
#   'rapide',
#   '.',
#   'Quelques',
#   'entrées'],
#  ['Ne',
#   'peut',
#   'pa',
#   'attendre',
#   'quand',
#   'est',
#   'la',
#   'sortie',
#   'unique',
#   '&',
#   'lt',
#   ';',
#   '3',
#   '..',
#   'x'],
#  ['Vous', 'êtes', 'le', 'bienvenus', '.'],
#  ['Sunyi', 'sepi', '.', 'Pasal', ',', 'soeur', "n'", 'est', 'pa', 'là', '.'],
#  ['Rien',
#   'de',
#   'pire',
#   'que',
#   "d'",
#   'obtenir',
#   'votre',
#   'chambre',
#   'réservée',
#   '...',
#   'mais',
#   'ce',
#   "n'",
#   'est',
#   'pa',
#   'ce',
#   'que',
#   'vous',
#   'avez',
#   'demandé',
#   '...',
#   'en',
#   'attendant',
#   'de',
#   'voir',
#   'comment',
#   'il',
#   'vont',
#   'le',
#   'réparer',
#   ',',
#   'ugh',
#   '!'],
#  ['Haha',
#   'ce',
#   "qu'",
#   'il',
#   'fait',
#   '.',
#   'Je',
#   'sais',
#   ',',
#   'je',
#   'doi',
#   'écouter',
#   'un',
#   'essai',
#   'complet',
#   'sur',
#   "l'",
#   'image',
#   'corporelle',
#   'et',
#   'la',
#   'santé',
#   ',',
#   'haha',
#   ',',
#   'que',
#   'faire',
#   'pour',
#   'le',
#   'chinois'],
#  ['Commence', 'mon', 'quart', 'de', 'clôture', '.', 'Cela', 'suce'],
#  ["C'",
#   'est',
#   "l'",
#   'heure',
#   'où',
#   "j'",
#   'adore',
#   'prendre',
#   'de',
#   'douche',
#   ',',
#   'tourner',
#   'cette',
#   'merde',
#   '!'],
#  ["Aujourd'hui",
#   ',',
#   'je',
#   'suis',
#   'venu',
#   'voir',
#   'mon',
#   'beau-frère',
#   'et',
#   'sa',
#   'famille',
#   '.',
#   'bonne',
#   'journée',
#   'à',
#   'ce',
#   'jour',
#   '!',
#   'Le',
#   'travail',
#   'en',
#   'cour',
#   'peut',
#   'être',
#   'le',
#   'plan',
#   'pour',
#   "l'",
#   'après-midi',
#   '.'],
#  ['Nous',
#   'avon',
#   'attaché',
#   'pour',
#   'le',
#   'premier',
#   '!',
#   '!',
#   '!',
#   '!',
#   'Alors',
#   'nous',
#   'avon',
#   'perdu',
#   'le',
#   'lol',
#   'tie',
#   'breaker',
#   ',',
#   'alors',
#   'nous',
#   'avon',
#   'obtenu',
#   'le',
#   'second',
#   '!'],
#  ['Nous',
#   'pension',
#   'que',
#   'vous',
#   'ne',
#   'suiviez',
#   'pa',
#   'le',
#   'maffei',
#   '.',
#   'Bon',
#   'de',
#   'savoir',
#   'que',
#   'nous',
#   'avon',
#   'eu',
#   'tort',
#   ',',
#   'car',
#   'il',
#   'se',
#   'met',
#   'rapidement',
#   'en',
#   'colère',
#   'et',
#   'est',
#   'difficile',
#   'à',
#   'apaiser'],
#  ['Regrette',
#   'instantanément',
#   'de',
#   'manger',
#   'de',
#   'la',
#   'mini',
#   'pizza',
#   '.',
#   "J'",
#   'aurais',
#   'aimé',
#   'que',
#   "j'",
#   'avais',
#   'le',
#   'temp',
#   'ce',
#   'matin',
#   'de',
#   'faire',
#   'le',
#   'déjeuner',
#   'à',
#   '1',
#   'milliard',
#   'de',
#   'kilomètres',
#   'plus',
#   'tard',
#   '?'],
#  ['Chillin', 'comme', 'un', 'polaire', 'dans', "l'", 'Arctique'],
#  ['Jour', 'le', 'plus', 'stressant', 'de', 'tous', 'le', 'temp'],
#  ["J'", 'ai', 'manqué', 'leur', 'idée', '♫', '~', '7gn8k'],
#  ['Voici',
#   'votre',
#   'page',
#   'Bebo',
#   'que',
#   "j'",
#   'ai',
#   'faite',
#   'pour',
#   'vous',
#   ',',
#   "j'",
#   'espère',
#   'que',
#   'vous',
#   'aimez'],
#  ['Je',
#   'viens',
#   'juste',
#   'de',
#   'réveiller',
#   '.',
#   'Je',
#   'ne',
#   'sais',
#   'pa',
#   'ce',
#   'que',
#   'je',
#   'vais',
#   'faire',
#   "aujourd'hui",
#   '.',
#   'Peut',
#   '-',
#   'être',
#   'laver',
#   'le',
#   'voitures',
#   'avec',
#   'de',
#   'la',
#   'paula',
#   'mais',
#   "c'",
#   'est',
#   'plutôt',
#   'chaud',
#   ',',
#   'donc',
#   'je',
#   'ne',
#   'suis',
#   'pa',
#   'sûr',
#   '.',
#   'Rien',
#   'à',
#   'la',
#   'télé',
#   'maintenant',
#   '...',
#   'ugh',
#   '!'],
#  ['Vient',
#   'de',
#   'terminer',
#   'le',
#   'dîner',
#   'dans',
#   'un',
#   'joli',
#   'restaurant',
#   'le',
#   'long',
#   'de',
#   'la',
#   'route',
#   'tanjong',
#   'pagar',
#   '.',
#   'Bonne',
#   'nourriture',
#   ',',
#   'prix',
#   'raisonnable',
#   '.',
#   'ça',
#   'en',
#   'vaut',
#   'la',
#   'peine',
#   '!'],
#  ['Les',
#   'textes',
#   'de',
#   'Twitter',
#   'sont',
#   'en',
#   'cours',
#   'pour',
#   'la',
#   'journée',
#   '.',
#   'Envoyez',
#   '-moi',
#   'un',
#   'message',
#   'si',
#   'vous',
#   'avez',
#   'besoin',
#   'de',
#   'moi',
#   'ou',
#   'voulez',
#   'juste',
#   'parler'],
#  ['Voulant',
#   'terminer',
#   'mon',
#   'combat',
#   ',',
#   'mais',
#   'le',
#   'client',
#   'doivent',
#   'se',
#   'rapprocher',
#   '.',
#   'Si',
#   'je',
#   'gagne',
#   ',',
#   'celebretory',
#   'taco',
#   'bell',
#   '.',
#   'Sinon',
#   ',',
#   'comfotaco',
#   'bell',
#   '.'],
#  ['Je',
#   'suis',
#   'fâché',
#   'par',
#   'son',
#   'travail',
#   '.',
#   'Merci',
#   'pour',
#   'le',
#   'conseil',
#   '(',
#   'trouvé',
#   'sur',
#   'votre',
#   'site',
#   ')',
#   '.',
#   'Elle',
#   'est',
#   'étonnante',
#   '.',
#   'Je',
#   'pense',
#   'que',
#   "c'",
#   'est',
#   'pourquoi',
#   'vous',
#   'avez',
#   'gagné',
#   'un',
#   'billet',
#   ';',
#   'Pour',
#   'nous',
#   'connecter',
#   '.'],
#  ['Oui',
#   ',',
#   'nous',
#   'devon',
#   'terminer',
#   'certains',
#   'commentaires',
#   'afin',
#   'que',
#   'nous',
#   'puissions',
#   'donner',
#   'plus',
#   'de',
#   'code',
#   'promotionnels',
#   ':',
#   '...'],
#  ['Bien',
#   ',',
#   'le',
#   'nouveaux',
#   'cuirs',
#   'sont',
#   'un',
#   'régal',
#   '.',
#   'Les',
#   'bébés',
#   'peuvent',
#   'avoir',
#   'besoin',
#   'de',
#   'se',
#   'briser',
#   'en',
#   'un',
#   'peu',
#   '.',
#   'Maintenant',
#   ',',
#   'posez',
#   'le',
#   'ba',
#   'en',
#   'arrière',
#   'et',
#   'le',
#   'vélo',
#   'ne',
#   'démarre',
#   'pa',
#   '.',
#   'Travailler',
#   'en',
#   'voiture',
#   '2',
#   'mardi'],
#  ['Sur', 'le', 'chemin', 'amyrah', 'zandra', 'home'],
#  ['Aller', 'au', 'poney', 'rose'],
#  ['Merci', 'najwa', '....', 'c', 'u', 'dans', '2', 'semaines', '.'],
#  ['Chicagopersonals',
#   'si',
#   'vous',
#   'avez',
#   'plus',
#   'de',
#   '25',
#   'an',
#   ',',
#   'venez',
#   "m'",
#   'aimer',
#   '(',
#   'south',
#   'chicagoland',
#   ')',
#   '27yr',
#   ':',
#   'je',
#   'suis',
#   'attentionné',
#   ',',
#   'goa',
#   '..'],
#  ['À', 'quelle', 'heure', 'finis', '-', 'tu', "l'", 'école', 'demain'],
#  ['Est', 'prêt', 'pour', 'le', 'voyage', 'de', 'me', 'fille', '!', '!'],
#  ['Sur',
#   'une',
#   'note',
#   'sérieuse',
#   ',',
#   'je',
#   'ne',
#   'sais',
#   'pa',
#   'où',
#   'est',
#   'mon',
#   'copain',
#   'ou',
#   'si',
#   'nous',
#   'somme',
#   'encore',
#   'ensemble',
#   '...',
#   'je',
#   "n'",
#   'ai',
#   'pa',
#   'entendu',
#   'parler',
#   'de',
#   'lui',
#   'depuis',
#   'vendredi',
#   'dernier',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['Je',
#   'suis',
#   'en',
#   'train',
#   'de',
#   'terminer',
#   'maintenant',
#   '.',
#   ':',
#   '/',
#   'Je',
#   'doi',
#   'faire',
#   'le',
#   'contour',
#   'et',
#   'la',
#   'biographie',
#   'réelle',
#   '.'],
#  ['Je', 'veux', 'être', 'Beyoncé', 'maintenant', '.'],
#  ['Merci', 'chéri'],
#  ['sound', 'de-lish', '.'],
#  ['Ont',
#   'eu',
#   'seulement',
#   '1',
#   'heure',
#   'de',
#   'sommeil',
#   'mais',
#   'je',
#   'suis',
#   'très',
#   'nerveuse',
#   'mais',
#   'froide'],
#  ["J'", 'ai', 'oublié', 'la', 'question'],
#  ['Elle',
#   'donne',
#   'une',
#   'pilule',
#   "d'",
#   'énergie',
#   ',',
#   'puis',
#   "m'",
#   'abandonne',
#   'au',
#   'pay',
#   'de',
#   'rêves',
#   '!',
#   'Hufffff'],
#  ['mauvais', 'jour'],
#  ['A', 'eu', 'un', 'excellent', 'dîner', 'et', 'est', 'allé', 'au', 'lit'],
#  ['Une',
#   'heure',
#   '35',
#   'minute',
#   "jusqu'",
#   'à',
#   "l'",
#   'iphone',
#   '3gs',
#   '.',
#   'Dois',
#   '-je',
#   'acheter',
#   '?',
#   'Ou',
#   'bâton',
#   'La',
#   'principale',
#   'chose',
#   'dont',
#   "j'",
#   'ai',
#   'besoin',
#   'est',
#   'le',
#   '32',
#   'gb',
#   '.'],
#  ['La',
#   'fille',
#   'qui',
#   'eu',
#   'le',
#   'cri',
#   'de',
#   'ddub',
#   'est',
#   'un',
#   'coucou',
#   '.',
#   'Vous',
#   'ne',
#   'voudriez',
#   'pa',
#   "l'",
#   'association',
#   '.',
#   'croyez',
#   '-moi',
#   '.'],
#  ['Ne',
#   'peut',
#   'pa',
#   'arrêter',
#   'de',
#   'regarder',
#   'neorago',
#   'sur',
#   'youtube',
#   '...',
#   'une',
#   'autre',
#   'performance',
#   'chaude',
#   'de',
#   'me',
#   'garçons',
#   '!'],
#  ['Mes',
#   'oreilles',
#   'sont',
#   'démangeaisons',
#   'à',
#   "l'",
#   'intérieur',
#   '.',
#   'Son',
#   'ennuyeux',
#   'meee'],
#  ['Mais',
#   "j'",
#   'ai',
#   'un',
#   'peu',
#   'peur',
#   'de',
#   'marcher',
#   'dans',
#   'cette',
#   'rue',
#   'dans',
#   'ce',
#   'ski',
#   '...',
#   'il',
#   'un',
#   'homme',
#   'sur',
#   'tous',
#   'le',
#   'coin',
#   '.',
#   "Quelqu'",
#   'un',
#   "m'",
#   'appelle'],
#  ['Est',
#   'allé',
#   '2',
#   'fois',
#   'il',
#   'quelque',
#   'temp',
#   '...',
#   "j'",
#   'étais',
#   'tellement',
#   'seul'],
#  ['Pourquoi', 'une', 'californie', 'si', 'froide', '?'],
#  ['Heureusement',
#   'après',
#   ',',
#   'un',
#   'tagine',
#   "n'",
#   'est',
#   'pa',
#   'un',
#   'résultat'],
#  ['Je', 'veux', 'partir', 'aussi', 'lenny', '....', '?', '~', '7cydo'],
#  ['Est',
#   'ridiculement',
#   'chaud',
#   'dans',
#   'son',
#   'appartement',
#   '...',
#   'mais',
#   'je',
#   'ne',
#   'peux',
#   'pa',
#   'attendre',
#   'ce',
#   'week',
#   '-',
#   'end'],
#  ['hey', 'ce', 'qui', 'se', 'passe'],
#  ['Poulet', 'frit', 'du', 'sud', '!', 'Miam', '!'],
#  ['Si', 'heureux', "d'", 'avoir', 'un', 'cerveau'],
#  ['Pour',
#   'le',
#   'film',
#   ',',
#   'mais',
#   'peut-être',
#   'que',
#   'je',
#   'suis',
#   'un',
#   'peu',
#   'génial',
#   '.'],
#  ['Ah',
#   'bien',
#   ',',
#   'même',
#   'si',
#   'je',
#   'ne',
#   'devais',
#   'pa',
#   'passer',
#   'devant',
#   'vous',
#   'pour',
#   'devenir',
#   'créatif',
#   'avec',
#   'le',
#   'moggy',
#   ',',
#   'la',
#   'manche',
#   ',',
#   'le',
#   'chat',
#   ',',
#   'la',
#   'manette',
#   'de',
#   'chat',
#   'mmm',
#   '....',
#   'ici',
#   'pus',
#   'pus',
#   '.'],
#  ['Prêt', 'à', 'marcher', 'et', 'son', 'seul', '1:24', '....'],
#  ['Lol',
#   'je',
#   'suis',
#   'jus',
#   'sayin',
#   'yall',
#   'toujours',
#   'gt',
#   'tha',
#   '411',
#   'lol'],
#  ['Bonjour', 'jayda', 'belle'],
#  ['Donc',
#   'je',
#   'suis',
#   'arrivé',
#   'à',
#   'la',
#   'conclusion',
#   ',',
#   'jacob',
#   'se',
#   'transforme',
#   'en',
#   'joli',
#   'loup',
#   '-',
#   'garou',
#   ',',
#   'sa',
#   'couleur',
#   'de',
#   'fourrure',
#   'est',
#   'si',
#   'magnifique',
#   '!',
#   '!'],
#  ['Avez', '-vous', 'préparé', 'la', 'bannière', '110', 'x', '80px', '?'],
#  ['Hey',
#   'lissette',
#   'comment',
#   'va',
#   '-',
#   'tu',
#   '?',
#   'Tout',
#   'le',
#   'plaisir',
#   'était',
#   'pour',
#   'moi'],
#  ['Bonjour',
#   '...',
#   'je',
#   'suis',
#   'nouveau',
#   'ici',
#   '...',
#   'enseigne',
#   '-moi',
#   'à',
#   'utiliser',
#   'ce',
#   'genre',
#   'de',
#   'site',
#   '...'],
#  ["c'",
#   'est',
#   'une',
#   'bonne',
#   'idée',
#   '.',
#   'Le',
#   'kilo',
#   'serait',
#   'un',
#   'grand',
#   'garde',
#   'du',
#   'corp',
#   ',',
#   'personne',
#   'ne',
#   'dérangerait',
#   '.',
#   "S'",
#   'il',
#   'vous',
#   'plaît',
#   ',',
#   'dites',
#   '-',
#   'lui',
#   'de',
#   'regarder',
#   'mon',
#   'do',
#   '...'],
#  ['Est',
#   '-ce',
#   'que',
#   "l'",
#   'une',
#   'de',
#   'chansons',
#   'de',
#   'votre',
#   'couverture',
#   '?',
#   "C'",
#   'est',
#   'une',
#   'excellente',
#   'chanson',
#   'par'],
#  ['Non', 'disponible', 'dans', 'mon', 'pay'],
#  ['Avez',
#   '-vous',
#   'déjà',
#   'pris',
#   'une',
#   'de',
#   'voile',
#   'de',
#   "l'",
#   'opéra',
#   '?',
#   "J'",
#   'ai',
#   'essayé',
#   'la',
#   'nuit',
#   'dernière',
#   'avec',
#   'petite',
#   'caméra',
#   ',',
#   'mais',
#   'je',
#   "n'",
#   'ai',
#   'pa',
#   'trop',
#   'marché',
#   '.'],
#  ['Gardez',
#   'à',
#   "l'",
#   'esprit',
#   "qu'",
#   'il',
#   'été',
#   'pris',
#   'avec',
#   'mon',
#   'téléphone',
#   ',',
#   'il',
#   'ne',
#   'le',
#   'fait',
#   'pa',
#   'justice'],
#  ['Sortir',
#   'à',
#   'la',
#   'maison',
#   'un',
#   'peu',
#   'puis',
#   'aller',
#   'à',
#   'sam',
#   '-',
#   'hanthas',
#   'open',
#   'house',
#   '!'],
#  ['Hablame', 'oh', 'bien', ',', 'il', 'toujours', "d'", 'autres'],
#  ['Merci',
#   'pour',
#   'le',
#   'conseil',
#   '...',
#   "j'",
#   'ai',
#   'effectivement',
#   'entendu',
#   'ça',
#   '.',
#   'Mais',
#   ',',
#   'parfois',
#   ',',
#   'je',
#   'sen',
#   'que',
#   'je',
#   'parle',
#   'tant',
#   'de',
#   'gen',
#   'vont',
#   'prendre',
#   'mal',
#   'de',
#   'moi',
#   'lol'],
#  ['Oh',
#   'bien',
#   ',',
#   'il',
#   'ont',
#   'encore',
#   'une',
#   'chance',
#   'la',
#   'prochaine',
#   'fois'],
#  ['Correction', ':', 'besoin', 'de', ' ', '6000'],
#  ['Vient',
#   "d'",
#   'arriver',
#   'dans',
#   'le',
#   'hampton',
#   'et',
#   'il',
#   'pleut',
#   '...',
#   '!',
#   '!'],
#  ['Moi',
#   'n',
#   'mon',
#   'bf',
#   'sure',
#   "s'",
#   'est',
#   'plaindé',
#   'de',
#   "l'",
#   'intrigue',
#   'que',
#   'nous',
#   'aimons',
#   'terminator',
#   '2',
#   'mieux',
#   '.',
#   'Mais',
#   "c'",
#   'était',
#   'correct',
#   '.',
#   'Je',
#   'lui',
#   'ai',
#   'donné',
#   'un',
#   '8/10'],
#  ['Omfg',
#   '!',
#   'Demi',
#   'était',
#   'en',
#   'Allemagne',
#   '?',
#   'Aaaaaaah',
#   "quelqu'",
#   'un',
#   'tue'],
#  ['Oh',
#   'oui',
#   ',',
#   'je',
#   'viens',
#   'de',
#   'recevoir',
#   'coke',
#   '-',
#   'zéro',
#   '400',
#   'billet',
#   'je',
#   'suis',
#   'tellement',
#   'excité'],
#  ['Sur',
#   'le',
#   'chemin',
#   'du',
#   'putain',
#   'de',
#   'zoo',
#   ',',
#   'je',
#   'souhaite',
#   'que',
#   'mon',
#   'mari',
#   'soit',
#   'avec',
#   'moi',
#   '.',
#   'Jamais',
#   'amusant',
#   'sans',
#   'lui',
#   '.'],
#  ['Hey',
#   'hey',
#   ',',
#   "j'",
#   'espère',
#   'vraiment',
#   'que',
#   'tu',
#   "m'",
#   'inscris',
#   '!',
#   '&',
#   'Lt',
#   ';',
#   '3',
#   'rachael'],
#  ['Eh',
#   'bien',
#   ',',
#   'ce',
#   "n'",
#   'est',
#   'pa',
#   'sympa',
#   "qu'",
#   'il',
#   'ait',
#   'bloqué',
#   'lol',
#   'bien',
#   'pour',
#   'que',
#   'tu',
#   'tweet',
#   'encore',
#   '!'],
#  ["C'",
#   'est',
#   'un',
#   'jeu',
#   'tellement',
#   'triste',
#   'que',
#   'je',
#   'ne',
#   'pense',
#   'pa',
#   'avoir',
#   'pu',
#   'le',
#   'faire',
#   'en',
#   'classe',
#   ',',
#   "j'",
#   'aurais',
#   'ressemblé',
#   'à',
#   'une',
#   'véritable',
#   'émotion',
#   'émotionnelle',
#   '...'],
#  ['A',
#   'décidé',
#   "d'",
#   'obtenir',
#   'un',
#   'itouch',
#   '32',
#   'gb',
#   'et',
#   'un',
#   'ihome',
#   'au',
#   'lieu',
#   "d'",
#   'un',
#   'xbox',
#   '360',
#   'pour',
#   'mon',
#   'anniversaire',
#   '.',
#   'Plus',
#   'de',
#   'temp',
#   'pour',
#   'runescape',
#   'de',
#   'cette',
#   'façon',
#   '.'],
#  ["J'",
#   'ai',
#   'appelé',
#   'le',
#   'magasin',
#   'de',
#   'CD',
#   '...',
#   'et',
#   'il',
#   "m'",
#   'ont',
#   'dit',
#   'que',
#   'lvatt',
#   'venait',
#   'peut-être',
#   'la',
#   'semaine',
#   'prochaine',
#   ',',
#   'je',
#   'veux',
#   'pleurer',
#   'maintenant',
#   '...',
#   'fml',
#   '.',
#   'Fml',
#   '.',
#   'Fml',
#   '.',
#   'Fml',
#   '.',
#   'Fml',
#   '.',
#   'Fml',
#   '.'],
#  ["J'",
#   'ai',
#   "l'",
#   'impression',
#   'de',
#   'boucler',
#   'me',
#   'cheveux',
#   "aujourd'hui",
#   '...',
#   'mais',
#   'alors',
#   'je',
#   'suis',
#   'paresseux'],
#  ['Fait', 'son', 'foodtecc'],
#  ["J'",
#   'ai',
#   'entendu',
#   'dire',
#   'que',
#   'le',
#   'temp',
#   'est',
#   'en',
#   'vrac',
#   'dans',
#   'le',
#   'bouffées',
#   'torrentielles',
#   '.',
#   'Il',
#   'est',
#   'parfait',
#   'dans',
#   'le',
#   'palmes',
#   '.',
#   'Été',
#   '&',
#   'lt',
#   ';',
#   '3'],
#  ['Était',
#   'tellement',
#   'content',
#   'de',
#   'partager',
#   "l'",
#   'accomplissement',
#   'de',
#   'soeur',
#   ',',
#   'même',
#   'si',
#   'elle',
#   'nous',
#   'nourrissait',
#   'trop',
#   'de',
#   'nourriture',
#   '.',
#   "C'",
#   'était',
#   'délicieux',
#   'cependant',
#   '.'],
#  ['La',
#   'douche',
#   "m'",
#   'fait',
#   'sentir',
#   'mieux',
#   'de',
#   'préparer',
#   'à',
#   'la',
#   'vie',
#   'sociale'],
#  ['A',
#   'réussi',
#   'à',
#   'bourrer',
#   'son',
#   'ventre',
#   '.',
#   ':',
#   '&',
#   'Amp',
#   ';',
#   '*',
#   'Veut',
#   'manger',
#   'plus',
#   '*'],
#  ['Vient',
#   'de',
#   'rentrer',
#   'à',
#   'la',
#   'maison',
#   '.',
#   'Le',
#   'gin',
#   'et',
#   'le',
#   'tonique',
#   'ont',
#   'tellement',
#   'baissé',
#   '...',
#   'ont',
#   'dansé',
#   'avec',
#   'me',
#   'chiennes',
#   ',',
#   'mais',
#   'ont',
#   'dû',
#   'sauter',
#   'le',
#   'dernier',
#   'après-midi',
#   'de',
#   'sortie'],
#  ['Dimanche',
#   'du',
#   'golf',
#   '...',
#   'vérifier',
#   '.',
#   'Tuyau',
#   'de',
#   'drainage',
#   'soutenu',
#   'dans',
#   'le',
#   'sous-sol',
#   '...',
#   'vérifier',
#   '.',
#   'Quelle',
#   'façon',
#   'de',
#   'finir',
#   'un',
#   'week',
#   '-',
#   'end'],
#  ['Je',
#   "n'",
#   'ai',
#   'jamais',
#   'eu',
#   'de',
#   'chance',
#   "d'",
#   'obtenir',
#   'le',
#   'jb',
#   'pour',
#   'tweet',
#   '/',
#   'myspace',
#   'ou',
#   'livechat',
#   'moi'],
#  ["j'", 'imagine', '.', 'Il', "m'", 'volé', 'une', 'voiture', '.'],
#  ['Cape',
#   'de',
#   'pluie',
#   'type',
#   'de',
#   'journée',
#   'autour',
#   'de',
#   "l'",
#   'usine',
#   'ewa',
#   '-',
#   'marine',
#   'en',
#   'Allemagne',
#   'du',
#   'Sud',
#   '...',
#   'mais',
#   '...',
#   'pour',
#   'tous',
#   'le',
#   'dslrs'],
#  ['Au',
#   'lit',
#   'se',
#   'sentant',
#   'comme',
#   'une',
#   'merde',
#   'après',
#   'avoir',
#   'séjourné',
#   'pour',
#   'regarder',
#   "l'",
#   'ufc',
#   '!',
#   '!',
#   'besoin',
#   'de',
#   'plus',
#   'de',
#   'sommeil',
#   '!',
#   '!',
#   'mal',
#   '!'],
#  ['Examens', 'ewww'],
#  ['Ce',
#   'dont',
#   "j'",
#   'ai',
#   'vraiment',
#   'besoin',
#   ',',
#   "c'",
#   'est',
#   'une',
#   'plage',
#   '!'],
#  ['Tellement',
#   'excité',
#   '.',
#   'Planifier',
#   'une',
#   'aventure',
#   'européenne',
#   'con',
#   'mi',
#   'amiga',
#   'becca'],
#  ['Pluie',
#   'arrive',
#   'enfin',
#   ',',
#   'drat',
#   '.',
#   'Devinez',
#   'que',
#   'cela',
#   'signifie',
#   'que',
#   'nous',
#   'devrons',
#   'faire',
#   'du',
#   'pique-nique',
#   'dans',
#   'le',
#   'salon',
#   'au',
#   'lieu',
#   'de',
#   'passer',
#   'au',
#   'wolftrap',
#   'tonite',
#   '.'],
#  ['Prier',
#   'pour',
#   'le',
#   'soleil',
#   '-',
#   'ne',
#   'pa',
#   'jouer',
#   'à',
#   'la',
#   'mode',
#   ',',
#   'peinture',
#   'et',
#   'pompier',
#   'sam',
#   'en',
#   'boucle',
#   '-',
#   'le',
#   'châteaux',
#   'de',
#   'sable',
#   'et',
#   'le',
#   'glaces',
#   'sont',
#   'beaucoup',
#   'plus',
#   'amusants'],
#  ['Jeté',
#   'et',
#   'tourné',
#   'toute',
#   'la',
#   'sooooooooo',
#   'fatigué',
#   '.',
#   'Ne',
#   'voulant',
#   'pa',
#   'être',
#   'au',
#   'travail',
#   '.'],
#  ["J'",
#   'ai',
#   'donc',
#   'voulu',
#   'que',
#   'mon',
#   'restaurant',
#   'chinois',
#   'local',
#   'porte',
#   'tout',
#   'le',
#   'tofu'],
#  ['veut', 'sleeeeep', '!', '!', 'si', 'fatigué'],
#  ['Park',
#   '+',
#   'amis',
#   '+',
#   'fam',
#   '+',
#   'mall',
#   '(',
#   'tanforan',
#   ')',
#   '+',
#   'jollibee',
#   '+',
#   'pierre',
#   'froide',
#   '=',
#   'satisfaction',
#   'complète'],
#  ['La',
#   'mauvaise',
#   'chance',
#   'nous',
#   'désavoue',
#   "d'",
#   'avoir',
#   'de',
#   'belle',
#   'choses',
#   '.'],
#  ['Ow',
#   ',',
#   'le',
#   'casquettes',
#   'de',
#   'la',
#   'faute',
#   'ont',
#   'mangé',
#   'mon',
#   'âme',
#   ',',
#   'et',
#   'paof',
#   'mon',
#   'visage'],
#  ['...',
#   'mais',
#   'alors',
#   ',',
#   'qui',
#   'suis',
#   '-je',
#   'pour',
#   'parler',
#   'avec',
#   'cette',
#   'écharpe',
#   'à',
#   'la',
#   'remorque'],
#  ['Hihihihihi',
#   ')',
#   ')',
#   ')',
#   'vous',
#   "n'",
#   'êtes',
#   'jamais',
#   'perdu',
#   'pour',
#   'une',
#   'réponse',
#   'mon',
#   'cowboy',
#   'somnambule'],
#  ['Bien',
#   'voir',
#   'ce',
#   'personnes',
#   'au',
#   'moins',
#   'savaient',
#   'que',
#   "c'",
#   'était',
#   'un',
#   'véritable',
#   'espace',
#   'de',
#   'stationnement',
#   'contrairement',
#   'à',
#   'certaines',
#   'personnes',
#   'que',
#   'je',
#   'connais',
#   '...',
#   'calculatrices',
#   'annd',
#   ',',
#   'imprimantes',
#   ',',
#   'etc.'],
#  ['Non', ',', 'je', 'ne', 'le', 'crois', 'pa'],
#  ['à',
#   'M',
#   '!',
#   '!',
#   'Je',
#   'suis',
#   'allé',
#   'sur',
#   'le',
#   'trébuchement',
#   ',',
#   'et',
#   'je',
#   'ne',
#   'pouvais',
#   'pa',
#   'trouver',
#   'comment',
#   'supprimer',
#   'le',
#   'animaux',
#   ',',
#   'alors',
#   'je',
#   'pensais',
#   'être',
#   'courageux',
#   ',',
#   'et',
#   'le',
#   'premier',
#   'trébucher',
#   'était',
#   'un',
#   'requin'],
#  ['Malheureusement',
#   'sur',
#   'mon',
#   'chemin',
#   'de',
#   'retour',
#   'à',
#   'la',
#   'maison',
#   '4rm',
#   'tampa',
#   '.',
#   'Je',
#   'ne',
#   'veux',
#   'pa',
#   'aller',
#   'au',
#   'Bacc',
#   '!',
#   '!',
#   '!'],
#  ['Un',
#   'peu',
#   'ivre',
#   'après',
#   'avoir',
#   'bu',
#   'à',
#   "l'",
#   'école',
#   '...',
#   'dernier',
#   'jour',
#   '!'],
#  ['En',
#   'regardant',
#   'le',
#   'mec',
#   'avec',
#   'le',
#   'poteau',
#   'dans',
#   'son',
#   'œil',
#   '.'],
#  ['Le',
#   'constructeur',
#   'est',
#   'tellement',
#   'mignon',
#   'avec',
#   'le',
#   'chat',
#   'aw',
#   '!'],
#  ['Est',
#   'triste',
#   '&',
#   'amp',
#   ';',
#   'amp',
#   ';',
#   'Je',
#   'vais',
#   'regarder',
#   'tbbt',
#   '(',
#   "j'",
#   'espère',
#   ')',
#   'animer',
#   '♥'],
#  ["C'",
#   'est',
#   'tellement',
#   'bouleversant',
#   '.',
#   'Elle',
#   'et',
#   'Ryan',
#   "n'",
#   'ont',
#   'jamais',
#   'eu',
#   'la',
#   'chance',
#   'de',
#   'se',
#   'marier'],
#  ['3', 'jours', ',', 'je', 'vais', 'au', 'festival', 'du', 'film', 'Tribeca'],
#  ['Essayez',
#   "d'",
#   'trouver',
#   'une',
#   'application',
#   'mobile',
#   'qui',
#   'fonctionne'],
#  ['Woooo',
#   'fait',
#   'le',
#   'travail',
#   'pour',
#   'le',
#   'week',
#   '-',
#   'end',
#   ',',
#   "j'",
#   'aime',
#   'avoir',
#   'weekend',
#   'hors'],
#  ['Et',
#   'maintenant',
#   ',',
#   'je',
#   'vais',
#   'au',
#   'lit',
#   'dire',
#   '...',
#   'une',
#   'copie',
#   'pour',
#   'une',
#   'autre',
#   'nouvelle',
#   'niche',
#   'est',
#   'dans',
#   'la',
#   'boîte',
#   '...',
#   'je',
#   'retrouve',
#   'dans',
#   "l'",
#   'écriture',
#   '&',
#   'groot',
#   '&',
#   'quot',
#   ';',
#   'dernièrement'],
#  ['Tout',
#   'ce',
#   'que',
#   'je',
#   'peux',
#   'dire',
#   "c'",
#   'est',
#   'deux',
#   'mot',
#   '...',
#   'ce',
#   'soir',
#   'était',
#   'délicieux'],
#  ['Oh',
#   'oui',
#   ',',
#   'le',
#   'croisement',
#   ',',
#   'puis',
#   'le',
#   'gamin',
#   'de',
#   "moe'",
#   'bc',
#   'mangent',
#   'gratuitement',
#   '...',
#   'ça',
#   'semble',
#   'avoir',
#   'décidé'],
#  ['Ça', "l'", 'air', 'très', 'bien'],
#  ['moi',
#   'aussi',
#   '.',
#   "J'",
#   'aimerais',
#   "n'",
#   'avoir',
#   'pa',
#   'lu',
#   'le',
#   'règlement',
#   'londonien'],
#  ['Lol',
#   'je',
#   'suppose',
#   'que',
#   'mon',
#   'bufffff',
#   'vous',
#   'donne',
#   'de',
#   'accessoires',
#   'pour',
#   'avoir',
#   '90',
#   '%',
#   'de',
#   'son',
#   'test'],
#  ['Yall',
#   'continuez',
#   ',',
#   'je',
#   'pense',
#   'que',
#   "l'",
#   'imma',
#   'le',
#   'lance',
#   'avec',
#   'mon',
#   'mec',
#   '2',
#   'nuits'],
#  ['Est',
#   'seul',
#   'ici',
#   'au',
#   'café',
#   'de',
#   'kublai',
#   '.',
#   'Je',
#   'demande',
#   'où',
#   'sont',
#   'le',
#   'autres',
#   'organisateurs'],
#  ['En',
#   'élevant',
#   'et',
#   'en',
#   "l'",
#   'aimant',
#   '...',
#   "n'",
#   'ont',
#   'pa',
#   'fumé',
#   'depuis',
#   'si',
#   'longtemps'],
#  ['L4d',
#   'est',
#   'un',
#   'jeu',
#   'formidable',
#   ',',
#   'plus',
#   'tard',
#   ',',
#   'je',
#   'serais',
#   'ravi',
#   'de',
#   'rejoindre',
#   'si',
#   'vous',
#   'avez',
#   'besoin',
#   "d'",
#   'un',
#   'autre',
#   'joueur'],
#  ['Claqué',
#   'la',
#   'porte',
#   'de',
#   "l'",
#   'avant',
#   'alors',
#   'que',
#   "j'",
#   'étais',
#   'entré',
#   'dans',
#   'la',
#   'voiture',
#   ',',
#   "j'",
#   'étais',
#   'super',
#   'pissé',
#   'et',
#   'brisé',
#   'le',
#   'pare-brise',
#   '.',
#   'Incroyable',
#   ',',
#   'sinon',
#   ',',
#   "j'",
#   'ai',
#   '2',
#   'salaire',
#   '4'],
#  ['Je',
#   'ne',
#   'veux',
#   'pa',
#   'voir',
#   'ton',
#   'visage',
#   'moche',
#   'internet',
#   'est',
#   'juste'],
#  ['Peut',
#   '-',
#   'être',
#   'est',
#   '-ce',
#   'un',
#   'signe',
#   'pour',
#   'moi',
#   'de',
#   'ne',
#   'pa',
#   'faire',
#   'de',
#   'magasin',
#   'puisque',
#   'la',
#   'comp',
#   'de',
#   'mère',
#   'agit',
#   'de',
#   'manière',
#   'extrêmement',
#   'spéciale'],
#  ['Abonnez', '-vous', 'à', 'page', 'youtube', "s'", 'il', 'vous', 'plaît'],
#  ['Chantait',
#   'pendant',
#   'toute',
#   'la',
#   'leçon',
#   "d'",
#   'anglais',
#   ',',
#   "c'",
#   'était',
#   'drôle',
#   '.',
#   'Et',
#   'également',
#   'joué',
#   'au',
#   'football',
#   "aujourd'hui"],
#  ['Mon', 'chat', 'gratté', 'mon', 'visage', '.'],
#  ['Aller',
#   'magique',
#   '...',
#   'nous',
#   'allons',
#   'battre',
#   'le',
#   'twit',
#   'de',
#   'lakers',
#   'lolz'],
#  ['Hou',
#   'la',
#   'la',
#   '!',
#   'Beaucoup',
#   'de',
#   'nouveaux',
#   'testeurs',
#   'bêta',
#   'ce',
#   'week',
#   '-',
#   'end',
#   '.',
#   "J'",
#   'espère',
#   'que',
#   'le',
#   'gen',
#   "s'",
#   'amusent',
#   '...',
#   '(',
#   'et',
#   'signalent',
#   'de',
#   'bug',
#   ')'],
#  ['Chatta',
#   'avec',
#   'ta',
#   'tante',
#   'où',
#   'est-elle',
#   '?',
#   'Oo',
#   'ic',
#   ',',
#   'ont',
#   '-ils',
#   'utilisé',
#   'cosu',
#   '?',
#   'Hm',
#   ',',
#   'lyl',
#   'idk',
#   'wht',
#   '2',
#   '...',
#   'ennuyé'],
#  ['Nikka',
#   '.',
#   'Haha',
#   '.',
#   'Je',
#   'pensais',
#   'que',
#   'magkita',
#   'ta',
#   '?',
#   'Awww',
#   '.',
#   'Ma',
#   'miss',
#   'namo',
#   'imo',
#   'kabuang',
#   '!',
#   'Hapit',
#   'na',
#   'skool',
#   '.',
#   'Ana',
#   'ka',
#   '.',
#   'Briser',
#   'no',
#   'cœurs',
#   '.',
#   'hahaha',
#   '.'],
#  ['Noirs', 'au', 'Space', 'Party', 'lol'],
#  ['Passe', 'une', 'bonne', 'journée', '!', 'Anniversaire', 'girrrl'],
#  ['Quoi',
#   "qu'",
#   'il',
#   'en',
#   'soit',
#   'Mieux',
#   'que',
#   'le',
#   'mien',
#   '...',
#   'un',
#   'peu',
#   '?',
#   'Roarrr',
#   ',',
#   'fmlllllllll',
#   '!',
#   'Karman',
#   '=',
#   'bio',
#   'fail',
#   '.',
#   'Non',
#   ',',
#   'faites',
#   'échouer',
#   "l'",
#   'épopée',
#   'scientifique',
#   '.'],
#  ['Cousin',
#   'disparu',
#   'ont',
#   'eu',
#   'un',
#   'beau',
#   'week',
#   '-',
#   'end',
#   ',',
#   'retour',
#   'à',
#   'la',
#   'révision',
#   'maintenant',
#   'ah',
#   'bien',
#   'doit',
#   'être',
#   'fait',
#   '!'],
#  ["Aujourd'hui", ',', 'ce', "n'", 'est', 'pa', 'un', 'bon', 'début', '.'],
#  ['Peut',
#   'entendre',
#   'le',
#   'tonnerre',
#   '!',
#   '!',
#   '!',
#   '&',
#   'Lt',
#   ';',
#   '3',
#   'plus',
#   "s'",
#   'il',
#   'vous',
#   'plait',
#   '!'],
#  ["Aujourd'hui",
#   ',',
#   'ce',
#   'serum',
#   'un',
#   'pur',
#   'travail',
#   'à',
#   '100',
#   '%',
#   '!',
#   'Non',
#   'msn',
#   ',',
#   'fb',
#   'et',
#   'twitter',
#   '!',
#   'après',
#   'ça'],
#  ['Nouveau',
#   'chanteur',
#   '?',
#   "J'",
#   'aurais',
#   'aimé',
#   'savoir',
#   'à',
#   'ce',
#   'sujet'],
#  ['2525', ':', 'dank', 'je', 'wel', ',', 'en', 'besoin'],
#  ['Je', 'veux', 'aller', 'à', 'la', 'piscine'],
#  ['Je',
#   'doi',
#   'seulement',
#   'regarder',
#   'm',
#   'elseas',
#   'face',
#   'pendant',
#   'cinq',
#   'jours',
#   'de',
#   'plus',
#   'deux',
#   'an',
#   'avec',
#   'cette',
#   'femme',
#   'était',
#   'trop',
#   '!'],
#  ['À',
#   'moins',
#   'que',
#   'vous',
#   'ne',
#   'vouliez',
#   'le',
#   'faire',
#   'deux',
#   'jours',
#   'de',
#   'suite',
#   ',',
#   'nous',
#   'devrons',
#   'continuer',
#   'un',
#   'autre',
#   'jour',
#   '.'],
#  ['Je',
#   'suis',
#   'tellement',
#   'fatigué',
#   "d'",
#   'un',
#   'mauvais',
#   'jour',
#   'après',
#   "l'",
#   'autre',
#   '...',
#   "j'",
#   'abandonne',
#   '...'],
#  ['Oh',
#   'wow',
#   '!',
#   'Ceux',
#   '-',
#   'ci',
#   'sont',
#   'bons',
#   '!',
#   '!',
#   '&',
#   'Amp',
#   ';',
#   '&',
#   'amp',
#   ';',
#   "c'",
#   'est',
#   'une',
#   'chanson',
#   '!',
#   'Vous',
#   'devriez',
#   'jouer',
#   'un',
#   'jour',
#   'et',
#   'le',
#   'mettre',
#   'sur',
#   'youtube',
#   'ou',
#   'quelque',
#   'chose',
#   'comme',
#   'ça',
#   '?',
#   'Haha',
#   '.'],
#  ['Personne', "d'", 'autre', "n'", 'est', 'éveillé'],
#  ['Vraiment',
#   'douloureux',
#   '.',
#   "j'",
#   'ai',
#   'besoin',
#   "d'",
#   'un',
#   'massage',
#   '.',
#   'Comme',
#   '4real'],
#  ['Je',
#   'ne',
#   'sais',
#   'pa',
#   'pourquoi',
#   ',',
#   'mais',
#   'il',
#   "n'",
#   'pa',
#   'envoyé',
#   'mon',
#   'dernier',
#   'tweet',
#   'à',
#   'zomg',
#   'moto',
#   'driveby'],
#  ['Tu', 'nous', 'manques', '!', '!', '!'],
#  ['Ma',
#   'mère',
#   'dit',
#   'que',
#   'je',
#   'ressemblais',
#   'à',
#   'un',
#   'nerd',
#   '.',
#   'Cela',
#   'fait',
#   'mal',
#   'à',
#   'me',
#   'sentiment',
#   'et',
#   'ensuite',
#   'je',
#   'lui',
#   'ai',
#   'dit',
#   '"',
#   'ne',
#   'pa',
#   'taurez',
#   '.',
#   '&',
#   'Quot',
#   ';'],
#  ['Je',
#   'travaille',
#   "jusqu'",
#   'au',
#   'moins',
#   'minuit',
#   ',',
#   'alors',
#   'je',
#   'suppose',
#   'que',
#   'je',
#   "n'",
#   'ai',
#   'pa',
#   'une',
#   'chance',
#   '.'],
#  ['Non',
#   ',',
#   'il',
#   "n'",
#   'pa',
#   'compris',
#   '.',
#   'Le',
#   'mobile',
#   "s'",
#   'est',
#   'égaré',
#   'tard',
#   '.',
#   'Ne',
#   'pa',
#   'laisser',
#   'passer',
#   'le',
#   'appels',
#   ',',
#   'le',
#   'sm',
#   'arrivent',
#   '2',
#   'jours',
#   'de',
#   'retard',
#   'etc'],
#  ["J'",
#   'adore',
#   'le',
#   'temple',
#   'de',
#   'Shirley',
#   'aussi',
#   '!',
#   'Maintenant',
#   'je',
#   'veux',
#   'un'],
#  ['Et',
#   "l'",
#   'Internet',
#   'fonctionne',
#   'encore',
#   'votre',
#   'bra',
#   'aussi',
#   ',',
#   'la',
#   'vie',
#   'est',
#   'bonne'],
#  ['Demain', 'dianna', 'vous', 'appellera'],
#  ['Los', 'Lupes', 'à', 'irving', 'avec', 'la', 'familia'],
#  ["J'",
#   'ai',
#   'juste',
#   'expérimenté',
#   'que',
#   "c'",
#   'est',
#   'agréable',
#   'de',
#   'faire',
#   'du',
#   'chien',
#   'me',
#   'propres',
#   'outils',
#   '.',
#   'Me',
#   'donner',
#   'de',
#   'commentaires',
#   'tout',
#   'le',
#   'temp',
#   '.',
#   'très',
#   'puissant',
#   '!'],
#  ['Considérant',
#   'la',
#   'crème',
#   'glacée',
#   'pour',
#   'le',
#   'petit-déjeuner',
#   '...',
#   'à',
#   'la',
#   'routine',
#   'du',
#   'matin',
#   '!',
#   'Avoir',
#   'un',
#   'grand',
#   'twitter'],
#  ['Regarde',
#   'actuellement',
#   'le',
#   'crépuscule',
#   'sur',
#   'dvd',
#   'et',
#   'souhaite',
#   'que',
#   'Edward',
#   'Cullen',
#   'soit',
#   'à',
#   'moi',
#   'tout',
#   'le',
#   'mien',
#   ',',
#   'haha'],
#  ['Aaa', '....', 'ne', 'sais', 'pa', 'quoi', 'faire'],
#  ['Oui',
#   ',',
#   'il',
#   'faut',
#   'avoir',
# ...
#   'appeler',
#   'maintenant',
#   'lol'],
#  ['Au',
#   'magasin',
#   'de',
#   'sprint',
#   'pour',
#   'voir',
#   "s'",
#   'il',
#   'peuvent',
#   'comprendre',
#   'que',
#   'caméra',
#   'ne',
#   'fonctionne',
#   'pa'],
#  ['Oui',
#   ',',
#   "j'",
#   'avais',
#   'beaucoup',
#   'de',
#   'problèmes',
#   'avec',
#   'tj',
#   'aussi',
#   ',',
#   "j'",
#   'avais',
#   'de',
#   'la',
#   'chance',
#   'la',
#   'première',
#   'fois',
#   'que',
#   'la',
#   'première',
#   'nuit',
#   'était',
#   'inaudible',
#   '.',
#   'Mais',
#   'une',
#   'deuxième',
#   'chance',
#   'est',
#   'venue'],
#  ['Les',
#   'lapin',
#   'sont',
#   'de',
#   'animaux',
#   'vicieux',
#   '.',
#   'Avez',
#   '-vous',
#   'vu',
#   'le',
#   'film',
#   'monty',
#   'python',
#   'saint',
#   'grail',
#   '?',
#   'Ce',
#   'lapin',
#   'était',
#   'un',
#   'monstre',
#   '.'],
#  ["c'",
#   'est',
#   'chaud',
#   '.',
#   "J'",
#   'ai',
#   'adoré',
#   'le',
#   '&',
#   'quot',
#   ';',
#   'chaque',
#   'fille',
#   '&',
#   'quot',
#   ';',
#   'Freestyle',
#   '.',
#   'La',
#   '"',
#   'anticipation',
#   '"',
#   'Pour',
#   '"',
#   'ready',
#   '"',
#   'quot',
#   ';',
#   'Commence',
#   'ici',
#   '&',
#   'quot',
#   ';',
#   'Yuuup'],
#  ['Pour',
#   'une',
#   'raison',
#   'quelconque',
#   ',',
#   'Corona',
#   'Light',
#   'goûte',
#   'tellement',
#   'mieux',
#   'quand',
#   'je',
#   'suis',
#   'avec',
#   'vous',
#   'que',
#   'quand',
#   'je',
#   'suis',
#   'seul',
#   '.'],
#  ['Merci', 'andy', 'crevette', 'barbe', 'louisiana'],
#  ['Ahh',
#   "'",
#   'longview',
#   "'",
#   'au',
#   'cours',
#   'de',
#   'la',
#   'journée',
#   'verte',
#   '-',
#   'rappelle',
#   "d'",
#   'essayer',
#   'de',
#   'jurer',
#   'aussi',
#   'fort',
#   'que',
#   'je',
#   'pourrais',
#   "m'",
#   'exprimer',
#   'dessus',
#   'lol'],
#  ['En',
#   'écoutant',
#   'quelque',
#   'chose',
#   'à',
#   'bo',
#   'Burnham',
#   '.',
#   'mec',
#   'marrant'],
#  ['sensationnel', '.', "J'", 'ai', 'encore', 'un', 'mal', 'de', 'tête'],
#  ['Sophs',
#   'endormis',
#   'sur',
#   'moi',
#   'aussi',
#   ',',
#   'mon',
#   'téléphone',
#   'continue',
#   'de',
#   'fonctionner',
#   'et',
#   'je',
#   'ne',
#   'peux',
#   'pa',
#   "l'",
#   'obtenir',
#   '!',
#   'Elle',
#   'v.',
#   'Somnolent',
#   "aujourd'hui",
#   '?',
#   '!',
#   '?'],
#  ['Hahhaa',
#   'qui',
#   'eu',
#   'de',
#   'la',
#   'chance',
#   'de',
#   'ne',
#   'pa',
#   'faire',
#   'de',
#   'très',
#   'bons',
#   'copains',
#   'de',
#   'voyage',
#   'serait',
#   '-on',
#   '?',
#   'Ba',
#   'sont',
#   'de',
#   'ordure',
#   ',',
#   'il',
#   'ne',
#   'semblent',
#   'pa',
#   'trop',
#   'aimer'],
#  ['Prouve',
#   'simplement',
#   'que',
#   'personne',
#   'ne',
#   'lit',
#   'plus',
#   'le',
#   'site',
#   'Web',
#   'si',
#   'ce',
#   "n'",
#   'est',
#   'pa',
#   'Twitter',
#   ',',
#   'il',
#   "n'",
#   'existe',
#   'pa',
#   '.'],
#  ['Se',
#   'demande',
#   'comment',
#   'il',
#   'peut',
#   'être',
#   'très',
#   'nuageux',
#   'quand',
#   'il',
#   'été',
#   'charmant',
#   'ce',
#   'derniers',
#   'jours'],
#  ['se', 'déconnecter', '!', 'Passer', 'au', 'mode', 'PC', '.'],
#  ['Cerise',
#   'après',
#   'une',
#   'journée',
#   'magnifique',
#   ',',
#   'un',
#   'barbecue',
#   'fabuleux',
#   'et',
#   'une',
#   'belle',
#   'nuit'],
#  ['Hahahah',
#   'owh',
#   'lool',
#   'ça',
#   'fonctionnera',
#   "j'",
#   'espère',
#   "qu'",
#   'il',
#   'vaut',
#   'mieux',
#   'que',
#   "l'",
#   'homme',
#   'je',
#   'déteste',
#   'hollande'],
#  ['Vraiment',
#   'mauvais',
#   'temp',
#   '.',
#   'Parfait',
#   'pour',
#   "s'",
#   'asseoir',
#   'dans',
#   'le',
#   'lit',
#   'en',
#   'regardant',
#   'seinfeld'],
#  ['Le',
#   'nouveau',
#   '-',
#   'shirt',
#   '5preview',
#   '....',
#   'Je',
#   'ne',
#   'vous',
#   'aime',
#   'arriver',
#   'je',
#   'besoin',
#   'de',
#   'mettre',
#   'à',
#   'jour',
#   'sur',
#   'le',
#   'dernières',
#   'choses',
#   '!'],
#  ['Je', 'suis', 'officiellement', '26'],
#  ["S'",
#   'il',
#   'vous',
#   'plaît',
#   ',',
#   'veuillez',
#   'le',
#   'réserver',
#   '!',
#   'il',
#   'sont',
#   'étonnants',
#   '!'],
#  ['Fait', '-il', '?', '?', '?', 'je', 'suis', 'offensé'],
#  ['@',
#   'Luke8bt',
#   'luke',
#   '....',
#   'vient',
#   'de',
#   'trouver',
#   'votre',
#   'réponse',
#   '.',
#   'Je',
#   'vous',
#   'remercie',
#   '.',
#   'vraiment',
#   'apprécié',
#   '.',
#   'Nous',
#   'somme',
#   'de',
#   'nouveau',
#   'amis',
#   '.'],
#  ['Ne', 'pa', 'se', 'sentir', 'bien', '..'],
#  ['Plus', 'bbm'],
#  ['Deux',
#   'en',
#   'ba',
#   'pour',
#   'aller',
#   'au',
#   'saint',
#   'jeudi',
#   'fille',
#   '!',
#   '!',
#   '!'],
#  ["N'",
#   'pa',
#   "d'",
#   'accès',
#   'à',
#   'YouTube',
#   'mais',
#   'doit',
#   'rechercher',
#   'pour',
#   'youtube'],
#  ['Assurez',
#   '-vous',
#   'de',
#   'publier',
#   'vos',
#   'prédictions',
#   'sur',
#   'le',
#   'forum',
#   'à',
#   'www.socceram.net'],
#  ['Merci', ',', 'je', 'suis', 'surpris', 'un', 'peu'],
#  ["C'",
#   'est',
#   'si',
#   'gentil',
#   'à',
#   "l'",
#   'extérieur',
#   "aujourd'hui",
#   ',',
#   'mais',
#   'ressemble',
#   'à',
#   'eryn',
#   'et',
#   'je',
#   'passerai',
#   'le',
#   'jour',
#   'à',
#   "l'",
#   'intérieur',
#   ',',
#   'elle',
#   "s'",
#   'est',
#   'réveillée',
#   'malade',
#   '...'],
#  ['Bien',
#   '...',
#   'Tu',
#   'veux',
#   'dire',
#   'que',
#   'tu',
#   'ne',
#   'feras',
#   'pa',
#   "l'",
#   'énergie',
#   'pour',
#   'trouver',
#   '?'],
#  ['Yay',
#   '!',
#   'voir',
#   '?',
#   '!',
#   'Restez',
#   'avec',
#   'moi',
#   '...',
#   'je',
#   'suis',
#   'plein',
#   'de',
#   'bonnes',
#   'idées',
#   'comme',
#   'ça',
#   '.',
#   '*',
#   'gros',
#   'câlins',
#   '*'],
#  ['Même',
#   'ici',
#   '...',
#   '*',
#   'mode',
#   'envy',
#   '*',
#   '...',
#   'elle',
#   "n'",
#   'pa',
#   'besoin',
#   'de',
#   '2',
#   'crunch',
#   'comme',
#   'je',
#   'shud',
#   '...',
#   'comme',
#   'wat',
#   "j'",
#   'ai',
#   'besoin',
#   'de',
#   '2',
#   'faire',
#   'plus',
#   'tard',
#   '...',
#   'wahaha'],
#  ['Et', 'merci', 'beaucoup'],
#  ['Est',
#   '-ce',
#   'que',
#   'je',
#   'peux',
#   'écouter',
#   'de',
#   'la',
#   'radio',
#   '(',
#   ')',
#   'sur',
#   "l'",
#   'iPhone',
#   '?',
#   "J'",
#   'ai',
#   'juste',
#   'brûlé',
#   'le',
#   'seul',
#   'petit',
#   'déjeuner',
#   'viable',
#   'que',
#   "j'",
#   'avais',
#   'dans',
#   'la',
#   'maison'],
#  ["d'",
#   'accord',
#   '.',
#   'Je',
#   'suppose',
#   'que',
#   'je',
#   'vais',
#   'tweeter',
#   'quelques',
#   'choses',
#   'aléatoires',
#   'et',
#   'ensuite',
#   'avoir',
#   'mon',
#   '2700e',
#   'tweet',
#   ',',
#   'puis',
#   'je',
#   'couche',
#   '.',
#   "d'",
#   'accord',
#   '?'],
#  ['Mon',
#   'obsédé',
#   'de',
#   '7',
#   'an',
#   ',',
#   'tout',
#   'comme',
#   'il',
#   'ré-créé',
#   'la',
#   'bataille',
#   'de',
#   'Geonosis',
#   'à',
#   'partir',
#   'de',
#   "l'",
#   'épisode',
#   '2',
#   '.',
#   'vraiment',
#   'incroyable',
#   '.'],
#  ["C'",
#   'est',
#   'un',
#   'samedi',
#   'matin',
#   'parfait',
#   '.',
#   'Le',
#   'soleil',
#   'brille',
#   ',',
#   'le',
#   'oiseaux',
#   'chantent',
#   '...',
#   'et',
#   'je',
#   'rattrape',
#   'sur',
#   'admin'],
#  ['Nous',
#   'avon',
#   'eu',
#   'tout',
#   'notre',
#   'bacon',
#   'pour',
#   'dîner',
#   'hier',
#   'soir'],
#  ['Je',
#   'ne',
#   'peux',
#   'pa',
#   'dormir',
#   '!',
#   'Je',
#   'doi',
#   'lever',
#   'dans',
#   '3',
#   'heures',
#   '.'],
#  ["J'",
#   'espère',
#   'que',
#   'je',
#   'pourrai',
#   '/',
#   'ou',
#   "j'",
#   'espère',
#   'que',
#   'le',
#   'conférencier',
#   'nous',
#   'donne',
#   'un',
#   'feu',
#   'vert',
#   'sur',
#   'le',
#   'projet',
#   ',',
#   'sinon',
#   ',',
#   'doit',
#   'travailler',
#   'pendant',
#   'la',
#   'nuit',
#   '...'],
#  ['Est', 'au', 'bureau'],
#  ['Stationné',
#   'sur',
#   'la',
#   'm1',
#   'le',
#   'jour',
#   'le',
#   'plus',
#   'chaud',
#   'de',
#   "l'",
#   'année'],
#  ['Je',
#   'pourrais',
#   'avoir',
#   'pris',
#   'une',
#   'décision',
#   'stupide',
#   'à',
#   'certains',
#   ',',
#   'mais',
#   'dans',
#   "l'",
#   'ensemble',
#   ',',
#   'je',
#   'suis',
#   'bien',
#   'amusé'],
#  ['Mon',
#   'ordinateur',
#   'portable',
#   'est',
#   'en',
#   'panne',
#   'alors',
#   'je',
#   "n'",
#   'ai',
#   'pa',
#   "d'",
#   'ordinateur',
#   'en',
#   'ce',
#   'moment'],
#  ['Hey',
#   '.',
#   'Passez',
#   'le',
#   'message',
#   'sur',
#   'Rory',
#   'que',
#   'je',
#   "l'",
#   'aime',
#   'absolument',
#   '!',
#   'Et',
#   "j'",
#   'adore',
#   'le',
#   'reste',
#   "d'",
#   'entre',
#   'vous',
#   ',',
#   'vous',
#   'avez',
#   'donné',
#   'un',
#   'coup',
#   'de',
#   'pied',
#   'au',
#   'dernier',
#   'mois',
#   '!'],
#  ['Lol',
#   '!',
#   'Ils',
#   'gardent',
#   'la',
#   'garde',
#   '!',
#   'Fille',
#   'amusante',
#   'en',
#   'liberté',
#   '!',
#   'Lol',
#   'j',
#   '/',
#   'k',
#   '!'],
#  ['-',
#   'disappeares',
#   'de',
#   'divertissement',
#   "d'",
#   'été',
#   ';',
#   'Avec',
#   "l'",
#   'été',
#   'en',
#   'Autriche',
#   '!',
#   '!'],
#  ['Jon',
#   '!',
#   'Bon',
#   'de',
#   'vous',
#   'voir',
#   'ici',
#   '!',
#   'Je',
#   'doi',
#   'venir',
#   'prendre',
#   'un',
#   'déjeuner',
#   'là',
#   '-',
#   'ba',
#   'bientôt',
#   '!'],
#  ['Vous',
#   'ne',
#   "m'",
#   'avez',
#   'pa',
#   'répondu',
#   ',',
#   'je',
#   'doi',
#   'donner',
#   '10',
#   '$',
#   'pour',
#   'mon',
#   'ami'],
#  ['-', 'tellement', 'mieux', '.', 'nouveau', 'et', 'amélioré'],
#  ['Oui', 'il', 'avait', '70', 'an', 'il', '2', 'semaines'],
#  ["J'", 'ai', 'parfois', 'le', 'deux', 'confus', '.'],
#  ['Est',
#   'en',
#   'train',
#   'de',
#   'manger',
#   'un',
#   'bon',
#   'bol',
#   'chaud',
#   'de',
#   'ramen',
#   'et',
#   'de',
#   'deuil',
#   'le',
#   'fait',
#   "qu'",
#   'elle',
#   'pris',
#   'son',
#   'téléphone',
#   'et',
#   'iPod',
#   'pris',
#   'ce',
#   'soir',
#   '...',
#   'Je',
#   'déteste',
#   'mon',
#   'vie',
#   '!'],
#  ['Salut', 'merci', 'de', "m'", 'avoir', 'suivi', 'xx'],
#  ['-', 'je', "t'", 'aime'],
#  ['Cela', 'suce', "l'", 'espoir', 'de', 'ne', 'pa', 'tomber', 'malade', '!'],
#  ['Vient',
#   'de',
#   'télécharger',
#   'la',
#   'photo',
#   'de',
#   'mon',
#   'espace',
#   'de',
#   'ciel',
#   'bleu'],
#  ['Mes', 'parent', 'aiment', 'le', 'format', '!'],
#  ["J'",
#   'aimerais',
#   'être',
#   'sorti',
#   'mais',
#   'aimer',
#   'bébé',
#   'kyssja',
#   '&',
#   'lt',
#   ';',
#   '3'],
#  ['Mon', 'bébé', 'est', 'vivant'],
#  ['En',
#   'attendant',
#   'que',
#   'Android',
#   '1.5',
#   'soit',
#   'poussé',
#   'à',
#   'la',
#   'g1',
#   'alors',
#   '?'],
#  ['Baise', "j'", 'ai', 'perdu', 'mon', 'capuchon', "d'", 'objectif'],
#  ['maintenant', "c'", 'est', '?', 'cool'],
#  ['Oh',
#   ',',
#   'je',
#   'sais',
#   '!',
#   'Je',
#   'regardais',
#   'avec',
#   'le',
#   'plus',
#   'petit',
#   'visage'],
#  ['Je',
#   'suis',
#   'tellement',
#   'fou',
#   'que',
#   "j'",
#   'ai',
#   'raté',
#   'le',
#   'tremblement',
#   'de',
#   'terre',
#   '!',
#   'Je',
#   'conduis',
#   'toujours',
#   'quand',
#   'ce',
#   'choses',
#   'se',
#   'passent',
#   '!'],
#  ["j'", 'ai', 'mal', 'au', 'doigt', '....'],
#  ['pssh', 'je', "n'", 'ai', 'rien', '.'],
#  ['17', 'jours', "jusqu'", 'à', 'ce', 'que', 'Star', 'Trek', 'arrive', '!'],
#  ['bonne', 'nuit', '!'],
#  [':',
#   'Essayez',
#   'twitter',
#   'de',
#   'la',
#   'nouvelle',
#   'Blackberry',
#   'bold',
#   'de',
#   'votre',
#   'femme',
#   'en',
#   'utilisant',
#   'ubertwitter',
#   'ou',
#   'application',
#   'twitterberry'],
#  ['Je',
#   'voudrais',
#   'vraiment',
#   'que',
#   "j'",
#   'aurais',
#   'pris',
#   'cette',
#   'biscuit',
#   'n',
#   'crème',
#   '...',
#   'tu',
#   'pen',
#   'que',
#   'ça',
#   'va',
#   'faire',
#   'passer',
#   '?'],
#  ['Les',
#   'mauvaises',
#   'choses',
#   'viennent',
#   '-',
#   'elles',
#   'en',
#   'trois',
#   '?',
#   'Vous',
#   'êtes',
#   'sur',
#   'un',
#   'rouleau',
#   '...'],
#  ['Eh', '.', 'Tout', 'le', 'monde', 'est', 'allé', 'au', 'lit'],
#  ['Nuit', 'au', 'musée', 'aspirée', '!', "J'", 'aimerais', 'avoir', 'vu'],
#  ['Est', 'prêt', 'à', 'se', 'coucher', '...', 'long', 'demain'],
#  ['Eh',
#   'bien',
#   ',',
#   'au',
#   'moins',
#   'prendre',
#   'une',
#   'photo',
#   'ou',
#   'deux',
#   "s'",
#   'il',
#   'vous',
#   'plaît',
#   '!'],
#  ['Mauvaise',
#   'expérience',
#   'dans',
#   'er',
#   '...',
#   'la',
#   'vie',
#   'est',
#   'vraiment',
#   'courte',
#   '.'],
#  ['Est',
#   'malade',
#   'de',
#   'faire',
#   'du',
#   'bruit',
#   '.',
#   'Aller',
#   'voir',
#   'de',
#   'amis',
#   'pour',
#   'discuter',
#   'et',
#   'un',
#   'café'],
#  ['Merci',
#   'pour',
#   'la',
#   'tête',
#   ',',
#   'tu',
#   'absolument',
#   'raison',
#   '...',
#   'ferai'],
#  ['Il',
#   'suffit',
#   'de',
#   'lira',
#   'que',
#   'Farrah',
#   'fawcett',
#   'est',
#   'mort',
#   '.',
#   'Rip',
#   ',',
#   'ange',
#   '.'],
#  ['Je', 'pense', 'que', 'mon', 'oreille', 'pourrait', 'être', 'infectée'],
#  ['Nb', 'prenez', 'deux'],
#  ["N'",
#   'pa',
#   'eu',
#   'le',
#   'shoplifter',
#   '.',
#   'A',
#   'vu',
#   'la',
#   'personne',
#   ',',
#   'mais',
#   'pa',
#   'autorisé',
#   'à',
#   'toucher',
#   'la',
#   'personne',
#   'pour',
#   'le',
#   'arrêter',
#   '.',
#   'Très',
#   'irritant',
#   '.'],
#  ['Rochelle',
#   'prend',
#   's',
#   'photo',
#   '?',
#   'Yay',
#   '!',
#   'Haha',
#   '.',
#   'Elle',
#   'est',
#   'géniale',
#   ',',
#   'elle',
#   'doit',
#   "l'",
#   'aimer',
#   '.',
#   "s'",
#   'amuser',
#   '!',
#   "J'",
#   'espère',
#   'que',
#   'je',
#   'vais',
#   'voir',
#   'ce',
#   'coup',
#   ',',
#   'ouais',
#   '?'],
#  ['Je', 'suis', 'battu', '...', 'Goodnight', 'twitter', '!'],
#  ['Ne', 'gaspille', 'pa', 'te', 'larmes', 'de', 'fiction'],
#  ['Avec',
#   'mac',
#   ',',
#   'Apple',
#   'fournit',
#   'un',
#   'bon',
#   'moyen',
#   'de',
#   'migrer',
#   'de',
#   "l'",
#   'ancien',
#   'vers',
#   'le',
#   'nouveau',
#   '.',
#   'Je',
#   "n'",
#   'ai',
#   'pa',
#   'encore',
#   'vu',
#   'de',
#   'article',
#   'similaires',
#   'pour',
#   'iphones',
#   '.',
#   "n'",
#   'importe',
#   'qui',
#   '?',
#   'Manuellement',
#   'alors'],
#  ['Se',
#   'sent',
#   'vraiment',
#   'froid',
#   'à',
#   'la',
#   'maison',
#   '-',
#   'très',
#   'différent',
#   'par',
#   'rapport',
#   'à',
#   'cette',
#   'semaine',
#   'la',
#   'semaine',
#   'dernière',
#   '!',
#   'Va',
#   'monter',
#   'le',
#   'chauffage',
#   'car',
#   'me',
#   'orteils',
#   'sont',
#   'gelés'],
#  ['Essayant', 'de', 'passer', 'cette', 'classe', "d'", 'espagnol'],
#  ['Amour', 'de', 'la', 'nuit', 'de', 'ronde', '4', 'démo'],
#  ['Omg',
#   ',',
#   'je',
#   "n'",
#   'ai',
#   'vraiment',
#   'envie',
#   "d'",
#   'étudier',
#   '!',
#   '!',
#   '!',
#   '!'],
#  ['Jade',
#   'suce',
#   '......',
#   'Elle',
#   'est',
#   'méchante',
#   ',',
#   'elle',
#   'veut',
#   'que',
#   'je',
#   'le',
#   'regarde',
#   'parce',
#   "qu'",
#   'elle',
#   "l'",
#   'air',
#   'de',
#   'regarder',
#   'maintenant',
#   '!',
#   'Oldies',
#   'sanglantes'],
#  ['Bien',
#   ',',
#   'il',
#   'vont',
#   'grandir',
#   'avant',
#   'de',
#   'le',
#   'connaître',
#   ',',
#   'alors',
#   'prenez',
#   'le',
#   'temp',
#   'maintenant'],
#  ['Ne', 'pa', 'trop', 'chaud'],
#  ['B', '?', 'Ng', 'b', '?', 'T'],
#  ['Je',
#   'fais',
#   'fumer',
#   'afin',
#   'que',
#   'je',
#   'puisse',
#   'sembler',
#   'mauvais',
#   'comme',
#   'Lawrence',
#   'tierney',
#   ',',
#   'mais',
#   'je',
#   'finirais',
#   'probablement',
#   'par',
#   'ressembler',
#   'à',
#   'un',
#   'jable',
#   'de',
#   'juin'],
#  ['Vraiment',
#   ',',
#   'je',
#   "n'",
#   'ai',
#   'plus',
#   'le',
#   'temp',
#   'pour',
#   'ça',
#   '...'],
#  ['Whoops', ',', 'ce', 'dernier', 'tweet', 'était', 'pour', 'vous', '.'],
#  ['Je',
#   'suis',
#   'désolé',
#   'que',
#   'vous',
#   'soyez',
#   'perplexe',
#   '!',
#   'triste',
#   '!',
#   'Nous',
#   'allons',
#   'vous',
#   'faire',
#   'un',
#   'spectacle',
#   'bientôt',
#   '!',
#   '!'],
#  ['Oh',
#   'oui',
#   ',',
#   'mais',
#   'je',
#   'suis',
#   'aussi',
#   'très',
#   'triste',
#   'à',
#   'la',
#   'rapidité',
#   'avec',
#   'laquelle',
#   'il',
#   'est',
#   'parti',
#   '!',
#   'comment',
#   'va',
#   'tout',
#   'le',
#   'monde',
#   '?',
#   '?'],
#  ['-',
#   'bisou',
#   ',',
#   'aerosmith',
#   ',',
#   'tdf',
#   ',',
#   'atl',
#   ',',
#   'bowling',
#   'pour',
#   'soupe',
#   ',',
#   'weezer',
#   '.',
#   'Je',
#   'suis',
#   'vraiment',
#   'en',
#   'train',
#   'de',
#   'nommer',
#   'me',
#   'groupes',
#   'préférés',
#   ',',
#   'mais',
#   'leurs',
#   'noms',
#   'sont',
#   'vraiment',
#   'cool',
#   '!'],
#  ['Très',
#   'gentil',
#   'ami',
#   ',',
#   'qui',
#   'peut',
#   'rendre',
#   'au',
#   'monde',
#   'normal'],
#  ['Ce', "n'", 'est', 'pa', 'le', 'soleil', "aujourd'hui"],
#  ['Lorsque',
#   'vous',
#   'savez',
#   'que',
#   'vous',
#   "n'",
#   'avez',
#   'presque',
#   'rien',
#   'en',
#   'commun',
#   'avec',
#   "quelqu'",
#   'un',
#   ',',
#   'mais',
#   'que',
#   'vous',
#   'vous',
#   'sentez',
#   'en',
#   'sécurité',
#   ',',
#   "qu'",
#   'est',
#   '-ce',
#   'que',
#   'cela',
#   'signifie',
#   '?',
#   'Ressemble',
#   '-t',
#   '-il',
#   'à',
#   'une',
#   'âme',
#   'soeur',
#   '?'],
#  ['Sur',
#   'le',
#   'chemin',
#   'de',
#   "l'",
#   'accueil',
#   'de',
#   'Audrey',
#   '.',
#   'Elle',
#   'ne',
#   'le',
#   'sait',
#   'pa',
#   'encore',
#   ',',
#   'elle',
#   'achète',
#   'son',
#   'premier',
#   'set',
#   'de',
#   'coup'],
#  ["N'",
#   'ont',
#   'pa',
#   'regardé',
#   'la',
#   'télévision',
#   'dans',
#   'quelques',
#   'semaines',
#   '.',
#   "L'",
#   'allumé',
#   'la',
#   'dernière',
#   'nuit',
#   ',',
#   'décidé',
#   "qu'",
#   'il',
#   'était',
#   'stupide',
#   'et',
#   "l'",
#   'éteint',
#   '.'],
#  ['Ooooo',
#   "j'",
#   'aimerais',
#   'venir',
#   'et',
#   'déchiqueter',
#   'de',
#   'choses',
#   'lol'],
#  ['Uhe',
#   '-',
#   "j'",
#   'étais',
#   'inquiet',
#   'pour',
#   'toi',
#   ';',
#   "C'",
#   'était',
#   'toucher',
#   'et',
#   'aller',
#   ',',
#   'mais',
#   'vous',
#   'avez',
#   'traversé'],
#  ...]

# %%
np.array(new_tweets).shape
# Out:
# /tmp/ipykernel_738129/1674151064.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   np.array(new_tweets).shape
# (20000,)

# %%
new_col = np.array(new_tweets)
print(type(new_col))
new_col

df_sample['preprocessed_spacy'] = new_col # pas besoin de convertir en pd.Series
df_sample.head()
# Out:
# <class 'numpy.ndarray'>
# /tmp/ipykernel_738129/2798256704.py:1: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   new_col = np.array(new_tweets)
#          label                                               text  \
# 121958       0  Mais je ne peux pas envoyer de courrier électr...
# 671155       0  Se sent mal après avoir mangé & quot; cinema s...
# 131932       0     awwe..hey..i doivent chat lit g2 plus tard? :]
# 1414414      1  La famille et les amis sont partis après un be...
# 259178       0  Oui, je commence définitivement à ressentir le...
#
#                                     preprocessed_text_nltk  \
# 121958   [Mais, je, ne, peux, pa, envoyer, de, courrier...
# 671155   [Se, sent, mal, après, avoir, mangé, &, quot, ...
# 131932   [awwe, .., hey, .., doivent, chat, lit, g2, pl...
# 1414414  [La, famille, et, le, amis, sont, partis, aprè...
# 259178   [Oui, ,, je, commence, définitivement, à, ress...
#
#                                         preprocessed_spacy
# 121958   [Mais, je, ne, peux, pa, envoyer, de, courrier...
# 671155   [Se, sent, mal, après, avoir, mangé, &, quot, ...
# 131932   [awwe, .., hey, .., doivent, chat, lit, g2, pl...
# 1414414  [La, famille, et, le, amis, sont, partis, aprè...
# 259178   [Oui, ,, je, commence, définitivement, à, ress...

# %% [markdown]
# Compare the time with this method.

# %% [markdown]
# # 3. Sentiment classification

# %% [markdown]
# Now that you have the tools to pre-process large bodies of text, you can try to classify more than 20,000 tweets (100,000 for example) 🔥!
#
# For this part, you are free to use the classification methods of your choice.
# Focus on preprocessing by exploring the tweets further 🔬!

# %%
## Build initial X and y
X = df_sample.preprocessed_spacy
y = df_sample.label.to_numpy()
X.shape
# Out:
# (20000,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)
print(f'X_train.shape: {X_train.shape}')
print(f'X_test.shape: {X_test.shape}')
print(f'y_train.shape: {y_train.shape}')
print(f'y_test.shape: {y_test.shape}')
# Out:
# X_train.shape: (15000,)
# X_test.shape: (5000,)
# y_train.shape: (15000,)
# y_test.shape: (5000,)

# %%
X_train
# Out:
# 518895                                           [suis, moi]
# 1195889                     [Merci, pour, votre, suppotoday]
# 825992       [Je, l', aime, ,, dwight, est, mon, préféré, .]
# 1505759            [Dit, que, l', amour, vivant, grandit, .]
# 1303175    [En, regardant, le, tweet, de, tht, ,, il, rap...
#                                  ...
# 1087288    [Dîner, et, ensuite, jouer, au, softball, avec...
# 78343      [Je, viens, de, rentrer, de, la, pendaison, av...
# 1431728    [Uriel, !, Vous, êtes, en, train, de, faire, l...
# 1386465    [toutes, no, félicitations, !, Très, drôle, ,,...
# 685521     [Vous, n', étiez, pa, un, bon, camarade, de, n...
# Name: preprocessed_spacy, Length: 15000, dtype: object

# %%
vectorizer = TfidfVectorizer(lowercase=False, analyzer=lambda x: x)
tf_idf_train = vectorizer.fit_transform(X_train).toarray()
tf_idf_train.shape
# Out:
# (15000, 20230)

# %%
## TEST: transform only on Test
tf_idf_test = vectorizer.transform(X_test).toarray()

# %%
lr = LogisticRegression(max_iter=100)
lr.fit(tf_idf_train, y_train)

# prédictions sur Train et Test
y_pred_train = lr.predict(tf_idf_train)
y_pred_test  = lr.predict(tf_idf_test)

# %%
# F1-score de Test
from sklearn.metrics import f1_score

vect_f1_score_test = f1_score(y_test, y_pred_test, average=None)
print(f" F1-score sur Test - label 0: {vect_f1_score_test[0]}")
print(f" F1-score sur Test - label 1: {vect_f1_score_test[1]}")
# on 20000 samples:
"""
F1-score sur Test - label 0: 0.7455023246411967
F1-score sur Test - label 1: 0.7508410845042549
"""
# Out:
#  F1-score sur Test - label 0: 0.7455023246411967
#  F1-score sur Test - label 1: 0.7508410845042549
# '\nF1-score sur Test - label 0: 0.7455023246411967\nF1-score sur Test - label 1: 0.7508410845042549\n'
